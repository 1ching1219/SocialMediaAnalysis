# %% [markdown]
# # 第14週 社群網路分析
#
# **Author** : 蔡俊宏
#
# **Date created** : 2023/05/14
#
# 本週課程利用之前使用的PTT美食版，觀察發文者與回文者的情況

# %%
! pip install pyvis networkx pandas numpy
# Out:
# Requirement already satisfied: pyvis in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (0.3.2)
# Requirement already satisfied: networkx in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (3.1)
# Requirement already satisfied: pandas in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (2.0.1)
# Requirement already satisfied: numpy in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (1.24.3)
# Requirement already satisfied: ipython>=5.3.0 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from pyvis) (8.12.2)
# Requirement already satisfied: jinja2>=2.9.6 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from pyvis) (3.1.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from pyvis) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: backcall in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: decorator in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (2.15.1)
# Requirement already satisfied: stack-data in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (5.9.0)
# Requirement already satisfied: typing-extensions in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (4.5.0)
# Requirement already satisfied: pexpect>4.3 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: appnope in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from jinja2>=2.9.6->pyvis) (2.1.2)
# Requirement already satisfied: six>=1.5 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->pyvis) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from stack-data->ipython>=5.3.0->pyvis) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/caijunhong/opt/anaconda3/envs/net/lib/python3.8/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)

# %%
import pandas as pd
import numpy as np
import pyvis
import networkx as nx
import IPython

# %%
raw_data = pd.read_csv('./raw_data/buffet_20_22.csv')
raw_data = raw_data[raw_data.artComment != '[]']
raw_data = raw_data.sample(round(raw_data.shape[0]/4))
print(raw_data.shape)
raw_data.head()
# Out:
# (123, 11)
#       system_id                                             artUrl
# 394         395  https://www.ptt.cc/bbs/Food/M.1596626709.A.48F...  \
# 303         304  https://www.ptt.cc/bbs/Food/M.1592063279.A.E0E...
# 239         240  https://www.ptt.cc/bbs/Food/M.1589791255.A.49C...
# 1231       1232  https://www.ptt.cc/bbs/Food/M.1643432020.A.8B5...
# 854         855  https://www.ptt.cc/bbs/Food/M.1616237558.A.40E...
#
#                      artTitle              artDate   artPoster artCatagory
# 394             [食記]高雄小反推花福韓燒  2020-08-05 19:25:04      linche        Food  \
# 303           [食記]台北欣葉日本料理健康店  2020-06-13 23:47:57     nikcoke        Food
# 239     [食記]新北板橋鍋飽飽火鍋＄145起吃超飽  2020-05-18 16:40:52     ally701        Food
# 1231            [食記]台中陶樂里庭園蔬食  2022-01-29 12:53:37        dass        Food
# 854   [食記]台北中正北車泰獅泰式料理(月亮蝦餅超厚  2021-03-20 18:52:32  TW00500203        Food
#
#                                              artContent
# 394   餐廳名稱：花福韓燒\n   消費時間：2020/5\n   地址：807高雄市三民區正忠路4...  \
# 303   日式料理吃到飽系列之--欣葉日本料理健康店\n\n有圖有真相圖文並茂版：\nhttps://...
# 239   2019年5月\n無音樂。有圖真相網誌好讀版\nhttps://ally701.pixnet...
# 1231  餐廳名稱：陶樂里庭園蔬食\n   消費時間：2022年/1月\n   地址：台中市潭子區豐興...
# 854   【泰獅 泰式料理】\n電話：02 2311 7778\n地址：台北市中正區武昌街一段16巷1...
#
#                                              artComment            e_ip
# 394   [{"cmtStatus": "推", "cmtPoster": "faway", "cmt...  27.246.197.217  \
# 303   [{"cmtStatus": "推", "cmtPoster": "perfectperfe...  211.75.180.193
# 239   [{"cmtStatus": "推", "cmtPoster": "allen1224a",...    101.10.19.36
# 1231  [{"cmtStatus": "推", "cmtPoster": "King12man36"...  123.110.12.146
# 854   [{"cmtStatus": "推", "cmtPoster": "ring0816", "...  49.216.222.250
#
#              insertedDate dataSource
# 394   2020-08-06 00:31:00        ptt
# 303   2020-06-14 00:04:36        ptt
# 239   2020-05-19 00:04:19        ptt
# 1231  2022-01-30 00:13:52        ptt
# 854   2021-03-21 00:29:02        ptt

# %%
#parse comment

def getComtInfo(com):
  cmters,cmt_statuss = [],[]
  com = eval(com)
  for i in com:
    print(i)
    cmters.append(i['cmtPoster'])
    cmt_statuss.append(i['cmtStatus'])
  return pd.Series([cmters, cmt_statuss])

raw_data[['artComter','artStatus']] = raw_data['artComment'].apply(lambda r: getComtInfo(r))
# Out:
# {'cmtStatus': '推', 'cmtPoster': 'faway', 'cmtContent': ':他們當務之急要改善的是抽氣設備,現在的效果簡直趨近於零', 'cmtDate': '2020-08-06 08:15:00'}
# {'cmtStatus': '→', 'cmtPoster': 'linche', 'cmtContent': ':我覺得需要好好整間重新整頓0..0', 'cmtDate': '2020-08-06 20:36:00'}
# {'cmtStatus': '推', 'cmtPoster': 'perfectperfe', 'cmtContent': ':現在加欣葉line好友，會有送滿500可折100的優待券', 'cmtDate': '2020-06-14 10:34:00'}
# {'cmtStatus': '→', 'cmtPoster': 'perfectperfe', 'cmtContent': ':。', 'cmtDate': '2020-06-14 10:34:00'}
# {'cmtStatus': '推', 'cmtPoster': 'allen1224a', 'cmtContent': ':2019，5月？', 'cmtDate': '2020-05-19 23:31:00'}
# {'cmtStatus': '推', 'cmtPoster': 'King12man36', 'cmtContent': ':推', 'cmtDate': '2022-01-29 13:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ring0816', 'cmtContent': ':饗泰多的月亮蝦餅也超厚~', 'cmtDate': '2021-03-21 21:07:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yakifone', 'cmtContent': ':這名字', 'cmtDate': '2020-09-22 16:12:00'}
# {'cmtStatus': '→', 'cmtPoster': 'breeze1006', 'cmtContent': ':之前吃過一次，記憶點很低、油煙味殘留在衣服上散不去', 'cmtDate': '2020-09-22 18:39:00'}
# {'cmtStatus': '推', 'cmtPoster': 'OGCOGCOGCOGC', 'cmtContent': ':為什麼要叫青樓啦XD', 'cmtDate': '2020-09-22 20:00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'flyingturtle', 'cmtContent': ':本來想去的，感謝分享', 'cmtDate': '2022-01-05 12:16:00'}
# {'cmtStatus': '推', 'cmtPoster': 'axion123', 'cmtContent': ':辛苦了，謝謝分享', 'cmtDate': '2022-01-05 14:01:00'}
# {'cmtStatus': '→', 'cmtPoster': 'chister', 'cmtContent': ':桂花就是芙蓉就是雞蛋', 'cmtDate': '2022-01-05 22:12:00'}
# {'cmtStatus': '推', 'cmtPoster': 'tiffanyhh', 'cmtContent': ':以前還不是吃到飽的時候超好吃的', 'cmtDate': '2022-01-05 22:47:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Pilar', 'cmtContent': ':小貴但看起來很過癮!', 'cmtDate': '2022-08-08 15:49:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kevin751231', 'cmtContent': ':貓呢？！我要貓？！', 'cmtDate': '2020-04-09 02:56:00'}
# {'cmtStatus': '推', 'cmtPoster': 'gn00661791', 'cmtContent': ':請問冷氣有改強嗎？上次去吃汗流浹背', 'cmtDate': '2022-09-29 00:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'nikcoke', 'cmtContent': ':我去吃的時候人潮沒有到很多,冷氣還算可以', 'cmtDate': '2022-09-29 21:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kidfu', 'cmtContent': ':量少，..吃不飽..', 'cmtDate': '2020-08-13 20:27:00'}
# {'cmtStatus': '推', 'cmtPoster': 'bell', 'cmtContent': ':現在是陽交大學', 'cmtDate': '2022-01-19 03:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'popoajcjje', 'cmtContent': ':感謝分享', 'cmtDate': '2022-04-21 14:29:00'}
# {'cmtStatus': '推', 'cmtPoster': 'hd6520', 'cmtContent': ':如果白蝦草蝦好吃就給滿分，這價位cp值真的高', 'cmtDate': '2022-01-05 22:12:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mimicwpe', 'cmtContent': ':推', 'cmtDate': '2022-01-06 01:44:00'}
# {'cmtStatus': '推', 'cmtPoster': 'TeamFrotress', 'cmtContent': ':作為住在附近的人推個', 'cmtDate': '2022-06-26 20:13:00'}
# {'cmtStatus': '推', 'cmtPoster': 'VegasThu', 'cmtContent': ':good', 'cmtDate': '2022-07-15 00:09:00'}
# {'cmtStatus': '推', 'cmtPoster': 'vV070413', 'cmtContent': ':我7/4那天去吃，菜補的很快，飲料也上的快，收盤也快速', 'cmtDate': '2022-07-15 20:54:00'}
# {'cmtStatus': '推', 'cmtPoster': 'selfvalue', 'cmtContent': ':', 'cmtDate': '2022-07-15 23:07:00'}
# {'cmtStatus': '→', 'cmtPoster': 'rtav', 'cmtContent': ':不推這間', 'cmtDate': '2020-01-04 12:53:00+00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mickey0127', 'cmtContent': ':讚讚', 'cmtDate': '2021-03-28 23:16:00'}
# {'cmtStatus': '推', 'cmtPoster': 'valgia', 'cmtContent': ':推感覺滿新奇吸引人~', 'cmtDate': '2021-03-29 15:21:00'}
# {'cmtStatus': '推', 'cmtPoster': 'dong08111', 'cmtContent': ':吃過兩次，不同分店，非常不推。肉很碎而且感覺不太新', 'cmtDate': '2021-03-29 17:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'dong08111', 'cmtContent': ':鮮、炸物也很普通...年糕分很多種，但吃不太出差別。', 'cmtDate': '2021-03-29 17:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'dong08111', 'cmtContent': ':價格頗貴，起士加100多塊只有薄薄一層', 'cmtDate': '2021-03-29 17:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'dong08111', 'cmtContent': ':如果很餓的確可以吃飽（還有炒飯、泡麵）吃品質的話，', 'cmtDate': '2021-03-29 17:30:00'}
# {'cmtStatus': '→', 'cmtPoster': 'dong08111', 'cmtContent': ':非常不推...而且非常重鹹...orz', 'cmtDate': '2021-03-29 17:31:00'}
# {'cmtStatus': '推', 'cmtPoster': 'JoyceTong', 'cmtContent': ':有單人限制嗎？', 'cmtDate': '2021-10-04 13:20:00'}
# {'cmtStatus': '推', 'cmtPoster': 'thudadai', 'cmtContent': ':推情報~只是這價格依之前去吃單點差不多也2000/人含10%', 'cmtDate': '2020-04-26 20:25:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Arutha', 'cmtContent': ':吃過4月版本，其實隨便吃吃算起來都超過2000/人，其實很划', 'cmtDate': '2020-04-27 04:47:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Arutha', 'cmtContent': ':算啦。而且還是3個人吃而已，其中兩位還老人家。', 'cmtDate': '2020-04-27 04:48:00'}
# {'cmtStatus': '推', 'cmtPoster': 'play90822', 'cmtContent': ':對食量大者很划算正常食量者不虧可是朋友都小鳥胃QQ', 'cmtDate': '2020-04-27 09:04:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Arutha', 'cmtContent': ':其實這方案優惠的點在湯品、主食煨麵和甜點部分都是幾個人', 'cmtDate': '2020-04-27 10:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Arutha', 'cmtContent': ':就給幾份。而這三類在單點菜單上單人份的價格都不便宜。', 'cmtDate': '2020-04-27 10:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Arutha', 'cmtContent': ':所以除非胃小到整個set都吃不完。不然選擇這優惠方案還是', 'cmtDate': '2020-04-27 10:31:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Arutha', 'cmtContent': ':比較划算。', 'cmtDate': '2020-04-27 10:31:00'}
# {'cmtStatus': '→', 'cmtPoster': 'NouTsan', 'cmtContent': ':我自已算了一下想吃的都點，整套下來加一成2400左右', 'cmtDate': '2020-04-27 12:28:00'}
# {'cmtStatus': '推', 'cmtPoster': 'sm0214', 'cmtContent': ':食量夠大才划算，或者份量都不多可吃較多樣，才有吸引力', 'cmtDate': '2020-04-27 21:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'chris7568', 'cmtContent': ':感覺499比較划算', 'cmtDate': '2020-02-12 10:48:00+00:00'}
# {'cmtStatus': '→', 'cmtPoster': 'gobby616', 'cmtContent': ':ya', 'cmtDate': '2022-02-03 21:16:00'}
# {'cmtStatus': '→', 'cmtPoster': 'rfdgrfdg', 'cmtContent': ':超級業', 'cmtDate': '2022-02-03 21:25:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Valerie18', 'cmtContent': ':好想吃', 'cmtDate': '2022-02-03 23:10:00'}
# {'cmtStatus': '→', 'cmtPoster': 'miyake702', 'cmtContent': ':吃完只對大骨有印象', 'cmtDate': '2022-02-03 23:21:00'}
# {'cmtStatus': '→', 'cmtPoster': 'winston06', 'cmtContent': ':這肉質叫頂級和牛霜降？要吃到飽不如去馬辣一千左右', 'cmtDate': '2022-02-03 23:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'winston06', 'cmtContent': ':價位我寧願去老四川', 'cmtDate': '2022-02-03 23:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'e04su3ao4', 'cmtContent': ':噓樓上老四川這價位根本吃不到什麼吧', 'cmtDate': '2022-02-04 03:12:00'}
# {'cmtStatus': '推', 'cmtPoster': 'babagaumi', 'cmtContent': ':好吃！過年前剛好有訂的位子', 'cmtDate': '2022-02-04 11:40:00'}
# {'cmtStatus': '→', 'cmtPoster': 'babagaumi', 'cmtContent': ':蝦子也很新鮮肉品質滿不錯的', 'cmtDate': '2022-02-04 11:41:00'}
# {'cmtStatus': '推', 'cmtPoster': 'oc4r', 'cmtContent': ':味道有夠濃嘔嘔嘔嘔嘔', 'cmtDate': '2022-02-05 13:55:00'}
# {'cmtStatus': '推', 'cmtPoster': 'billnina', 'cmtContent': ':昨天幸運訂到九點的位子，老實說真的不錯', 'cmtDate': '2022-02-06 15:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'billnina', 'cmtContent': ':麻辣鍋可以續豬大骨，大骨肉非常嫩，我吃了三根', 'cmtDate': '2022-02-06 15:52:00'}
# {'cmtStatus': '推', 'cmtPoster': 'billnina', 'cmtContent': ':熟成和牛的部分就還可，孜然的調味和牛好吃，印象比較', 'cmtDate': '2022-02-06 15:53:00'}
# {'cmtStatus': '推', 'cmtPoster': 'nctufish', 'cmtContent': ':他們家什麼都好吃，唯獨牛排例外XD', 'cmtDate': '2020-12-31 03:04:00'}
# {'cmtStatus': '→', 'cmtPoster': 'triccsegg', 'cmtContent': ':被牛排耽誤的美式餐廳嗎XD', 'cmtDate': '2021-01-02 13:56:00'}
# {'cmtStatus': '推', 'cmtPoster': 'pochidoggy66', 'cmtContent': ':馬辣或新馬辣吧，酒味不夠可以要求加酒（馥臨的鮮', 'cmtDate': '2022-10-20 10:18:46'}
# {'cmtStatus': '→', 'cmtPoster': 'pochidoggy66', 'cmtContent': ':蝦餛飩真心懷念）', 'cmtDate': '2022-10-20 10:18:46'}
# {'cmtStatus': '推', 'cmtPoster': 'lok6', 'cmtContent': ':也想問哪裡有好吃花雕雞', 'cmtDate': '2022-10-20 10:18:46'}
# {'cmtStatus': '推', 'cmtPoster': 'ja881213', 'cmtContent': ':神來一鍋？', 'cmtDate': '2022-10-20 10:18:46'}
# {'cmtStatus': '→', 'cmtPoster': 'aaabbbcccd', 'cmtContent': ':完了！', 'cmtDate': '2020-09-10 11:56:00'}
# {'cmtStatus': '→', 'cmtPoster': 'blexshiou', 'cmtContent': ':老實說，去過一次就不會想再去第二次了，牛排難吃，沙', 'cmtDate': '2020-09-10 21:36:00'}
# {'cmtStatus': '→', 'cmtPoster': 'blexshiou', 'cmtContent': ':拉吧都是家常菜，吃粗飽的，唯一特點是cp值高', 'cmtDate': '2020-09-10 21:36:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Sana', 'cmtContent': ':CP高就夠了,我家牛排的品質...就一般啊', 'cmtDate': '2020-09-11 10:44:00'}
# {'cmtStatus': '推', 'cmtPoster': 'shiraishi', 'cmtContent': ':雙十一K平台還有折扣碼TRAVEL95可以用', 'cmtDate': '2022-11-14 13:05:00'}
# {'cmtStatus': '推', 'cmtPoster': 'm0034022', 'cmtContent': ':可以來揪一波了四人比較划算', 'cmtDate': '2022-11-14 17:14:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kamen766', 'cmtContent': ':謝謝分享', 'cmtDate': '2022-11-14 18:32:00'}
# {'cmtStatus': '推', 'cmtPoster': 'EEloveyou', 'cmtContent': ':會很難訂嗎？', 'cmtDate': '2022-11-15 08:23:00'}
# {'cmtStatus': '推', 'cmtPoster': 'AlphaD', 'cmtContent': ':咖啡變難喝了,聽說去年底換豆子????', 'cmtDate': '2020-01-25 18:53:00+00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'larle', 'cmtContent': ':以肉為名的火鍋店有夠多的XDD', 'cmtDate': '2020-04-02 23:43:00'}
# {'cmtStatus': '→', 'cmtPoster': 'womandddd', 'cmtContent': ':哈哈，對啊，就是要大口吃肉啦！', 'cmtDate': '2020-04-02 23:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'vankhub', 'cmtContent': ':鴨血豆腐可以無限加', 'cmtDate': '2020-04-03 02:02:00'}
# {'cmtStatus': '→', 'cmtPoster': 'womandddd', 'cmtContent': ':點的時候店員沒有特別說><鴨血豆腐好吃', 'cmtDate': '2020-04-03 11:12:00'}
# {'cmtStatus': '推', 'cmtPoster': 'alstonfju', 'cmtContent': ':吃過一次但時間1.5小時實在有點趕', 'cmtDate': '2020-04-03 14:41:00'}
# {'cmtStatus': '→', 'cmtPoster': 'womandddd', 'cmtContent': ':我們應該是有超過1.5h，但沒客滿店員沒有趕，服務態度', 'cmtDate': '2020-04-03 16:09:00'}
# {'cmtStatus': '→', 'cmtPoster': 'womandddd', 'cmtContent': ':還不錯。', 'cmtDate': '2020-04-03 16:09:00'}
# {'cmtStatus': '推', 'cmtPoster': 'dodo11060', 'cmtContent': ':馬肉超級讚...', 'cmtDate': '2021-02-28 18:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'cindy81620', 'cmtContent': ':肉好誘人', 'cmtDate': '2021-03-02 10:37:00'}
# {'cmtStatus': '推', 'cmtPoster': 'calase', 'cmtContent': ':假日一個小時有點趕...', 'cmtDate': '2022-02-21 23:46:00'}
# {'cmtStatus': '推', 'cmtPoster': 'allenboy', 'cmtContent': ':一個人880加一成服務費，只能吃一小時？有點扯啊……', 'cmtDate': '2022-02-22 08:58:00'}
# {'cmtStatus': '→', 'cmtPoster': 'oc4r', 'cmtContent': ':看到什麼CNN推薦字眼就知道這篇文章味道有多濃了', 'cmtDate': '2022-02-22 09:06:00'}
# {'cmtStatus': '→', 'cmtPoster': 'oc4r', 'cmtContent': ':原文在哪都不知道店家說說部落客就照抄0.0', 'cmtDate': '2022-02-22 09:08:00'}
# {'cmtStatus': '推', 'cmtPoster': 'JoyceTong', 'cmtContent': ':用運通卡訂一晚3300附早餐不限時間', 'cmtDate': '2022-02-22 10:07:00'}
# {'cmtStatus': '→', 'cmtPoster': 'JoyceTong', 'cmtContent': ':880+10%我真的不知道有啥好去的', 'cmtDate': '2022-02-22 10:07:00'}
# {'cmtStatus': '→', 'cmtPoster': 'sodaparadise', 'cmtContent': ':去年10月底吃過一次蠻普通，很多都是現成的東西', 'cmtDate': '2022-02-22 19:30:00'}
# {'cmtStatus': '→', 'cmtPoster': 'sodaparadise', 'cmtContent': ':或加熱擺出來的，像是點心類、香腸類、冷盤台式小', 'cmtDate': '2022-02-22 19:30:00'}
# {'cmtStatus': '→', 'cmtPoster': 'sodaparadise', 'cmtContent': ':菜類、麵包檯大量小麵包乾癟乾癟吃起來口感不像當', 'cmtDate': '2022-02-22 19:30:00'}
# {'cmtStatus': '→', 'cmtPoster': 'sodaparadise', 'cmtContent': ':天現製', 'cmtDate': '2022-02-22 19:30:00'}
# {'cmtStatus': '→', 'cmtPoster': 'erty', 'cmtContent': ':看這描述就一般飯店早餐啊...', 'cmtDate': '2022-02-23 13:33:00'}
# {'cmtStatus': '→', 'cmtPoster': 'X120oops', 'cmtContent': ':又見殿系列', 'cmtDate': '2020-10-25 11:14:00'}
# {'cmtStatus': '→', 'cmtPoster': 'NouTsan', 'cmtContent': ':這間使用芥末椒鹽的頻率高到你吃到最後會起賭爛', 'cmtDate': '2020-10-26 00:36:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kenfan', 'cmtContent': ':想請問室內冷氣夠強嗎??之前去其他店都會吃到整身流汗', 'cmtDate': '2022-07-28 10:40:00'}
# {'cmtStatus': '推', 'cmtPoster': 'STARKUO', 'cmtContent': ':饗麻饗辣最早是在嘉義開的，不過嘉義店收起來了', 'cmtDate': '2023-03-08 21:02:00'}
# {'cmtStatus': '→', 'cmtPoster': 'FlynnZhang', 'cmtContent': ':國賓還有在營業嗎', 'cmtDate': '2023-03-08 21:04:00'}
# {'cmtStatus': '推', 'cmtPoster': 'top1429', 'cmtContent': ':推一個，聚餐的好地方', 'cmtDate': '2023-03-08 21:16:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Beckcloud', 'cmtContent': ':推一個~順便贈送一張3/10到期的100折價券安南區自取XD', 'cmtDate': '2023-03-08 21:24:00'}
# {'cmtStatus': '推', 'cmtPoster': 'hsx1002', 'cmtContent': ':是只有小橡樹才是服務人員幫忙挖嗎', 'cmtDate': '2023-03-08 21:36:00'}
# {'cmtStatus': '推', 'cmtPoster': 'sbuh0111', 'cmtContent': ':比麻辣風暴好多了，麻辣風暴一直改東西，越來越少炸得也', 'cmtDate': '2023-03-08 21:37:00'}
# {'cmtStatus': '→', 'cmtPoster': 'sbuh0111', 'cmtContent': ':不怎麼樣，真的去一次就不會再去', 'cmtDate': '2023-03-08 21:37:00'}
# {'cmtStatus': '噓', 'cmtPoster': 'a030220785', 'cmtContent': ':有空走過去後面，看看他們的環境你就會考慮一下了', 'cmtDate': '2023-03-08 21:43:00'}
# {'cmtStatus': '推', 'cmtPoster': 'jiern', 'cmtContent': ':對這家印象差會偷客人用餐時間8點半進入吃飯想說可以吃', 'cmtDate': '2023-03-08 21:46:00'}
# {'cmtStatus': '→', 'cmtPoster': 'jiern', 'cmtContent': ':到10點結果大約9點多海鮮區食材收的乾乾淨淨等於有一半', 'cmtDate': '2023-03-08 21:46:00'}
# {'cmtStatus': '→', 'cmtPoster': 'jiern', 'cmtContent': ':主力食材不見即然要這樣就別寫最後收客到9點或退些費用', 'cmtDate': '2023-03-08 21:46:00'}
# {'cmtStatus': '→', 'cmtPoster': 'jiern', 'cmtContent': ':給客人而不是用餐時間才一半就把主力食材移走一半', 'cmtDate': '2023-03-08 21:46:00'}
# {'cmtStatus': '推', 'cmtPoster': 'goodser456', 'cmtContent': ':普通，草莓季去的，草莓超小顆而且完全不會甜==', 'cmtDate': '2023-03-08 21:46:00'}
# {'cmtStatus': '→', 'cmtPoster': 'xffh', 'cmtContent': ':印象差+1螃蟹祭螃蟹肉爛到像泥訂五人給一桌一鍋沒下次', 'cmtDate': '2023-03-08 22:00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'biemelo157', 'cmtContent': ':謝謝精確座標，終於找到到這間店了', 'cmtDate': '2023-03-08 22:06:00'}
# {'cmtStatus': '噓', 'cmtPoster': 'jamze', 'cmtContent': ':噓店家完全是一次店4個人只有一鍋然後肉還要夾盤子', 'cmtDate': '2023-03-08 22:09:00'}
# {'cmtStatus': '→', 'cmtPoster': 'jamze', 'cmtContent': ':上超級慢印象中也只有蝦子比較新鮮其他的就...', 'cmtDate': '2023-03-08 22:10:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Ikvena', 'cmtContent': ':草莓季吃了兩次真的有的甜有的不甜所以我都會煉乳加爆', 'cmtDate': '2023-03-08 22:11:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Ikvena', 'cmtContent': ':0.0b', 'cmtDate': '2023-03-08 22:11:00'}
# {'cmtStatus': '推', 'cmtPoster': 'KarlMarx', 'cmtContent': ':草莓要每顆都甜很難吧....。', 'cmtDate': '2023-03-08 22:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yoyo15', 'cmtContent': ':看這篇突然懷念起永大路的勁辣旋風(應該是這店名)', 'cmtDate': '2023-03-08 22:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'xenon573', 'cmtContent': ':東西我覺得是好吃的、缺點就是人多時上肉真D慢', 'cmtDate': '2023-03-08 22:19:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kevinro66', 'cmtContent': ':同意樓上，星期六晚上人多的時候，肉半小時才出一盤，', 'cmtDate': '2023-03-08 22:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kevinro66', 'cmtContent': ':搞毛啊！', 'cmtDate': '2023-03-08 22:29:00'}
# {'cmtStatus': '推', 'cmtPoster': 'leo0227', 'cmtContent': ':去一次就不會再去了，之前家人懷孕去吃，地板濕答答差點', 'cmtDate': '2023-03-08 22:36:00'}
# {'cmtStatus': '→', 'cmtPoster': 'leo0227', 'cmtContent': ':滑倒，然後當天送的湯底又送錯，工作人員差點撞倒兒童椅', 'cmtDate': '2023-03-08 22:36:00'}
# {'cmtStatus': '→', 'cmtPoster': 'leo0227', 'cmtContent': ':，也沒說聲抱歉。', 'cmtDate': '2023-03-08 22:36:00'}
# {'cmtStatus': '推', 'cmtPoster': 'jeff1008', 'cmtContent': ':去過一次普普通通不會再去', 'cmtDate': '2023-03-08 22:39:00'}
# {'cmtStatus': '推', 'cmtPoster': 'brella', 'cmtContent': ':永華店還不錯', 'cmtDate': '2023-03-08 22:46:00'}
# {'cmtStatus': '噓', 'cmtPoster': 'TIMPIGTIM', 'cmtContent': ':我也覺得這間服務上很差永華店體驗好很多', 'cmtDate': '2023-03-08 22:47:00'}
# {'cmtStatus': '→', 'cmtPoster': 'hgddr6881686', 'cmtContent': ':完全不推', 'cmtDate': '2023-03-08 23:08:00'}
# {'cmtStatus': '→', 'cmtPoster': 'leonian', 'cmtContent': ':吃過一次，覺得東西都蠻粗的，不會再去+1', 'cmtDate': '2023-03-08 23:25:00'}
# {'cmtStatus': '推', 'cmtPoster': 'zzz50126', 'cmtContent': ':吃過2次永華一次國賓國賓那次肉比較差', 'cmtDate': '2023-03-08 23:36:00'}
# {'cmtStatus': '推', 'cmtPoster': 'TsaiPoki', 'cmtContent': ':覺得甜點好吃其他普', 'cmtDate': '2023-03-08 23:46:00'}
# {'cmtStatus': '推', 'cmtPoster': 'zeroyaking', 'cmtContent': ':公司聚餐吃過一次....錢還是省下來好了', 'cmtDate': '2023-03-08 23:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'parislove3', 'cmtContent': ':還記得2013有吃過永康店位子安排在門口手肘會被電動', 'cmtDate': '2023-03-08 23:53:00'}
# {'cmtStatus': '→', 'cmtPoster': 'parislove3', 'cmtContent': ':門打到室內有蚊子還拿到過期的包裝火鍋料不知這幾', 'cmtDate': '2023-03-08 23:54:00'}
# {'cmtStatus': '→', 'cmtPoster': 'parislove3', 'cmtContent': ':年有無改善', 'cmtDate': '2023-03-08 23:54:00'}
# {'cmtStatus': '推', 'cmtPoster': 'stupid52020', 'cmtContent': ':真的沒很好吃', 'cmtDate': '2023-03-08 23:59:00'}
# {'cmtStatus': '推', 'cmtPoster': 'atien666', 'cmtContent': ':4人一鍋不是正常嗎', 'cmtDate': '2023-03-09 00:10:00'}
# {'cmtStatus': '推', 'cmtPoster': 'duoooo24', 'cmtContent': ':以前還沒有名時，cp值超高，現在出名了，裝潢華麗了，', 'cmtDate': '2023-03-09 00:12:00'}
# {'cmtStatus': '→', 'cmtPoster': 'duoooo24', 'cmtContent': ':東西越來越難吃了', 'cmtDate': '2023-03-09 00:12:00'}
# {'cmtStatus': '推', 'cmtPoster': 'clamplove', 'cmtContent': ':可惜沒有鮮蚵', 'cmtDate': '2023-03-09 00:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'womf', 'cmtContent': ':東西不錯吃但絕對不想人多的時間去肉片現切等到天荒地老', 'cmtDate': '2023-03-09 00:55:00'}
# {'cmtStatus': '推', 'cmtPoster': 'lun1110', 'cmtContent': ':鍋子太淺而且沒鴛鴦鍋...新馬辣我四人吃是兩人一鍋', 'cmtDate': '2023-03-09 01:13:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ladoris', 'cmtContent': ':看了推文，麻辣鍋愛好者我還是繼續吃老常在好惹', 'cmtDate': '2023-03-09 01:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'nanako', 'cmtContent': ':會偷用餐時間＋1，時間還沒到，海鮮跟冰淇淋都收光光，印', 'cmtDate': '2023-03-09 02:43:00'}
# {'cmtStatus': '→', 'cmtPoster': 'nanako', 'cmtContent': ':象很差，建議要去吃的不要訂第二輪的時間', 'cmtDate': '2023-03-09 02:43:00'}
# {'cmtStatus': '推', 'cmtPoster': 'hdotistyle', 'cmtContent': ':完全一次店我還是去隔壁南紡吃新馬辣好了', 'cmtDate': '2023-03-09 03:37:00'}
# {'cmtStatus': '推', 'cmtPoster': 'k5a', 'cmtContent': ':偷用餐時間這點怎麼在很多食記看過好幾次了...這樣不行吧', 'cmtDate': '2023-03-09 04:45:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Sofast', 'cmtContent': ':上次去還不錯', 'cmtDate': '2023-03-09 06:36:00'}
# {'cmtStatus': '推', 'cmtPoster': 'abcdegg', 'cmtContent': ':認真覺得普通沒有什麼特別吸引力肉真的普普', 'cmtDate': '2023-03-09 07:45:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Memento202', 'cmtContent': ':店家不行的地方可以評論，但說沒鴛鴦鍋的有沒有先去吃', 'cmtDate': '2023-03-09 08:05:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Memento202', 'cmtContent': ':過再來嫌啊，笑死', 'cmtDate': '2023-03-09 08:05:00'}
# {'cmtStatus': '推', 'cmtPoster': 'lee108112', 'cmtContent': ':看過阿強在食材附近散步口味一次店', 'cmtDate': '2023-03-09 08:29:00'}
# {'cmtStatus': '噓', 'cmtPoster': 'Alphaplus', 'cmtContent': ':環境太雜亂，放食物的地方都濕濕水水的', 'cmtDate': '2023-03-09 08:39:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Alphaplus', 'cmtContent': ':新馬辣大勝，雖然價格高一個等級，但不差那兩三百', 'cmtDate': '2023-03-09 08:39:00'}
# {'cmtStatus': '推', 'cmtPoster': 'xSAUCEx', 'cmtContent': ':真的愈來愈難吃剛開時去小店吃過覺得物超所', 'cmtDate': '2023-03-09 09:16:00'}
# {'cmtStatus': '→', 'cmtPoster': 'xSAUCEx', 'cmtContent': ':值後來愈開愈大間只剩裝潢ok東西難吃', 'cmtDate': '2023-03-09 09:16:00'}
# {'cmtStatus': '噓', 'cmtPoster': 'GGINDOWBOW', 'cmtContent': ':口味還行但是會偷時間不然就是補料速率慢到讓人覺得', 'cmtDate': '2023-03-09 09:26:00'}
# {'cmtStatus': '→', 'cmtPoster': 'GGINDOWBOW', 'cmtContent': ':是故意的很沒誠意', 'cmtDate': '2023-03-09 09:26:00'}
# {'cmtStatus': '推', 'cmtPoster': 'saladp', 'cmtContent': ':去過永華店是四大一小給兩個鴛鴦鍋', 'cmtDate': '2023-03-09 11:31:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ayazard', 'cmtContent': ':感謝滅火,新馬辣吃太多次後本想換家吃看看', 'cmtDate': '2023-03-09 11:54:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kugyumayu', 'cmtContent': ':嫌的要死用餐時間還是九成至客滿', 'cmtDate': '2023-03-09 12:25:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kugyumayu', 'cmtContent': ':不知道這價位的吃到飽麻辣鍋有哪間能打？', 'cmtDate': '2023-03-09 12:25:00'}
# {'cmtStatus': '推', 'cmtPoster': 'QS531', 'cmtContent': ':CP值高的就是XM跟寶吧', 'cmtDate': '2023-03-09 12:30:00'}
# {'cmtStatus': '→', 'cmtPoster': 'inging841009', 'cmtContent': ':我覺得原店CP值較高', 'cmtDate': '2023-03-09 13:45:00'}
# {'cmtStatus': '推', 'cmtPoster': 'jiern', 'cmtContent': ':能不能打不知道反正我不會上門光顧連用餐時間也在偷誰', 'cmtDate': '2023-03-09 13:49:00'}
# {'cmtStatus': '→', 'cmtPoster': 'jiern', 'cmtContent': ':知道看不到的廚房有什麼還會偷', 'cmtDate': '2023-03-09 13:49:00'}
# {'cmtStatus': '→', 'cmtPoster': 'jiern', 'cmtContent': ':如果當年XM不去搞意大利麵不去德安搞百貨店舖搞港式飲茶', 'cmtDate': '2023-03-09 13:53:00'}
# {'cmtStatus': '→', 'cmtPoster': 'jiern', 'cmtContent': ':專心做麻辣鍋的街邊店如今台南市場一定仍是XM稱霸專注', 'cmtDate': '2023-03-09 13:53:00'}
# {'cmtStatus': '→', 'cmtPoster': 'jiern', 'cmtContent': ':做好本業比什麼都重要', 'cmtDate': '2023-03-09 13:53:00'}
# {'cmtStatus': '推', 'cmtPoster': 'smalldora', 'cmtContent': ':這個價位來說台南只剩新馬辣能比了', 'cmtDate': '2023-03-09 14:13:00'}
# {'cmtStatus': '推', 'cmtPoster': 'grandzxcv', 'cmtContent': ':XM林森店真可惜，大學生客群很大的', 'cmtDate': '2023-03-09 16:07:00'}
# {'cmtStatus': '推', 'cmtPoster': 'HeavyBlue', 'cmtContent': ':推文自己小心...老闆會看PTT', 'cmtDate': '2023-03-09 17:04:00'}
# {'cmtStatus': '推', 'cmtPoster': 'hdotistyle', 'cmtContent': ':多加個2300吃新馬辣不香嗎還不用自己拿食材', 'cmtDate': '2023-03-09 18:36:00'}
# {'cmtStatus': '推', 'cmtPoster': 'jiern', 'cmtContent': ':看就看自己店內做法被人質疑有問題又不是講非事實的事', 'cmtDate': '2023-03-09 18:49:00'}
# {'cmtStatus': '→', 'cmtPoster': 'jiern', 'cmtContent': ':還是不想解決問題只想解決提出問題的人？', 'cmtDate': '2023-03-09 18:49:00'}
# {'cmtStatus': '噓', 'cmtPoster': 'Elvis1991', 'cmtContent': ':這饗麻服務真的不怎麼好', 'cmtDate': '2023-03-09 19:00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'lun1110', 'cmtContent': ':鍋子我記去「了熟鍋」，響麻有鴛鴦鍋但我覺得太淺了', 'cmtDate': '2023-03-09 22:19:00'}
# {'cmtStatus': '→', 'cmtPoster': 'lun1110', 'cmtContent': ':前陣子吃太多火鍋有點混亂，但新馬辣我覺得要用自己手機', 'cmtDate': '2023-03-09 22:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'lun1110', 'cmtContent': ':好麻煩', 'cmtDate': '2023-03-09 22:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'lun1110', 'cmtContent': ':點餐比較喜歡小蒙牛，但品項是新馬辣贏，價格也較高', 'cmtDate': '2023-03-09 22:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'lun1110', 'cmtContent': ':而且新馬辣是牛肉咖喱飯！', 'cmtDate': '2023-03-09 22:23:00'}
# {'cmtStatus': '推', 'cmtPoster': 'lun1110', 'cmtContent': ':沒有鴛鴦鍋的是「熟鍋」，在此修正下，別再說我沒吃過了Q', 'cmtDate': '2023-03-09 22:37:00'}
# {'cmtStatus': '→', 'cmtPoster': 'lun1110', 'cmtContent': ':Q', 'cmtDate': '2023-03-09 22:37:00'}
# {'cmtStatus': '推', 'cmtPoster': 'lun1110', 'cmtContent': ':再請開版幫我刪除沒鴛鴦鍋那個留言，麻煩了謝謝', 'cmtDate': '2023-03-09 23:08:00'}
# {'cmtStatus': '推', 'cmtPoster': 'envy116', 'cmtContent': ':永華店比較好，國賓的動線有點差，尤其是熟食區後的內用', 'cmtDate': '2023-03-10 07:02:00'}
# {'cmtStatus': '→', 'cmtPoster': 'envy116', 'cmtContent': ':區，有夠擠的', 'cmtDate': '2023-03-10 07:02:00'}
# {'cmtStatus': '→', 'cmtPoster': 'parislove3', 'cmtContent': ':不知道kugyumayu在扯什麼人多客滿又度代表真的很好', 'cmtDate': '2023-03-10 13:10:00'}
# {'cmtStatus': '推', 'cmtPoster': 'qize1428', 'cmtContent': ':新馬辣>all', 'cmtDate': '2023-03-10 21:28:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Z31', 'cmtContent': ':新馬辣真的一次店第三輪肉質和前面的不一樣極度不推', 'cmtDate': '2023-04-07 22:07:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Z31', 'cmtContent': ':推薦饗宴或是饗麻饗辣都不錯近期吃很推薦單點推薦牛園火鍋', 'cmtDate': '2023-04-07 22:08:00'}
# {'cmtStatus': '推', 'cmtPoster': 'jericho1026', 'cmtContent': ':食材種類滿多的，甜點也好吃，以這價位算不錯了', 'cmtDate': '2023-04-09 15:16:00'}
# {'cmtStatus': '→', 'cmtPoster': 'zyc5566', 'cmtContent': ':這家我認真覺得還好', 'cmtDate': '2022-06-15 19:42:00'}
# {'cmtStatus': '→', 'cmtPoster': 'wowbox', 'cmtContent': ':這價位不輸台北了', 'cmtDate': '2020-08-09 16:05:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ulter', 'cmtContent': ':光看內容跟戰醬幾乎一模一樣', 'cmtDate': '2022-03-27 20:28:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ulter', 'cmtContent': ':不過戰將沒哈根XD', 'cmtDate': '2022-03-27 20:31:00'}
# {'cmtStatus': '推', 'cmtPoster': 'leptoneta', 'cmtContent': ':很抱歉，您所查詢的網誌頁面不存在。', 'cmtDate': '2022-11-14 23:09:59'}
# {'cmtStatus': '→', 'cmtPoster': 'nikcoke', 'cmtContent': ':已修正,感謝告知', 'cmtDate': '2022-11-15 21:15:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ALENDA', 'cmtContent': ':如果是業配該註明吧', 'cmtDate': '2020-10-08 12:14:00'}
# {'cmtStatus': '→', 'cmtPoster': 'chickenbo', 'cmtContent': ':我自己付錢的', 'cmtDate': '2020-10-08 18:43:00'}
# {'cmtStatus': '推', 'cmtPoster': 'pilimovies', 'cmtContent': ':推分享難得有不業配的食記好險我窮人家只能吃考狀猿', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '→', 'cmtPoster': 'pilimovies', 'cmtContent': ':跟色鼎體驗都還不錯XD', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'mazda6666', 'cmtContent': ':感謝你的心得….不用去踩雷了！', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'papabearche', 'cmtContent': ':上次去出餐時間沒有這麼短，感覺你的狀況是員工在趕', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '→', 'cmtPoster': 'papabearche', 'cmtContent': ':下班？', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'SamWhite', 'cmtContent': ':推分享', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'u100047', 'cmtContent': ':我上次去吃還吃到蛋殼跟斗六比差太多了', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'pphh', 'cmtContent': ':這家我也覺得不太行', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'aqlec', 'cmtContent': ':一直想去吃，感謝滅火', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'tra12009', 'cmtContent': ':感謝分享，以後就知道不用去了', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'er38933', 'cmtContent': ':花這麼多，結果吃的比夜市的蒙古烤肉還急...', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'topaaron12', 'cmtContent': ':謝謝分享還是台中的風間跟老井好吃', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'movieghost', 'cmtContent': ':感謝滅火還是去烤狀猿自己慢慢烤就好', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'ccsashin', 'cmtContent': ':剛開店的時候很好吃的，食材好不好吃要看服務人員會不會', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '→', 'cmtPoster': 'ccsashin', 'cmtContent': ':烤，真的有差', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '→', 'cmtPoster': 'adai69', 'cmtContent': ':@papabearche結帳時有反應給主管，他說應該不是趕下班，', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '→', 'cmtPoster': 'adai69', 'cmtContent': ':他們不是兩點就下班，不過我們在快吃完時候吧檯區員工都', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '→', 'cmtPoster': 'adai69', 'cmtContent': ':在收拾了，用起餐來真的有莫名壓力-.-', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'usea5a', 'cmtContent': ':感謝分享', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'willow', 'cmtContent': ':好幾年前去過體驗還不錯的說看來走下坡了', 'cmtDate': '2022-02-23 17:13:14'}
# {'cmtStatus': '推', 'cmtPoster': 'qw8800333', 'cmtContent': ':請問這家現在有刷卡功能了嗎？開幕後幾個月去吃了六千', 'cmtDate': '2022-02-23 19:43:00'}
# {'cmtStatus': '→', 'cmtPoster': 'qw8800333', 'cmtContent': ':多竟然只收現金', 'cmtDate': '2022-02-23 19:43:00'}
# {'cmtStatus': '推', 'cmtPoster': 'whhw', 'cmtContent': ':推', 'cmtDate': '2022-02-23 19:56:00'}
# {'cmtStatus': '→', 'cmtPoster': 'adai69', 'cmtContent': ':@qw8800333一樣還是沒有刷卡，我也是結帳時才知道，還在', 'cmtDate': '2022-02-23 19:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'adai69', 'cmtContent': ':濕冷天氣去對面全聯領錢，冷支支。不過這是我沒先問清楚', 'cmtDate': '2022-02-23 19:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'adai69', 'cmtContent': ':又帶不夠錢的關係，比較不方便而已XD', 'cmtDate': '2022-02-23 19:59:00'}
# {'cmtStatus': '推', 'cmtPoster': 'zxc89003', 'cmtContent': ':感謝分享', 'cmtDate': '2022-02-23 20:18:00'}
# {'cmtStatus': '→', 'cmtPoster': 'penfan', 'cmtContent': ':員林常有不知道在貴啥意思的餐廳', 'cmtDate': '2022-02-23 22:06:00'}
# {'cmtStatus': '推', 'cmtPoster': 'lanjack', 'cmtContent': ':我個人認為，如果一家有提供米飯的餐廳或餐館，卻連最基', 'cmtDate': '2022-02-23 22:21:00'}
# {'cmtStatus': '→', 'cmtPoster': 'lanjack', 'cmtContent': ':本的飯都煮不好，那麼跟我說它其他店內的商品有多好吃我', 'cmtDate': '2022-02-23 22:21:00'}
# {'cmtStatus': '→', 'cmtPoster': 'lanjack', 'cmtContent': ':打死都不信…飯煮到都黏塊也太雷了吧…', 'cmtDate': '2022-02-23 22:21:00'}
# {'cmtStatus': '推', 'cmtPoster': 'chiauuuia', 'cmtContent': ':好扯', 'cmtDate': '2022-02-23 22:43:00'}
# {'cmtStatus': '推', 'cmtPoster': 'leathercraft', 'cmtContent': ':吃過一次，付現無刷卡，不會想再去；吃到會膩。', 'cmtDate': '2022-02-23 23:57:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kent00216', 'cmtContent': ':半小時？？？', 'cmtDate': '2022-02-24 00:08:00'}
# {'cmtStatus': '推', 'cmtPoster': 'asister06', 'cmtContent': ':欸，還沒倒喔', 'cmtDate': '2022-02-24 00:10:00'}
# {'cmtStatus': '推', 'cmtPoster': 'flymomo2001', 'cmtContent': ':我也是，吃到黏飯很倒彈', 'cmtDate': '2022-02-24 01:14:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kissung', 'cmtContent': ':推分享', 'cmtDate': '2022-02-24 06:09:00'}
# {'cmtStatus': '推', 'cmtPoster': 'wuuman', 'cmtContent': ':這價格…彰化人真的是隱形富豪', 'cmtDate': '2022-02-24 07:57:00'}
# {'cmtStatus': '推', 'cmtPoster': 'fatetree', 'cmtContent': ':人口紅利比不上台中價位倒是跟上了所以我幾年前開始', 'cmtDate': '2022-02-24 08:32:00'}
# {'cmtStatus': '推', 'cmtPoster': 'fatetree', 'cmtContent': ':就打死不在彰化吃非連鎖的高價位的餐廳了', 'cmtDate': '2022-02-24 08:34:00'}
# {'cmtStatus': '推', 'cmtPoster': 'fatetree', 'cmtContent': ':慘欸剛剛谷歌才知道是連鎖店的', 'cmtDate': '2022-02-24 08:38:00'}
# {'cmtStatus': '→', 'cmtPoster': 'fatetree', 'cmtContent': ':看來只剩大型的連鎖的西堤跟石二鍋才不雷了XD', 'cmtDate': '2022-02-24 08:38:00'}
# {'cmtStatus': '推', 'cmtPoster': 'c2578910', 'cmtContent': ':半小時？有夠誇張XDD', 'cmtDate': '2022-02-25 01:49:00'}
# {'cmtStatus': '→', 'cmtPoster': 'anada1217', 'cmtContent': ':這叫服務態度不佳?台灣的餐飲服務業真難做....', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '→', 'cmtPoster': 'anada1217', 'cmtContent': ':這種高貴的客人不適合吃平價的牛排和服務', 'cmtDate': '2020-11-05 08:37:00'}
# {'cmtStatus': '推', 'cmtPoster': 'hcarly', 'cmtContent': ':平價牛排才更不會把客人放在盤子裏的衛生紙挑出來放桌上吧', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '推', 'cmtPoster': 'callTM', 'cmtContent': ':用過衛生紙擺桌上是蠻神奇的', 'cmtDate': '2020-11-06 04:30:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mizuki', 'cmtContent': ':沒問要不要兒童座椅自己提不就好了', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '→', 'cmtPoster': 'mrq089', 'cmtContent': ':要兒童椅不會主動講還要人家問？', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '推', 'cmtPoster': 'parappa', 'cmtContent': ':赤鬼超推薦的，有的客人只適合吃王品系列吧！', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '→', 'cmtPoster': 'capazek', 'cmtContent': ':不覺得赤鬼這服務有啥問題耶', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '→', 'cmtPoster': 'godgod777', 'cmtContent': ':員工冷漠、兇狠、彪悍，像兄弟牛排館', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '→', 'cmtPoster': 'godgod777', 'cmtContent': ':覺得能把章魚燒賣到上太空的老闆一定是個狠角色', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '推', 'cmtPoster': 'tearness', 'cmtContent': ':辣媽的圖咧!啊這裡不是八卦版', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '→', 'cmtPoster': 'godgod777', 'cmtContent': ':我不想被做成消波塊，自己去金錢豹門口守株待兔', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '推', 'cmtPoster': 'ImKSW', 'cmtContent': ':很多早餐店都是好吃便宜態度也好', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '→', 'cmtPoster': 'ImKSW', 'cmtContent': ':還會叫肥宅帥哥，根本佛心', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '→', 'cmtPoster': 'godgod777', 'cmtContent': ':客人少才有時間跟你服務好，客人多忙到懶得理你', 'cmtDate': '2020-04-29 20:38:00'}
# {'cmtStatus': '→', 'cmtPoster': 'godgod777', 'cmtContent': ':人多太累就以價制量，人少太閒就只能薄利多銷', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '→', 'cmtPoster': 'godgod777', 'cmtContent': ':我是肥宅也是帥哥', 'cmtDate': '2020-04-29 11:17:11'}
# {'cmtStatus': '→', 'cmtPoster': 'BUE', 'cmtContent': ':錯字可以多校稿一下啦，然後不知道為什麼，台灣很多店家都要', 'cmtDate': '2022-08-16 12:38:00'}
# {'cmtStatus': '→', 'cmtPoster': 'BUE', 'cmtContent': ':放很吵或低音很重的音樂，吃起來其實很不舒服，講話都要用吼', 'cmtDate': '2022-08-16 12:38:00'}
# {'cmtStatus': '→', 'cmtPoster': 'BUE', 'cmtContent': ':辛殿的音樂讓我用餐時會覺得很吵，壓迫感很重', 'cmtDate': '2022-08-16 12:40:00'}
# {'cmtStatus': '→', 'cmtPoster': 'BUE', 'cmtContent': ':既然都有限時間了，不能讓客人好好吃飯嗎？QQ', 'cmtDate': '2022-08-16 12:41:00'}
# {'cmtStatus': '推', 'cmtPoster': 'olin7745', 'cmtContent': ':可能是不想讓大家聊天，邊聊邊吃再來吵有限時吃不飽', 'cmtDate': '2022-08-16 13:11:00'}
# {'cmtStatus': '推', 'cmtPoster': 'howard1997', 'cmtContent': ':雞頸肉是牛角的本體其他都普普', 'cmtDate': '2020-02-28 02:35:00'}
# {'cmtStatus': '推', 'cmtPoster': 'deepsnow2015', 'cmtContent': ':沒有檸檬汁之後我對牛角的愛已經少了一半QAQ', 'cmtDate': '2020-02-28 09:16:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mangomuachee', 'cmtContent': ':感謝踩雷～', 'cmtDate': '2020-01-27 01:20:00+00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'thudadai', 'cmtContent': ':XD', 'cmtDate': '2020-01-27 10:31:00+00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'MaribelHearn', 'cmtContent': ':感謝食記', 'cmtDate': '2020-01-28 09:47:00+00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Trter', 'cmtContent': ':現在大家都很愛搞肉多這招耶~~', 'cmtDate': '2020-09-14 19:40:00'}
# {'cmtStatus': '→', 'cmtPoster': 'uni3012', 'cmtContent': ':但我覺得他們家海鮮比較厲害耶，有被海鮮嚇到', 'cmtDate': '2020-09-15 21:58:00'}
# {'cmtStatus': '推', 'cmtPoster': 'trollwitch', 'cmtContent': ':美食搭配背後故事，很吸引人', 'cmtDate': '2020-05-22 20:31:00'}
# {'cmtStatus': '→', 'cmtPoster': 'pochidoggy66', 'cmtContent': ':這肉量算很貴吧....牛肋條好市多一公斤也才四百多', 'cmtDate': '2021-01-13 17:27:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ImKSW', 'cmtContent': ':這種店確實都不便宜', 'cmtDate': '2021-01-14 08:09:00'}
# {'cmtStatus': '→', 'cmtPoster': 'brian21201', 'cmtContent': ':Yupoke屌打', 'cmtDate': '2022-04-05 14:40:00'}
# {'cmtStatus': '推', 'cmtPoster': 'peter2300807', 'cmtContent': ':YUPOKE比較好吃！！別跑錯了', 'cmtDate': '2022-04-06 06:40:00'}
# {'cmtStatus': '→', 'cmtPoster': 'KUNI0202', 'cmtContent': ':真心討厭裡頭一堆廣告然後又一堆資訊不足的網址圖文版。', 'cmtDate': '2022-04-06 09:35:00'}
# {'cmtStatus': '推', 'cmtPoster': 'amy6272000', 'cmtContent': ':我今天跟我男友去吃，他也說這肉片薄到下去三秒就熟', 'cmtDate': '2022-10-10 23:26:00'}
# {'cmtStatus': '→', 'cmtPoster': 'amy6272000', 'cmtContent': ':了', 'cmtDate': '2022-10-10 23:27:00'}
# {'cmtStatus': '→', 'cmtPoster': 'amy6272000', 'cmtContent': ':肉片是真的有點傻眼，但菜跟冰淇淋真的不錯', 'cmtDate': '2022-10-10 23:28:00'}
# {'cmtStatus': '→', 'cmtPoster': 'amy6272000', 'cmtContent': ':嫩雞柳我推鐵了心～好吃服務也好！', 'cmtDate': '2022-10-10 23:28:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yakifone', 'cmtContent': ':這家生意越來越好！！', 'cmtDate': '2020-07-29 22:43:00'}
# {'cmtStatus': '推', 'cmtPoster': 'oijkue', 'cmtContent': ':慘,這種價位還這麼鳥', 'cmtDate': '2021-09-14 20:29:00'}
# {'cmtStatus': '推', 'cmtPoster': 'cool10528', 'cmtContent': ':吃過一次，就那一次了。', 'cmtDate': '2021-09-15 04:04:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yakifone', 'cmtContent': ':超快！！第一報', 'cmtDate': '2021-12-03 18:22:00'}
# {'cmtStatus': '推', 'cmtPoster': 'sa13961387', 'cmtContent': ':推', 'cmtDate': '2021-12-03 20:09:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ripplee', 'cmtContent': ':推', 'cmtDate': '2021-12-04 07:56:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kintboos', 'cmtContent': ':有時很好奇這種是真干貝嗎?感覺每顆大小都一模一樣', 'cmtDate': '2021-09-16 19:58:50'}
# {'cmtStatus': '→', 'cmtPoster': 'jim12441', 'cmtContent': ':那種聚合干貝不如不要吃', 'cmtDate': '2021-09-16 19:58:50'}
# {'cmtStatus': '推', 'cmtPoster': 'aaakiyohara', 'cmtContent': ':這間只有生日當天買一送一才會去', 'cmtDate': '2021-09-17 20:52:00'}
# {'cmtStatus': '→', 'cmtPoster': 'tingbaby0920', 'cmtContent': ':大墩路上的咚豬咚豬，除了火鍋還有燒烤還有很多自助', 'cmtDate': '2021-11-09 23:03:00'}
# {'cmtStatus': '→', 'cmtPoster': 'tingbaby0920', 'cmtContent': ':吧。價錢也很划算', 'cmtDate': '2021-11-09 23:03:00'}
# {'cmtStatus': '推', 'cmtPoster': 'embrace0902', 'cmtContent': ':吃過1、3、4、5同事很愛青花椒我是覺得還好詹記', 'cmtDate': '2022-09-28 13:09:00'}
# {'cmtStatus': '→', 'cmtPoster': 'embrace0902', 'cmtContent': ':的鴨血最優秀蛋餃好吃其他的鴨血都普', 'cmtDate': '2022-09-28 13:09:00'}
# {'cmtStatus': '→', 'cmtPoster': 'embrace0902', 'cmtContent': ':普通沒什麼紀憶點', 'cmtDate': '2022-09-28 13:10:00'}
# {'cmtStatus': '→', 'cmtPoster': 'pz5202', 'cmtContent': ':青花椒+1', 'cmtDate': '2022-09-28 13:16:00'}
# {'cmtStatus': '推', 'cmtPoster': 'chaswind', 'cmtContent': ':吃過1.4.5最喜歡詹記，蛋餃好吃，肉也不錯', 'cmtDate': '2022-09-28 13:28:00'}
# {'cmtStatus': '推', 'cmtPoster': 'feedmesalad', 'cmtContent': ':唯一支持詹記大辣，十人可以坐包廂', 'cmtDate': '2022-09-28 13:45:00'}
# {'cmtStatus': '推', 'cmtPoster': 'despair78214', 'cmtContent': ':詹記不解釋', 'cmtDate': '2022-09-28 16:57:00'}
# {'cmtStatus': '推', 'cmtPoster': 'alicefang199', 'cmtContent': ':想推薦名單外的八條老宅剛好就在中山區', 'cmtDate': '2022-09-28 17:25:00'}
# {'cmtStatus': '推', 'cmtPoster': 'TCBGA', 'cmtContent': ':推八條老宅', 'cmtDate': '2022-09-28 18:06:00'}
# {'cmtStatus': '推', 'cmtPoster': 'popularyulin', 'cmtContent': ':你愛花椒嗎?我青花驕都請他給我很多辣醬跟花椒爽', 'cmtDate': '2022-09-28 19:04:00'}
# {'cmtStatus': '推', 'cmtPoster': 'hatasun', 'cmtContent': ':名單全都吃過～八條老宅可插進前兩名', 'cmtDate': '2022-09-28 21:11:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yukasakurai', 'cmtContent': ':青花轎推一個！詹記愛吃辣的不行', 'cmtDate': '2022-09-28 23:20:00'}
# {'cmtStatus': '→', 'cmtPoster': 'KUNI0202', 'cmtContent': ':這幾年吃過最優大概是兩家，八條老宅，湯頭不俗，厲害，', 'cmtDate': '2022-09-28 23:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'KUNI0202', 'cmtContent': ':價位稍高，但我覺得很值。', 'cmtDate': '2022-09-28 23:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'KUNI0202', 'cmtContent': ':另一家則是多年愛店，藍記。', 'cmtDate': '2022-09-28 23:46:00'}
# {'cmtStatus': '→', 'cmtPoster': 'KUNI0202', 'cmtContent': ':湯頭辣中帶麻，又香，很有味道。', 'cmtDate': '2022-09-28 23:50:00'}
# {'cmtStatus': '推', 'cmtPoster': 'circleee', 'cmtContent': ':八條老宅推，但鍋底不是吃到飽', 'cmtDate': '2022-09-29 02:38:00'}
# {'cmtStatus': '→', 'cmtPoster': 'r1t1r', 'cmtContent': ':八條應該超出你這預算不少..', 'cmtDate': '2022-09-29 10:39:00'}
# {'cmtStatus': '推', 'cmtPoster': 'dragonashco', 'cmtContent': ':這預算只推詹記', 'cmtDate': '2022-09-29 14:44:00'}
# {'cmtStatus': '推', 'cmtPoster': 'embrace0902', 'cmtContent': ':喔，八條老宅也滿好吃的沒錯', 'cmtDate': '2022-09-30 01:03:00'}
# {'cmtStatus': '推', 'cmtPoster': 'pinkwl6', 'cmtContent': ':八條老宅真的贏過內文五間^^”不好意思沒針對問題回', 'cmtDate': '2022-09-30 10:39:00'}
# {'cmtStatus': '→', 'cmtPoster': 'pinkwl6', 'cmtContent': ':覆哈哈', 'cmtDate': '2022-09-30 10:39:00'}
# {'cmtStatus': '→', 'cmtPoster': 'BigbirdUU', 'cmtContent': ':挖推推', 'cmtDate': '2022-09-30 13:20:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Rakoko', 'cmtContent': ':很棒推', 'cmtDate': '2022-09-30 13:32:00'}
# {'cmtStatus': '→', 'cmtPoster': 'smx82625', 'cmtContent': ':八條老宅有夠難吃的......吃老撈好嗎', 'cmtDate': '2022-10-01 11:39:00'}
# {'cmtStatus': '推', 'cmtPoster': 'nicen', 'cmtContent': ':東華川府很好吃唷！只是有點慢', 'cmtDate': '2022-10-01 19:28:00'}
# {'cmtStatus': '推', 'cmtPoster': 'piglin', 'cmtContent': ':這家好吃喔，蠻推薦的，青菜無限供應，而且都是有機的', 'cmtDate': '2020-10-05 14:11:00'}
# {'cmtStatus': '推', 'cmtPoster': 'bomber7382', 'cmtContent': ':推詳細，有牛脆胸蠻吸引的', 'cmtDate': '2022-09-13 10:34:00'}
# {'cmtStatus': '推', 'cmtPoster': 'PanaS0Nic', 'cmtContent': ':雖然講了很多，但看總結好像沒有很推啊XD', 'cmtDate': '2022-09-13 10:36:00'}
# {'cmtStatus': '→', 'cmtPoster': 'weiike', 'cmtContent': ':看你在不在意cp值吧', 'cmtDate': '2022-09-13 15:01:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yungju', 'cmtContent': ':不太懂為什麼訂17:20會損失一小時?', 'cmtDate': '2022-09-13 16:48:00'}
# {'cmtStatus': '→', 'cmtPoster': 'jean040532', 'cmtContent': ':請假了！結果沒什麼人，根本不用請假QAQ!', 'cmtDate': '2022-09-13 17:01:00'}
# {'cmtStatus': '→', 'cmtPoster': 'alan3100', 'cmtContent': ':就不差但沒到會跑大老遠必吃的店', 'cmtDate': '2022-09-13 19:32:00'}
# {'cmtStatus': '推', 'cmtPoster': 'curryhats', 'cmtContent': ':看那肉的照片…有比新馬辣好嗎…', 'cmtDate': '2022-09-13 20:06:00'}
# {'cmtStatus': '→', 'cmtPoster': 'jean040532', 'cmtContent': ':會不會是我照相技術太差XD', 'cmtDate': '2022-09-13 20:59:00'}
# {'cmtStatus': '推', 'cmtPoster': 'longya', 'cmtContent': ':這裡應該算環球吧？citilink在一樓以上的部分', 'cmtDate': '2020-12-19 09:15:00'}
# {'cmtStatus': '推', 'cmtPoster': 'homej', 'cmtContent': ':這家基本口味都不差,除非很挑食,不然都可接受', 'cmtDate': '2020-02-10 04:13:00+00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'itsadream', 'cmtContent': ':最近奶蛋類的變多了，全素、五辛素品項變少，', 'cmtDate': '2020-02-10 04:19:00+00:00'}
# {'cmtStatus': '→', 'cmtPoster': 'itsadream', 'cmtContent': ':但應該還是比其他素食吃到飽店家好很多', 'cmtDate': '2020-02-10 04:20:00+00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'momicats', 'cmtContent': ':是素食但做得精緻，口味也不錯~', 'cmtDate': '2020-02-10 04:45:00+00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'jamiro0000', 'cmtContent': ':也可以去吃到飽版問問看喔', 'cmtDate': '2020-02-10 07:49:00+00:00'}
# {'cmtStatus': '→', 'cmtPoster': 'r1t1r', 'cmtContent': ':他是蔬食餐廳不是純素餐廳，餐點我覺得還不錯', 'cmtDate': '2020-02-10 12:13:00+00:00'}
# {'cmtStatus': '→', 'cmtPoster': 'TERIYAKI', 'cmtContent': ':個人非吃素者也覺得不錯吃有種健康吃buffet的錯覺哈哈', 'cmtDate': '2020-02-10 13:09:00+00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'bentryit', 'cmtContent': ':我喜歡（我非吃素者但喜歡蔬食）', 'cmtDate': '2020-02-10 15:06:00+00:00'}
# {'cmtStatus': '→', 'cmtPoster': 'bentryit', 'cmtContent': ':至少冰淇淋有滿足需要', 'cmtDate': '2020-02-10 15:06:00+00:00'}
# {'cmtStatus': '→', 'cmtPoster': 'bentryit', 'cmtContent': ':重點是氣氛很有秩序、裝潢合理，不像其他素食吃到飽一', 'cmtDate': '2020-02-10 15:07:00+00:00'}
# {'cmtStatus': '→', 'cmtPoster': 'bentryit', 'cmtContent': ':樣有股老氣', 'cmtDate': '2020-02-10 15:07:00+00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'karen2520', 'cmtContent': ':這家很好吃也有現打飲料很推薦', 'cmtDate': '2020-02-11 04:07:00+00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'sweetkin', 'cmtContent': ':去吃過2-3次真材實料又好吃！推+1', 'cmtDate': '2020-04-28 21:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'linmei3', 'cmtContent': ':好難', 'cmtDate': '2020-04-28 23:13:00'}
# {'cmtStatus': '推', 'cmtPoster': 'sprpcp', 'cmtContent': ':吃到飽只有午餐時段嗎', 'cmtDate': '2020-04-29 09:43:00'}
# {'cmtStatus': '→', 'cmtPoster': 'suzukihiro', 'cmtContent': ':是', 'cmtDate': '2020-04-29 14:37:00'}
# {'cmtStatus': '推', 'cmtPoster': 'allen1224a', 'cmtContent': ':我都點肉吃到飽，划算', 'cmtDate': '2020-09-14 22:47:00'}
# {'cmtStatus': '推', 'cmtPoster': 'NouTsan', 'cmtContent': ':水，有人寫，推，想去吃和牛方案但怕很排XD', 'cmtDate': '2020-11-09 15:34:00'}
# {'cmtStatus': '→', 'cmtPoster': 'NouTsan', 'cmtContent': ':招牌的Premium4好吃嗎？', 'cmtDate': '2020-11-09 15:35:00'}
# {'cmtStatus': '推', 'cmtPoster': 'TWINNINES', 'cmtContent': ':同行者之一)Premium4我們當天只有點鑽石切割腹肉紐約', 'cmtDate': '2020-11-09 15:41:00'}
# {'cmtStatus': '→', 'cmtPoster': 'TWINNINES', 'cmtContent': ':客牛排和豪邁的原塊牛排，很好吃！', 'cmtDate': '2020-11-09 15:41:00'}
# {'cmtStatus': '推', 'cmtPoster': 'NouTsan', 'cmtContent': ':耶謝謝情報，豪邁原塊的部位好像是使用橫膈膜，好想吃QQ', 'cmtDate': '2020-11-09 15:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'r1t1r', 'cmtContent': ':單人可吃嗎', 'cmtDate': '2020-11-09 16:10:00'}
# {'cmtStatus': '→', 'cmtPoster': 'dkdt', 'cmtContent': ':有單人座，我們前面一組也是一個人的', 'cmtDate': '2020-11-09 16:13:00'}
# {'cmtStatus': '推', 'cmtPoster': 'robotcl', 'cmtContent': ':好想吃', 'cmtDate': '2020-11-09 16:14:00'}
# {'cmtStatus': '推', 'cmtPoster': 'TWINNINES', 'cmtContent': ':補充，點單系統會在用餐時間結束前15分鐘關閉/', 'cmtDate': '2020-11-09 16:15:00'}
# {'cmtStatus': '推', 'cmtPoster': 'pochidoggy66', 'cmtContent': ':請問單人座多嗎？', 'cmtDate': '2020-11-09 16:42:00'}
# {'cmtStatus': '推', 'cmtPoster': 'r1t1r', 'cmtContent': ':感謝～這樣平日可以找時間探路看看了', 'cmtDate': '2020-11-09 17:03:00'}
# {'cmtStatus': '推', 'cmtPoster': 'sdfg014025xx', 'cmtContent': ':燒烤100分鐘感覺很趕', 'cmtDate': '2020-11-09 22:26:00'}
# {'cmtStatus': '→', 'cmtPoster': 'dkdt', 'cmtContent': ':出餐很快，而且火力也蠻強的，至少我們4個人都是吃撐著走的', 'cmtDate': '2020-11-09 22:49:00'}
# {'cmtStatus': '推', 'cmtPoster': 'v21638245', 'cmtContent': ':原本還在猶豫，看來可以吃吃看', 'cmtDate': '2020-11-09 23:44:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Licor', 'cmtContent': ':和民先前關掉大多數分店,不知是生意不好或撤資', 'cmtDate': '2020-11-10 03:56:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Licor', 'cmtContent': ':很高興有關係企業來展店', 'cmtDate': '2020-11-10 03:56:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Licor', 'cmtContent': ':台灣人是不是不喜歡日式居酒屋,白木屋和養老乃瀧都倒了...', 'cmtDate': '2020-11-10 03:57:00'}
# {'cmtStatus': '→', 'cmtPoster': 'uranusjr', 'cmtContent': ':台灣平價族群確實不會選居酒屋,通常都是去熱炒店;居酒', 'cmtDate': '2020-11-10 09:05:00'}
# {'cmtStatus': '→', 'cmtPoster': 'uranusjr', 'cmtContent': ':屋不是沒有市場,但是那個族群又不愛連鎖的了', 'cmtDate': '2020-11-10 09:06:00'}
# {'cmtStatus': '推', 'cmtPoster': 'thudadai', 'cmtContent': ':養老乃瀧多久沒聽到了小時候吃過的店', 'cmtDate': '2020-11-10 10:25:00'}
# {'cmtStatus': '推', 'cmtPoster': 'a09410045', 'cmtContent': ':不是不喜歡是覺得不好吃耶', 'cmtDate': '2020-11-10 11:55:00'}
# {'cmtStatus': '→', 'cmtPoster': 'a09410045', 'cmtContent': ':台灣日本的白木屋都吃過', 'cmtDate': '2020-11-10 11:56:00'}
# {'cmtStatus': '→', 'cmtPoster': 'a100205069', 'cmtContent': ':電話不給預約到現場不給排呵呵', 'cmtDate': '2020-11-10 12:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'a100205069', 'cmtContent': ':補噓', 'cmtDate': '2020-11-10 12:53:00'}
# {'cmtStatus': '推', 'cmtPoster': 'hikarustar', 'cmtContent': ':推', 'cmtDate': '2020-11-10 12:56:00'}
# {'cmtStatus': '→', 'cmtPoster': 'NouTsan', 'cmtContent': ':不給排是怎樣:O', 'cmtDate': '2020-11-10 13:18:00'}
# {'cmtStatus': '→', 'cmtPoster': 'NouTsan', 'cmtContent': ':還在想14:00最後入場，要不要去看一下的', 'cmtDate': '2020-11-10 13:19:00'}
# {'cmtStatus': '推', 'cmtPoster': 'a100205069', 'cmtContent': ':就他只開放一點點現場候位名額滿了就連排都不給排你', 'cmtDate': '2020-11-10 13:47:00'}
# {'cmtStatus': '→', 'cmtPoster': 'a100205069', 'cmtContent': ':跟他預約晚上也不給', 'cmtDate': '2020-11-10 13:47:00'}
# {'cmtStatus': '→', 'cmtPoster': 'sabear', 'cmtContent': ':上村官網有註明截至今日還是試營運預約都還沒開放啊', 'cmtDate': '2020-11-10 21:54:00'}
# {'cmtStatus': '→', 'cmtPoster': 'sabear', 'cmtContent': ':如果滿場不給候位感覺還可以(？)避免排隊久候', 'cmtDate': '2020-11-10 21:55:00'}
# {'cmtStatus': '推', 'cmtPoster': 'error123', 'cmtContent': ':竟然有50分鐘的選項', 'cmtDate': '2020-11-11 03:45:00'}
# {'cmtStatus': '推', 'cmtPoster': 'jjoonnyy', 'cmtContent': ':我只關心上菜速度快不快', 'cmtDate': '2020-11-11 15:25:00'}
# {'cmtStatus': '→', 'cmtPoster': 'dkdt', 'cmtContent': ':我是覺得蠻快的啦我們點的東西也都有來', 'cmtDate': '2020-11-11 22:11:00'}
# {'cmtStatus': '→', 'cmtPoster': 'dkdt', 'cmtContent': ':50分鐘的選項感覺會吃得很趕是真的還要扣15分鐘前會關系統', 'cmtDate': '2020-11-11 22:12:00'}
# {'cmtStatus': '→', 'cmtPoster': 'alfi2016', 'cmtContent': ':濃濃葉配味假鮑魚', 'cmtDate': '2020-09-04 15:43:00'}
# {'cmtStatus': '推', 'cmtPoster': 'aq5137', 'cmtContent': ':往餐酒館找吧', 'cmtDate': '2022-03-29 22:25:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ghostl40809', 'cmtContent': ':中原街secretbistro可以試試看', 'cmtDate': '2022-03-29 23:33:00'}
# {'cmtStatus': '推', 'cmtPoster': 'unchained', 'cmtContent': ':草山夜未眠氣氛超好', 'cmtDate': '2022-03-30 15:48:00'}
# {'cmtStatus': '推', 'cmtPoster': 'wingdeniel', 'cmtContent': ':一千以內可以試試老人家的相親聖地波麗路', 'cmtDate': '2022-03-31 08:24:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Emerson158', 'cmtContent': ':什麼?!夏洛克56給到10顆星的店??', 'cmtDate': '2020-04-11 21:44:00'}
# {'cmtStatus': '推', 'cmtPoster': 'suzukihiro', 'cmtContent': ':看完之後我怎麼覺得小菜才是本體XD', 'cmtDate': '2020-04-12 01:19:00'}
# {'cmtStatus': '推', 'cmtPoster': 'dodo11060', 'cmtContent': ':看起來很厲害啊！', 'cmtDate': '2020-04-12 19:23:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Spurs5566', 'cmtContent': ':慘QQ', 'cmtDate': '2020-10-12 10:50:00'}
# {'cmtStatus': '推', 'cmtPoster': 'paulsama', 'cmtContent': ':個人認為食物：★★☆', 'cmtDate': '2022-03-05 01:21:00'}
# {'cmtStatus': '→', 'cmtPoster': 'onlylove514', 'cmtContent': ':五分熟看起來沒什麼問題', 'cmtDate': '2020-08-19 07:55:00'}
# {'cmtStatus': '推', 'cmtPoster': 'darkholezero', 'cmtContent': ':天鍋宴', 'cmtDate': '2020-11-17 01:11:00'}
# {'cmtStatus': '推', 'cmtPoster': 'etfive217', 'cmtContent': ':富樂阿紅', 'cmtDate': '2020-11-17 02:07:00'}
# {'cmtStatus': '推', 'cmtPoster': 'stableman302', 'cmtContent': ':牛棒碗安', 'cmtDate': '2020-11-17 02:29:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yjterry', 'cmtContent': ':天鍋宴', 'cmtDate': '2020-11-17 02:54:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ufoo', 'cmtContent': ':好食多可自行線上訂位', 'cmtDate': '2020-11-17 05:13:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ufoo', 'cmtContent': ':推冬瓜檸檬一生摯愛', 'cmtDate': '2020-11-17 05:13:00'}
# {'cmtStatus': '推', 'cmtPoster': 'rdsun', 'cmtContent': ':後山埤對面的石二鍋', 'cmtDate': '2020-11-17 07:50:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Nov17', 'cmtContent': ':滾吧鍋物', 'cmtDate': '2020-11-17 08:03:00'}
# {'cmtStatus': '推', 'cmtPoster': 'papadriest', 'cmtContent': ':養心殿', 'cmtDate': '2020-11-17 08:58:00'}
# {'cmtStatus': '推', 'cmtPoster': 'becathy', 'cmtContent': ':東北之家酸菜白肉鍋吃到飽~或是築間牛奶鍋', 'cmtDate': '2020-11-17 09:39:00'}
# {'cmtStatus': '推', 'cmtPoster': 'dragonashco', 'cmtContent': ':新北投站附近的原鍋食堂，每年冬天必吃', 'cmtDate': '2020-11-17 10:07:00'}
# {'cmtStatus': '→', 'cmtPoster': 'nick2428', 'cmtContent': ':好食多', 'cmtDate': '2020-11-17 10:13:00'}
# {'cmtStatus': '推', 'cmtPoster': 'awinwu', 'cmtContent': ':阿紅', 'cmtDate': '2020-11-17 10:32:00'}
# {'cmtStatus': '→', 'cmtPoster': 'iamseanx', 'cmtContent': ':肉老大', 'cmtDate': '2020-11-17 10:50:00'}
# {'cmtStatus': '推', 'cmtPoster': 'steve2512', 'cmtContent': ':神來一鍋花雕湯頭棒三種魚漿鮮', 'cmtDate': '2020-11-17 10:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'guanghagrid', 'cmtContent': ':謝謝大家推薦，我會再查查', 'cmtDate': '2020-11-17 11:01:00'}
# {'cmtStatus': '推', 'cmtPoster': 'linni517', 'cmtContent': ':德朗', 'cmtDate': '2020-11-17 11:09:00'}
# {'cmtStatus': '推', 'cmtPoster': 'fishyu72', 'cmtContent': ':肉老大', 'cmtDate': '2020-11-17 11:18:00'}
# {'cmtStatus': '推', 'cmtPoster': 'wudu', 'cmtContent': ':加分', 'cmtDate': '2020-11-17 11:19:00'}
# {'cmtStatus': '推', 'cmtPoster': 'tearness', 'cmtContent': ':Mealroom正妹保證愛', 'cmtDate': '2020-11-17 11:25:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Mikya', 'cmtContent': ':初衷小鹿', 'cmtDate': '2020-11-17 11:39:00'}
# {'cmtStatus': '推', 'cmtPoster': 'adsl1465', 'cmtContent': ':卡拉拉', 'cmtDate': '2020-11-17 12:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'thirtynm', 'cmtContent': ':故意火鍋', 'cmtDate': '2020-11-17 12:03:00'}
# {'cmtStatus': '推', 'cmtPoster': 'pinkwl6', 'cmtContent': ':阿官火鍋初衷小鹿', 'cmtDate': '2020-11-17 12:09:00'}
# {'cmtStatus': '推', 'cmtPoster': 'FuNnYw', 'cmtContent': ':自然風橘色單人鍋市民大道涮涮鍋', 'cmtDate': '2020-11-17 13:36:00'}
# {'cmtStatus': '推', 'cmtPoster': 'robertlu5810', 'cmtContent': ':正官', 'cmtDate': '2020-11-17 14:28:00'}
# {'cmtStatus': '推', 'cmtPoster': 'monster7', 'cmtContent': ':天鍋宴', 'cmtDate': '2020-11-17 14:42:00'}
# {'cmtStatus': '推', 'cmtPoster': 'TAFFY', 'cmtContent': ':天鍋宴一定要點海鮮，純肉類CP值很低而且克數偷很兇', 'cmtDate': '2020-11-17 15:04:00'}
# {'cmtStatus': '→', 'cmtPoster': 'TAFFY', 'cmtContent': ':澎湃火鍋我覺得不錯', 'cmtDate': '2020-11-17 15:04:00'}
# {'cmtStatus': '推', 'cmtPoster': 'pochidoggy66', 'cmtContent': ':火鍋106，胡椒豬肚雞讚', 'cmtDate': '2020-11-17 15:31:00'}
# {'cmtStatus': '推', 'cmtPoster': 'boy422111', 'cmtContent': ':好食多', 'cmtDate': '2020-11-17 16:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'GDDD', 'cmtContent': ':科技大樓站禾豐海鮮新鮮肉也好吃', 'cmtDate': '2020-11-17 16:10:00'}
# {'cmtStatus': '推', 'cmtPoster': 'wfyal', 'cmtContent': ':如果新北市接受的話，景安站旁的小海水產值得一試', 'cmtDate': '2020-11-17 17:58:00'}
# {'cmtStatus': '推', 'cmtPoster': 'people010203', 'cmtContent': ':雞湯大叔', 'cmtDate': '2020-11-17 18:27:00'}
# {'cmtStatus': '推', 'cmtPoster': 'sherryshies', 'cmtContent': ':肉老大', 'cmtDate': '2020-11-17 18:44:00'}
# ...
# {'cmtStatus': '推', 'cmtPoster': 'Ihatelive', 'cmtContent': ':蟹黃豆腐煲感覺很讚耶', 'cmtDate': '2022-05-25 16:33:00'}
# {'cmtStatus': '→', 'cmtPoster': 'oc4r', 'cmtContent': ':味道好濃0.0', 'cmtDate': '2020-03-21 19:46:50'}
# {'cmtStatus': '推', 'cmtPoster': 'jamovam', 'cmtContent': ':他們銅盤好吃，肉不知道怎麼弄的，很嫩', 'cmtDate': '2020-01-24 10:21:00+00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Kornfeil', 'cmtContent': ':有吃過南港的覺得蠻好吃~', 'cmtDate': '2020-01-25 11:28:00+00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'scissorstone', 'cmtContent': ':唐揚雞用的是雞胸肉，炸起來仍保有肉汁，挺喜歡的~', 'cmtDate': '2020-10-09 08:14:00'}
# {'cmtStatus': '推', 'cmtPoster': 'chiajui', 'cmtContent': ':慶洲館的烤盤是類似的。', 'cmtDate': '2022-05-27 15:38:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ILB1800600', 'cmtContent': ':感謝資訊不過慶洲館好像不太一樣', 'cmtDate': '2022-05-27 16:09:00'}
# {'cmtStatus': '→', 'cmtPoster': 'pilk', 'cmtContent': ':南大門？', 'cmtDate': '2022-05-27 16:16:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ILB1800600', 'cmtContent': ':南大門也不太一樣印象在二樓沒有一樓店面', 'cmtDate': '2022-05-27 18:19:00'}
# {'cmtStatus': '推', 'cmtPoster': 'cuteyo520', 'cmtContent': ':水刺光復店？', 'cmtDate': '2022-05-27 21:57:00'}
# {'cmtStatus': '推', 'cmtPoster': 'peter080845', 'cmtContent': ':糕糕在尚我就覺得看過台北好像收了', 'cmtDate': '2022-05-28 00:35:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ILB1800600', 'cmtContent': ':對!就是糕糕在尚.看到就想起來了.6年了收了也沒辦法.', 'cmtDate': '2022-05-28 02:17:00'}
# {'cmtStatus': '→', 'cmtPoster': 'IkarusWillie', 'cmtContent': ':這家是新千葉不是千葉XD', 'cmtDate': '2021-08-16 20:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ha0118', 'cmtContent': ':每次下班經過都客滿', 'cmtDate': '2021-07-14 21:30:00'}
# {'cmtStatus': '→', 'cmtPoster': 'nanie', 'cmtContent': ':你的網誌網址太長了~變成兩行', 'cmtDate': '2021-07-14 21:39:00'}
# {'cmtStatus': '→', 'cmtPoster': 'cin2', 'cmtContent': ':用餐限時100分鐘?', 'cmtDate': '2021-07-14 21:43:00'}
# {'cmtStatus': '→', 'cmtPoster': 'qwe5900531', 'cmtContent': ':剛吃過不推...位子太小油一直噴到手', 'cmtDate': '2021-07-14 22:01:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Vuvukuku', 'cmtContent': ':吃過不推', 'cmtDate': '2021-07-14 22:27:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Vuvukuku', 'cmtContent': ':加價149海陸制霸菜單上肉品圖片都是厚切肉', 'cmtDate': '2021-07-14 22:27:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Vuvukuku', 'cmtContent': ':實際送上是火鍋肉片的厚度', 'cmtDate': '2021-07-14 22:27:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Vuvukuku', 'cmtContent': ':而且還有兩三盤大概有80%都是脂肪的肉片', 'cmtDate': '2021-07-14 22:27:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Vuvukuku', 'cmtContent': ':而且店面西曬嚴重也沒有設計窗簾', 'cmtDate': '2021-07-14 22:27:00'}
# {'cmtStatus': '→', 'cmtPoster': 'bluefr00', 'cmtContent': ':吃過不愛。位置好小。帶小孩很危險，離鍋都很近，也沒', 'cmtDate': '2021-07-14 22:31:00'}
# {'cmtStatus': '→', 'cmtPoster': 'bluefr00', 'cmtContent': ':地方放兒童餐椅', 'cmtDate': '2021-07-14 22:31:00'}
# {'cmtStatus': '推', 'cmtPoster': 'qqa11023', 'cmtContent': ':油很噴就單純吃粗飽的', 'cmtDate': '2021-07-14 22:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'funnyBD', 'cmtContent': ':用餐環境擁擠，上次五個人有一個要坐在路中間，真的是無', 'cmtDate': '2021-07-14 22:46:00'}
# {'cmtStatus': '→', 'cmtPoster': 'funnyBD', 'cmtContent': ':言', 'cmtDate': '2021-07-14 22:46:00'}
# {'cmtStatus': '推', 'cmtPoster': 'a45', 'cmtContent': ':120分鐘，見菜單右下角。', 'cmtDate': '2021-07-14 22:55:00'}
# {'cmtStatus': '推', 'cmtPoster': 'csjh960023', 'cmtContent': ':生意超好', 'cmtDate': '2021-07-14 23:01:00'}
# {'cmtStatus': '推', 'cmtPoster': 'amy2930', 'cmtContent': ':整間油煙味超重，空間超小', 'cmtDate': '2021-07-14 23:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'erer1976', 'cmtContent': ':用餐120分鐘，早上和下午各開放5組現場排隊候位，電話很', 'cmtDate': '2021-07-14 23:03:00'}
# {'cmtStatus': '→', 'cmtPoster': 'erer1976', 'cmtContent': ':難打，上禮拜提早半小時幸運排到，真的很不錯！但吃到飽', 'cmtDate': '2021-07-14 23:03:00'}
# {'cmtStatus': '→', 'cmtPoster': 'erer1976', 'cmtContent': ':能力太弱......很適合喜歡韓式烤肉的人，烤肉包生菜包泡', 'cmtDate': '2021-07-14 23:03:00'}
# {'cmtStatus': '→', 'cmtPoster': 'erer1976', 'cmtContent': ':菜包蒜片，很想再去吃，但太難訂位了', 'cmtDate': '2021-07-14 23:03:00'}
# {'cmtStatus': '推', 'cmtPoster': 'WenWen26', 'cmtContent': ':油太會噴了我不行，但這個價位配上食材是真的對嗜肉的吸', 'cmtDate': '2021-07-14 23:10:00'}
# {'cmtStatus': '→', 'cmtPoster': 'WenWen26', 'cmtContent': ':引力很大', 'cmtDate': '2021-07-14 23:10:00'}
# {'cmtStatus': '推', 'cmtPoster': 'bewell0216', 'cmtContent': ':這間好吃', 'cmtDate': '2021-07-14 23:17:00'}
# {'cmtStatus': '→', 'cmtPoster': 'quan1224', 'cmtContent': ':完全不推，中午剛開店進門差點因為地上太油滑倒，調味', 'cmtDate': '2021-07-14 23:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'quan1224', 'cmtContent': ':料罐子都是油垢，胡椒鹽都結塊，牛豬雞都放在同一區看', 'cmtDate': '2021-07-14 23:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'quan1224', 'cmtContent': ':著其他人混合夾來夾去，店員態度不佳，員工做不好，在', 'cmtDate': '2021-07-14 23:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'quan1224', 'cmtContent': ':客人旁邊訓話，請他們換個地方說話被兇，時間還沒到也', 'cmtDate': '2021-07-14 23:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'quan1224', 'cmtContent': ':還沒吃完就被告知結帳因為下一輪客人快到了，', 'cmtDate': '2021-07-14 23:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'nmercra', 'cmtContent': ':看完留言好滅火', 'cmtDate': '2021-07-14 23:29:00'}
# {'cmtStatus': '推', 'cmtPoster': 'vickey70', 'cmtContent': ':滅火+1', 'cmtDate': '2021-07-14 23:49:00'}
# {'cmtStatus': '推', 'cmtPoster': 'furuuchitw', 'cmtContent': ':滅火+1...本來還想跟朋友去吃', 'cmtDate': '2021-07-15 00:39:00'}
# {'cmtStatus': '推', 'cmtPoster': 'dds7788369', 'cmtContent': ':座位設計成這樣靠低價搶市拼翻桌，感覺員工發生職災', 'cmtDate': '2021-07-15 00:47:00'}
# {'cmtStatus': '→', 'cmtPoster': 'dds7788369', 'cmtContent': ':或公共安全意外是遲早的事...去過一次就不會再去了', 'cmtDate': '2021-07-15 00:47:00'}
# {'cmtStatus': '→', 'cmtPoster': 'hemble', 'cmtContent': ':推文真的超滅火..剛好有人是生肖價要去吃的說..', 'cmtDate': '2021-07-15 00:55:00'}
# {'cmtStatus': '→', 'cmtPoster': 'hemble', 'cmtContent': ':阿..生肖價多打的XD', 'cmtDate': '2021-07-15 00:57:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mos01', 'cmtContent': ':好滅火', 'cmtDate': '2021-07-15 01:02:00'}
# {'cmtStatus': '→', 'cmtPoster': 'sseraph', 'cmtContent': ':椅子要多窄有多窄，吸管要多粗有多粗', 'cmtDate': '2021-07-15 01:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'supergu', 'cmtContent': ':蛤!滅火了，還是吃銅*好了', 'cmtDate': '2021-07-15 01:25:00'}
# {'cmtStatus': '噓', 'cmtPoster': 'njunju', 'cmtContent': ':一次店+1烤盤設計超爛中間會積油所以油才會亂噴根本一', 'cmtDate': '2021-07-15 01:38:00'}
# {'cmtStatus': '→', 'cmtPoster': 'njunju', 'cmtContent': ':點也不韓式', 'cmtDate': '2021-07-15 01:38:00'}
# {'cmtStatus': '→', 'cmtPoster': 'njunju', 'cmtContent': ':那烤盤根本就不是寒式根本就高雄式烤盤的失敗設計', 'cmtDate': '2021-07-15 01:39:00'}
# {'cmtStatus': '→', 'cmtPoster': 'njunju', 'cmtContent': ':肉是很多但都吃粗飽的好吃沒半個', 'cmtDate': '2021-07-15 01:40:00'}
# {'cmtStatus': '→', 'cmtPoster': 'njunju', 'cmtContent': ':我很少網上給這麼差的負評因為真的有夠雷', 'cmtDate': '2021-07-15 01:41:00'}
# {'cmtStatus': '→', 'cmtPoster': 'njunju', 'cmtContent': ':男生還可以但不會有妹子會喜歡這家店臉被油煙噴好噴滿', 'cmtDate': '2021-07-15 01:43:00'}
# {'cmtStatus': '→', 'cmtPoster': 'njunju', 'cmtContent': ':那抽油煙機吸力弱到不行', 'cmtDate': '2021-07-15 01:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Elvis1991', 'cmtContent': ':吃過不推', 'cmtDate': '2021-07-15 01:59:00'}
# {'cmtStatus': '噓', 'cmtPoster': 'a497848', 'cmtContent': ':整件超油==', 'cmtDate': '2021-07-15 01:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'a497848', 'cmtContent': ':*間', 'cmtDate': '2021-07-15 01:59:00'}
# {'cmtStatus': '推', 'cmtPoster': 'essential015', 'cmtContent': ':烤盤的錫箔紙好像199火烤兩吃', 'cmtDate': '2021-07-15 02:04:00'}
# {'cmtStatus': '→', 'cmtPoster': 'minoru04', 'cmtContent': ':台南韓式烤肉吃到飽幾乎都雷然後都活不久', 'cmtDate': '2021-07-15 02:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'smai27', 'cmtContent': ':一次店，真的不堆', 'cmtDate': '2021-07-15 08:10:00'}
# {'cmtStatus': '推', 'cmtPoster': 'amacus', 'cmtContent': ':本來餓了看了推文就飽了', 'cmtDate': '2021-07-15 08:39:00'}
# {'cmtStatus': '→', 'cmtPoster': 'baychi999', 'cmtContent': ':這跟隔壁壽喜燒應該同個老闆感覺水準應該也一樣XD', 'cmtDate': '2021-07-15 08:39:00'}
# {'cmtStatus': '推', 'cmtPoster': 's74819', 'cmtContent': ':隔壁也很雷。一樣四人桌為主，五個人就也是塞椅子在走道，', 'cmtDate': '2021-07-15 08:50:00'}
# {'cmtStatus': '→', 'cmtPoster': 's74819', 'cmtContent': ':服務生送餐來來去去的很不方便，廁所格局很妙還只有一間，', 'cmtDate': '2021-07-15 08:50:00'}
# {'cmtStatus': '→', 'cmtPoster': 's74819', 'cmtContent': ':當天用餐還是壞的沒得上，店員都跟客人說去寶雅', 'cmtDate': '2021-07-15 08:50:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ula0806', 'cmtContent': ':烤盤的油真的很會噴，取菜動線好擠很難拿取，用餐時間120', 'cmtDate': '2021-07-15 08:53:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ula0806', 'cmtContent': ':分，上個月跟朋友去吃完的感想就是間一次店', 'cmtDate': '2021-07-15 08:53:00'}
# {'cmtStatus': '推', 'cmtPoster': 'w790818', 'cmtContent': ':留言讚讚', 'cmtDate': '2021-07-15 08:56:00'}
# {'cmtStatus': '推', 'cmtPoster': 'whj0530', 'cmtContent': ':超難訂位看完留言不想去了', 'cmtDate': '2021-07-15 09:05:00'}
# {'cmtStatus': '→', 'cmtPoster': 'is', 'cmtContent': ':超難訂位所以跑去左營吃了結果沒鍋肉吃一輪就膩到陣亡', 'cmtDate': '2021-07-15 10:27:00'}
# {'cmtStatus': '推', 'cmtPoster': 'all115104', 'cmtContent': ':滅火+1本來打算去吃看看的', 'cmtDate': '2021-07-15 10:52:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yenpoppy', 'cmtContent': ':價錢很可以，品質普普，人多東西易亂，忙到沒人清理', 'cmtDate': '2021-07-15 11:10:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Halon', 'cmtContent': ':感謝滅火', 'cmtDate': '2021-07-15 11:33:00'}
# {'cmtStatus': '→', 'cmtPoster': 'wc4eva', 'cmtContent': ':看起來很像台中的86燒烤韓式版', 'cmtDate': '2021-07-15 12:05:00'}
# {'cmtStatus': '推', 'cmtPoster': 'aexl26', 'cmtContent': ':吃過兩次這價位（299）沒啥好嫌了除了超難訂位', 'cmtDate': '2021-07-15 12:12:00'}
# {'cmtStatus': '→', 'cmtPoster': 'aexl26', 'cmtContent': ':有訂到還會去吃就是了', 'cmtDate': '2021-07-15 12:13:00'}
# {'cmtStatus': '噓', 'cmtPoster': 'YYYuMan', 'cmtContent': ':難吃', 'cmtDate': '2021-07-15 12:31:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kimomo', 'cmtContent': ':看完完全滅火哈哈哈哈', 'cmtDate': '2021-07-15 13:31:00'}
# {'cmtStatus': '推', 'cmtPoster': 'niggerdick', 'cmtContent': ':也太雷哈哈哈哈，但吃燒肉把肉丟進湯鍋方便多惹', 'cmtDate': '2021-07-15 14:06:00'}
# {'cmtStatus': '推', 'cmtPoster': 'batis', 'cmtContent': ':心得好誠實XD感覺就好爛', 'cmtDate': '2021-07-15 14:52:00'}
# {'cmtStatus': '→', 'cmtPoster': 'th88012', 'cmtContent': ':一次店', 'cmtDate': '2021-07-15 15:30:00'}
# {'cmtStatus': '推', 'cmtPoster': 'th88012', 'cmtContent': ':如果真的要去吃,推薦咖哩雞跟五花豬還有海苔飯', 'cmtDate': '2021-07-15 15:35:00'}
# {'cmtStatus': '推', 'cmtPoster': 'flowerDcup', 'cmtContent': ':為何難吃又一堆人啊', 'cmtDate': '2021-07-15 17:20:00'}
# {'cmtStatus': '→', 'cmtPoster': 'zeroyaking', 'cmtContent': ':因為有些人就貪便宜阿', 'cmtDate': '2021-07-15 19:14:00'}
# {'cmtStatus': '→', 'cmtPoster': 'cin2', 'cmtContent': ':因為還是窮人居多', 'cmtDate': '2021-07-15 20:29:00'}
# {'cmtStatus': '推', 'cmtPoster': 'amy2930', 'cmtContent': ':我覺得好吃的肉沒幾樣，反而豬隊友沒幾樣肉，但都很好吃', 'cmtDate': '2021-07-15 21:24:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ericsherry', 'cmtContent': ':吃過普，帶小孩座位小危險不推薦', 'cmtDate': '2021-07-15 23:45:00'}
# {'cmtStatus': '噓', 'cmtPoster': 'sistem', 'cmtContent': ':油煙味很重吃完到外面會覺得這世界的空氣多麼清新、美好', 'cmtDate': '2021-07-16 00:08:00'}
# {'cmtStatus': '噓', 'cmtPoster': 'morefishman', 'cmtContent': ':候位機制極差沒訂到就是現場等到熱死', 'cmtDate': '2021-07-19 17:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'RX78RXF91', 'cmtContent': ':價位算便宜，但味道還好', 'cmtDate': '2020-03-28 12:58:00'}
# {'cmtStatus': '→', 'cmtPoster': 'saku0317', 'cmtContent': ':說飲料吧，也太抬舉，完全不建議去', 'cmtDate': '2022-09-04 16:44:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Karstens', 'cmtContent': ':雷', 'cmtDate': '2022-09-04 20:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'shelesa22', 'cmtContent': ':這間很雷+1完全不值得吃', 'cmtDate': '2022-09-04 21:03:00'}
# {'cmtStatus': '推', 'cmtPoster': 'smith5656', 'cmtContent': ':看起來不怎麼樣又沒有價位，完全不想去', 'cmtDate': '2022-02-27 22:19:00'}
# {'cmtStatus': '推', 'cmtPoster': 'dreamcloud', 'cmtContent': ':大億麗緻也有外帶餐盒活動然後..就沒有然後了', 'cmtDate': '2020-05-02 16:23:00'}
# {'cmtStatus': '推', 'cmtPoster': 'sprpcp', 'cmtContent': ':火鍋店推薦的的是飲料跟水果XDDD', 'cmtDate': '2020-07-07 11:12:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yufang1130', 'cmtContent': ':鐵板燒店一定要有青菜、白飯跟湯真的是標配了有些', 'cmtDate': '2022-10-11 13:06:00'}
# {'cmtStatus': '→', 'cmtPoster': 'yufang1130', 'cmtContent': ':還可以續青菜', 'cmtDate': '2022-10-11 13:06:00'}
# {'cmtStatus': '推', 'cmtPoster': 'thirtyoz5566', 'cmtContent': ':這家好吃，他的炒泡麵也很讚', 'cmtDate': '2022-10-12 12:00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'flower323', 'cmtContent': ':自助吧選擇比起一般鐵板燒真的算多了耶', 'cmtDate': '2022-10-13 11:30:00'}
# {'cmtStatus': '→', 'cmtPoster': 'aben5566', 'cmtContent': ':平價鐵板燒的確都是推吃粗飽', 'cmtDate': '2022-10-13 17:25:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ivsna', 'cmtContent': ':平日中午的信義區老乾杯但可能會超出預算一點', 'cmtDate': '2022-01-03 18:21:00'}
# {'cmtStatus': '→', 'cmtPoster': 'nayaya', 'cmtContent': ':老乾杯預算應該不是超出一點而已吧（？', 'cmtDate': '2022-01-03 20:18:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Relyonair', 'cmtContent': ':三樵炭火燒肉應該有符合你的需求', 'cmtDate': '2022-01-03 22:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'DamnDre', 'cmtContent': ':三樵不算安靜吧...京昌園應該有符合你條件', 'cmtDate': '2022-01-04 00:26:00'}
# {'cmtStatus': '→', 'cmtPoster': 'r1t1r', 'cmtContent': ':老乾杯是這預算兩倍以上吧', 'cmtDate': '2022-01-04 08:21:00'}
# {'cmtStatus': '→', 'cmtPoster': 'iPhone3GS', 'cmtContent': ':本來想推中山燒肉，但預算不夠', 'cmtDate': '2022-01-04 13:06:00'}
# {'cmtStatus': '→', 'cmtPoster': 'mdlp', 'cmtContent': ':訂了京昌園謝謝DamnDre推薦一生平安', 'cmtDate': '2022-01-04 15:21:00'}
# {'cmtStatus': '推', 'cmtPoster': 'stanxopstl', 'cmtContent': ':胡同會點餐的話，1000可以很飽', 'cmtDate': '2022-01-04 16:04:00'}
# {'cmtStatus': '→', 'cmtPoster': 'thirtynm', 'cmtContent': ':看估狗評論老乾杯很兩極,現在還值不值得去吃呢?', 'cmtDate': '2022-01-04 20:27:00'}
# {'cmtStatus': '推', 'cmtPoster': 'jimhall', 'cmtContent': ':業配？', 'cmtDate': '2020-03-10 21:57:00'}
# {'cmtStatus': '推', 'cmtPoster': 'gobby616', 'cmtContent': ':啊人家分類不就廣宣了', 'cmtDate': '2020-03-10 22:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'hidyyang', 'cmtContent': ':謝謝樓上XDD', 'cmtDate': '2020-03-11 00:58:00'}
# {'cmtStatus': '推', 'cmtPoster': 'oldriver', 'cmtContent': ':看起來是不錯美福牛肉我吃過蠻好吃的不過自助沒吃過', 'cmtDate': '2020-03-11 11:24:00'}
# {'cmtStatus': '→', 'cmtPoster': 'hidyyang', 'cmtContent': ':我覺得雖然種類不到很多但每樣都精緻不錯', 'cmtDate': '2020-03-12 17:50:00'}
# {'cmtStatus': '推', 'cmtPoster': 'p12464', 'cmtContent': ':可以吃看看澄居，有些人覺得份量少，不過我每次都吃很飽', 'cmtDate': '2020-09-02 23:45:00'}
# {'cmtStatus': '推', 'cmtPoster': 'a0880037ba2', 'cmtContent': ':樓上那間不是吃到飽吧～', 'cmtDate': '2020-09-03 18:48:00'}
# {'cmtStatus': '推', 'cmtPoster': 'tnl0716', 'cmtContent': ':好客燒烤', 'cmtDate': '2020-09-04 03:13:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Tiyara', 'cmtContent': ':滷肉飯無限吃這麼值得宣傳嗎XD', 'cmtDate': '2020-12-31 16:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'dodo11060', 'cmtContent': ':七月才去吃，開在這個地段，這種水準，很難撐...', 'cmtDate': '2020-08-05 13:16:00'}
# {'cmtStatus': '推', 'cmtPoster': 'allen1224a', 'cmtContent': ':感謝滅火，不然差點就要去吃', 'cmtDate': '2020-08-06 12:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'data1728', 'cmtContent': ':沒有肉燥跟蛋之類的嗎', 'cmtDate': '2022-07-25 08:33:00'}
# {'cmtStatus': '→', 'cmtPoster': 'LuckyCoCo', 'cmtContent': ':沒有看到肉燥和蛋喔去之前也以為可以吃到蛋', 'cmtDate': '2022-07-25 09:13:00'}
# {'cmtStatus': '→', 'cmtPoster': 'terhiot', 'cmtContent': ':也太孤單了…', 'cmtDate': '2020-08-01 13:13:00'}
# {'cmtStatus': '推', 'cmtPoster': 'egghard29', 'cmtContent': ':這家肉海鮮等食材很棒但鍋底口味一般般', 'cmtDate': '2022-03-21 08:09:00'}
# {'cmtStatus': '推', 'cmtPoster': 'dodo11060', 'cmtContent': ':啊嘶', 'cmtDate': '2020-07-05 20:19:00'}
# {'cmtStatus': '推', 'cmtPoster': 'sunny15', 'cmtContent': ':推', 'cmtDate': '2020-07-07 09:41:00'}
# {'cmtStatus': '推', 'cmtPoster': 'hsuannx26', 'cmtContent': ':我也是連假去吃超慶幸自己只選了499的', 'cmtDate': '2020-07-02 19:52:00'}
# {'cmtStatus': '→', 'cmtPoster': 'hsuannx26', 'cmtContent': ':超級不推出餐台附近那股很濃的餿味真的很恐怖然後點', 'cmtDate': '2020-07-02 19:52:00'}
# {'cmtStatus': '→', 'cmtPoster': 'hsuannx26', 'cmtContent': ':了包肉的蒜片居然整個都是酸的', 'cmtDate': '2020-07-02 19:53:00'}
# {'cmtStatus': '→', 'cmtPoster': 'hsuannx26', 'cmtContent': ':店員還說之前也有人反應但內場說蒜頭一切開就是這樣了', 'cmtDate': '2020-07-02 19:54:00'}
# {'cmtStatus': '→', 'cmtPoster': 'hsuannx26', 'cmtContent': ':？？？？店裡整個吵到不行說話都要小喊真的極度不推！', 'cmtDate': '2020-07-02 19:54:00'}
# {'cmtStatus': '→', 'cmtPoster': 'smallta', 'cmtContent': ':我連有些東西可以點都不知道', 'cmtDate': '2020-07-02 22:09:00'}
# {'cmtStatus': '→', 'cmtPoster': 'angelgreen', 'cmtContent': ':滿普的這間', 'cmtDate': '2020-08-13 10:25:00'}
# {'cmtStatus': '→', 'cmtPoster': 'fundoris', 'cmtContent': ':寫好多......', 'cmtDate': '2020-08-12 23:04:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yakifone', 'cmtContent': ':大賣場裡算不錯的店，機器麵意外好吃', 'cmtDate': '2022-12-08 15:06:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ruth0204', 'cmtContent': ':剩下孫家將跟義式小品還沒去吃就通通解鎖了', 'cmtDate': '2022-12-08 16:23:00'}

# %%
raw_data = raw_data.explode(['artComter','artStatus'])
socail_data = raw_data[['artUrl','artPoster','artComter','artStatus']]
socail_data.head(10)
# Out:
#                                                  artUrl   artPoster
# 394   https://www.ptt.cc/bbs/Food/M.1596626709.A.48F...      linche  \
# 394   https://www.ptt.cc/bbs/Food/M.1596626709.A.48F...      linche
# 303   https://www.ptt.cc/bbs/Food/M.1592063279.A.E0E...     nikcoke
# 303   https://www.ptt.cc/bbs/Food/M.1592063279.A.E0E...     nikcoke
# 239   https://www.ptt.cc/bbs/Food/M.1589791255.A.49C...     ally701
# 1231  https://www.ptt.cc/bbs/Food/M.1643432020.A.8B5...        dass
# 854   https://www.ptt.cc/bbs/Food/M.1616237558.A.40E...  TW00500203
# 492   https://www.ptt.cc/bbs/Food/M.1600760494.A.41D...       grawd
# 492   https://www.ptt.cc/bbs/Food/M.1600760494.A.41D...       grawd
# 492   https://www.ptt.cc/bbs/Food/M.1600760494.A.41D...       grawd
#
#          artComter artStatus
# 394          faway         推
# 394         linche         →
# 303   perfectperfe         推
# 303   perfectperfe         →
# 239     allen1224a         推
# 1231   King12man36         推
# 854       ring0816         推
# 492       yakifone         推
# 492     breeze1006         →
# 492   OGCOGCOGCOGC         推

# %%
socail_data.artStatus.unique()
# Out:
# array(['推', '→', '噓'], dtype=object)

# %% [markdown]
# 簡單劃出文章、發文者、評論者的網路

# %%
# 建立邊的資料
import random


po_df = socail_data[['artPoster','artUrl']].drop_duplicates().rename(columns = {'artPoster':'src','artUrl':'dis'})
sample_url = random.choices(po_df.dis.unique().tolist(),k=300)
po_df = po_df[po_df.dis.isin(sample_url)]
re_df = socail_data[['artComter','artUrl','artStatus']].rename(columns = {'artComter':'src','artUrl':'dis','artStatus':'weight'})
re_df = re_df[re_df.dis.isin(sample_url)]
re_df = re_df[~re_df['src'].isna()]



def convertStatus(s):
  if s == '推':
    return 2
  elif s == '→':
    return 1
  else :
    return -1
re_df['weight'] = re_df['weight'].map(convertStatus)
re_df = re_df.groupby(['src','dis']).sum().reset_index()

# 設定分數低的為紅色
def getColor(w):
  if w>0:
    return 'green'
  else:
    return 'red'
re_df['color'] = re_df.weight.map(getColor)

# %%
re_df
# Out:
#             src                                                dis  weight
# 0        ALENDA  https://www.ptt.cc/bbs/Food/M.1602012705.A.031...       2  \
# 1        AlphaD  https://www.ptt.cc/bbs/Food/M.1579766074.A.BB5...       2
# 2        AlphaD  https://www.ptt.cc/bbs/Food/M.1583982662.A.755...       2
# 3     Alphaplus  https://www.ptt.cc/bbs/Food/M.1655268051.A.324...       0
# 4        Arutha  https://www.ptt.cc/bbs/Food/M.1587898980.A.623...       7
# ..          ...                                                ...     ...
# 480  zeroyaking  https://www.ptt.cc/bbs/Food/M.1620371370.A.52C...       1
# 481  zeroyaking  https://www.ptt.cc/bbs/Food/M.1655268051.A.324...       2
# 482    zxc89003  https://www.ptt.cc/bbs/Food/M.1645607596.A.305...       2
# 483     zyc5566  https://www.ptt.cc/bbs/Food/M.1655268051.A.324...       1
# 484    zzz50126  https://www.ptt.cc/bbs/Food/M.1655268051.A.324...       2
#
#      color
# 0    green
# 1    green
# 2    green
# 3      red
# 4    green
# ..     ...
# 480  green
# 481  green
# 482  green
# 483  green
# 484  green
#
# [485 rows x 4 columns]

# %%
# 人為綠色節點
# po文為橘色節點

netWork = pyvis.network.Network(notebook=True, cdn_resources='in_line',directed=True)
person = list(set(po_df.src.unique().tolist()+re_df.src.unique().tolist()))
url = po_df.dis.unique().tolist()
netWork.add_nodes(
    nodes = person,
    value = [1 for i in range(len(person))],
    color = ['#66CDAA' for i in range(len(person))],
    title = person
)
netWork.add_nodes(
    nodes = url,
    value = [2 for i in range(len(url))],
    color = ['#FFB366' for i in range(len(url))],
    title = url
)
for i in po_df.to_numpy():
  netWork.add_edge(i[0],i[1],width = 2,color='grey')
for i in re_df.to_numpy():
  netWork.add_edge(i[0],i[1],width = 2,color=i[3])

# 設定layout
netWork.repulsion()

# netWork.toggle_physics(True)
# netWork.set_options("""
# const options = {
#   "physics": {
#     "forceAtlas2Based": {
#       "springLength": 100
#     },
#     "minVelocity": 0.75,
#     "solver": "forceAtlas2Based",
#     "timestep": 0.48
#   }
# }
# """)

netWork.show("./basic_netWork.html")
IPython.display.HTML('basic_netWork.html')
# Out:
# ./basic_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# 以上可以看出多數的文章留言偏少，只有四篇的文章的回文較多

# %% [markdown]
# 計算網友之間的關係

# %%
pos_cmt = socail_data.copy()
pos_cmt = pos_cmt[~pos_cmt.artComter.isna()]
pos_cmt.head(10)
# Out:
#                                                  artUrl   artPoster
# 394   https://www.ptt.cc/bbs/Food/M.1596626709.A.48F...      linche  \
# 394   https://www.ptt.cc/bbs/Food/M.1596626709.A.48F...      linche
# 303   https://www.ptt.cc/bbs/Food/M.1592063279.A.E0E...     nikcoke
# 303   https://www.ptt.cc/bbs/Food/M.1592063279.A.E0E...     nikcoke
# 239   https://www.ptt.cc/bbs/Food/M.1589791255.A.49C...     ally701
# 1231  https://www.ptt.cc/bbs/Food/M.1643432020.A.8B5...        dass
# 854   https://www.ptt.cc/bbs/Food/M.1616237558.A.40E...  TW00500203
# 492   https://www.ptt.cc/bbs/Food/M.1600760494.A.41D...       grawd
# 492   https://www.ptt.cc/bbs/Food/M.1600760494.A.41D...       grawd
# 492   https://www.ptt.cc/bbs/Food/M.1600760494.A.41D...       grawd
#
#          artComter artStatus
# 394          faway         推
# 394         linche         →
# 303   perfectperfe         推
# 303   perfectperfe         →
# 239     allen1224a         推
# 1231   King12man36         推
# 854       ring0816         推
# 492       yakifone         推
# 492     breeze1006         →
# 492   OGCOGCOGCOGC         推

# %%
pos_cmt['score'] = pos_cmt['artStatus'].apply(lambda r: convertStatus(r))
pos_cmt = pos_cmt.groupby(['artComter','artPoster']).sum('score').reset_index()
pos_cmt = pos_cmt[pos_cmt.score>=0]
pos_cmt = pos_cmt[pos_cmt.artComter != pos_cmt.artPoster]
# pos_cmt.score = 1
pos_cmt
# Out:
#       artComter     artPoster  score
# 0        ALENDA     chickenbo      2
# 2        AlphaD  gillianshine      2
# 3     Alphaplus       reesion      0
# 4        Arutha       NouTsan      7
# 5           BUE     cheauwong      4
# ..          ...           ...    ...
# 494     yzkg391         oao88      2
# 495  zeroyaking       reesion      3
# 496    zxc89003        adai69      2
# 497     zyc5566       reesion      1
# 498    zzz50126       reesion      2
#
# [471 rows x 3 columns]

# %%
pers = np.unique(pos_cmt[['artComter', 'artPoster']])
mat = pd.pivot_table(pos_cmt,index = 'artComter', columns = 'artPoster' ,values='score' ).fillna(0)\
  .reindex(columns=pers, index=pers, fill_value=0).to_numpy()
print(mat.shape)
tri = (np.tril(mat,-1).T + np.triu(mat,1))
mat_s = tri+tri.T

# # print((mat == mat.transpose()).all())

# G = nx.DiGraph(mat)
# G_sub = sorted(nx.connected_components(G), key=len, reverse=True)
# G_max_sub = G.subgraph(G_sub[0])
# # 重新定義 mat
# mat = nx.adjacency_matrix(G_max_sub).todense()
# node_idx = list(G_max_sub.nodes)
# # mat = mat[np.ix_(node_idx,node_idx)]
# pers = pers[node_idx]
# print((mat == mat.transpose()).all())

# # 計算無向圖的adj
# Out:
# (505, 505)

# %%
def random_color():
  r = lambda: random.randint(0,255)
  return '#%02X%02X%02X' % (r(),r(),r())

def matPresentGraph(mat:np.array,node_id:list,node_type:list=None,node_value:list = None,directed = True,edge_color=None) -> pyvis.network.Network:

  if directed != True:
    if (mat == mat.transpose()).all():
      print('matrix is Symmetric')
    else:
      print('matrix is not Symmetric')
  if node_type == None:
    c = random_color()
    node_colors = [c for i in range(len(node_id))]
    node_type = [" " for i in range(len(node_id))]
  else:
    node_color_map = {}
    for i in set(node_type):
      while True:
        c = random_color()
        if c not in node_color_map.values():
          break
      node_color_map[i] = c
    node_colors = [node_color_map[i] for i in node_type]
  # print(node_colors)
  if edge_color == None:
    edge_color = random_color()
  edge_color = random_color()
  if node_value == None:
    node_value = [1 for i in range(len(node_id))]

  net = pyvis.network.Network(notebook=True, directed = directed, cdn_resources='in_line')
  
  titles_list = []
  for i ,j in zip(node_id,node_type):
    titles_list.append(str(i)+":"+str(j))

  net.add_nodes(
      nodes = node_id,
      value = node_value,
      label = node_id,
      title = titles_list,
      color = node_colors
  )

  for row in range(len(node_id)):
    for col in range(len(node_id)):
      if mat[row][col]>0.:
        net.add_edge(
            node_id[row],node_id[col],width = mat[row][col],color = edge_color,title = mat[row][col]
        )
  net.repulsion()
  return net

# %%
# 定義發文者（po）、評論者(cmt)、兩者兼具(both)
node_type = []

cmt_list = pos_cmt['artComter'].unique().tolist()
po_list = pos_cmt['artPoster'].unique().tolist()
both_list = list(set(cmt_list) & set(po_list))
for p in pers:
  if p in both_list:
    node_type.append('both')

  elif p in cmt_list:
    node_type.append('cmt')

  elif p in po_list:
    node_type.append('po')

# %%
net = matPresentGraph(mat = mat,node_id = pers,node_type = node_type)
net.show("./pers_netWork.html")
IPython.display.HTML('pers_netWork.html')
# Out:
# ./pers_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# 計算eigenvector centrality （無向圖）

# %%
eigenvec = np.array(list(nx.eigenvector_centrality(nx.Graph(mat_s),max_iter = 10000).values()))
eigenvec = (eigenvec-np.min(eigenvec))/(np.max(eigenvec)-np.min(eigenvec))

# %%
q = np.quantile(eigenvec,[.2,.4,.6,.8])
q
# Out:
# array([6.69500552e-33, 1.22880427e-15, 2.23944918e-13, 9.62255870e-02])

# %%
node_value = []


for i in eigenvec:

  if i > q[3]:
    node_value.append(25)
  elif i >q[2]:
    node_value.append(20)
  elif i>q[1]:
    node_value.append(15)
  elif i>q[0]:
    node_value.append(10)
  else:
    node_value.append(5)
net = matPresentGraph(mat = mat,node_id = pers,node_type = node_type,node_value = node_value,directed=False)
net.show("./pers_eig_netWork.html")
IPython.display.HTML('pers_eig_netWork.html')
# Out:
# matrix is not Symmetric
# ./pers_eig_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# 我們可以發現有多次評論的人，或是評論的文章同時有多人評論的，重要程度愈高

# %% [markdown]
# PageRank (有向圖)

# %%
# Digraph 設定有向圖
pagerank = np.array(list(nx.pagerank(nx.DiGraph(mat)).values()))
# pagerank = (pagerank-np.min(pagerank))/(np.max(pagerank)-np.min(pagerank))
pagerank
# Out:
# array([0.00113836, 0.00355845, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.0021064 , 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00404247,
#        0.00404247, 0.0021064 , 0.00113836, 0.00113836, 0.00113836,
#        0.0050105 , 0.00113836, 0.00113836, 0.00113836, 0.0021064 ,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.0021064 , 0.00113836, 0.00113836, 0.00326804, 0.00113836,
#        0.00113836, 0.0021064 , 0.0050105 , 0.00903927, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00876028, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00636575, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.02824334, 0.0021064 , 0.00113836, 0.00113836, 0.0021064 ,
#        0.00113836, 0.00113836, 0.00219096, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00184825,
#        0.00113836, 0.00113836, 0.0050105 , 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.0021064 , 0.00404247, 0.00113836,
#        0.00113836, 0.00127665, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00537351, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00170305, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.0050105 , 0.00780397,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00520411, 0.00113836, 0.0023    , 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00697884, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.01695766, 0.00113836, 0.0021064 ,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.02000219, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00307443, 0.00113836, 0.00343744, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.0021064 , 0.00113836, 0.0021064 , 0.00113836, 0.00113836,
#        0.00113836, 0.0021064 , 0.00113836, 0.00113836, 0.00113836,
#        0.00307443, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.01227076,
#        0.00113836, 0.00113836, 0.00416212, 0.00113836, 0.00113836,
#        0.00974136, 0.00423607, 0.00113836, 0.00113836, 0.00374771,
#        0.00113836, 0.03663297, 0.00113836, 0.00404247, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00436514,
#        0.00113836, 0.00113836, 0.0021064 , 0.00323577, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00403438, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00307443, 0.00292868,
#        0.00162238, 0.00694657, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00404247, 0.00113836, 0.00404247,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.0058679 , 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.0021064 , 0.00113836, 0.00113836,
#        0.00171918, 0.00113836, 0.00113836, 0.00162238, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00743059, 0.00113836,
#        0.00113836, 0.0021064 , 0.00113836, 0.00597853, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.0021064 ,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.0084454 ,
#        0.00113836, 0.00113836, 0.00646255, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00404247, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.10536344, 0.00113836,
#        0.0021064 , 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00133197, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00851386, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00307443,
#        0.00113836, 0.00113836, 0.00113836, 0.00162238, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00326804, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00355845, 0.00113836,
#        0.00113836, 0.00113836, 0.00371979, 0.00113836, 0.00113836,
#        0.00113836, 0.00141494, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.0021064 , 0.00113836,
#        0.00113836, 0.0050105 , 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00759193, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00452648, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00404247, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00146104, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00113836,
#        0.00113836, 0.00113836, 0.00113836, 0.00113836, 0.00307443,
#        0.00113836, 0.00307443, 0.00113836, 0.00113836, 0.00113836])

# %%
net = matPresentGraph(mat = mat,node_id = pers,node_type = node_type,node_value=(pagerank*1000).tolist())
net.show("./pers_page_netWork.html")
IPython.display.HTML('pers_page_netWork.html')
# Out:
# ./pers_page_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# 可以看出indegree 較多，重要程度愈高

# %% [markdown]
# Hits score （有向圖）

# %%
out_,in_ = nx.hits(nx.DiGraph(mat),max_iter=100)
out_,in_ = np.array(list(out_.values())),np.array(list(in_.values()))
out_ = (out_-np.min(out_))/(np.max(out_)-np.min(out_))
in_ = (in_-np.min(in_))/(np.max(in_)-np.min(in_))

# %%
in_q = np.quantile(in_,[.2,.4,.6,.8])
out_q = np.quantile(out_,[.2,.4,.6,.8])

# %%
in_q
# Out:
# array([4.04120020e-16, 4.07480062e-16, 4.09020356e-16, 4.13165099e-16])

# %%
node_value = []


for i in out_:
  if i > out_q[3]:
    node_value.append(25)
  elif i >out_q[2]:
    node_value.append(20)
  elif i>out_q[1]:
    node_value.append(15)
  elif i>out_q[0]:
    node_value.append(10)
  else:
    node_value.append(5)

net = matPresentGraph(mat = mat,node_id = pers,node_type = node_type,node_value=node_value)
net.show("./pers_out_netWork.html")
IPython.display.HTML('pers_out_netWork.html')
# Out:
# ./pers_out_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %%
node_value = []
for i in in_:
  if i > in_q[3]:
    node_value.append(25)
  elif i >in_q[2]:
    node_value.append(20)
  elif i>in_q[1]:
    node_value.append(15)
  elif i>in_q[0]:
    node_value.append(10)
  else:
    node_value.append(5)

net = matPresentGraph(mat = mat,node_id = pers,node_type = node_type,node_value=node_value)
net.show("./pers_in_netWork.html")
IPython.display.HTML('pers_in_netWork.html')
# Out:
# ./pers_in_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# 可以發現indegree/outdegree的多寡會決定其重要程度

# %% [markdown]
# betweenness centrality

# %%
bet = np.array(list(nx.betweenness_centrality(nx.Graph(mat_s)).values()))
bet = (bet-np.min(bet))/(np.max(bet)-np.min(bet))
bet_q = np.quantile(bet,[.2,.4,.6,.8])

# %%
node_value = []
for i in bet:
  if i > bet_q[3]:
    node_value.append(25)
  elif i > bet_q[2]:
    node_value.append(20)
  elif i>bet_q[1]:
    node_value.append(15)
  elif i>bet_q[0]:
    node_value.append(10)
  else:
    node_value.append(5)

net = matPresentGraph(mat = mat,node_id = pers,node_type = node_type,node_value=node_value)
net.show("./pers_bet_netWork.html")
IPython.display.HTML('pers_bet_netWork.html')
# Out:
# ./pers_bet_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# Transitivity/Density/Distance/Diameter/Clustering
#
# 計算最大的subgraph 的 measure

# %%
# 計算max subgraph
G = nx.Graph(mat_s)
G_sub = sorted(nx.connected_components(G), key=len, reverse=True)
G_max_sub = G.subgraph(G_sub[0])
# # 重新定義 mat
sub_mat = nx.adjacency_matrix(G_max_sub).todense()
node_idx = list(G_max_sub.nodes)
sub_pers = pers[node_idx]

# %% [markdown]
# 畫出最大subgraph

# %%
net = matPresentGraph(mat=sub_mat,node_id=sub_pers,directed=False)
net.show("./max_sub.html")
IPython.display.HTML('max_sub.html')
# Out:
# matrix is Symmetric
# ./max_sub.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# 計算transitivity

# %%
nx.transitivity(nx.Graph(sub_mat))
# Out:
# 0.0037998733375554147

# %% [markdown]
# 計算density 及 distance

# %%
nx.density(nx.Graph(sub_mat))
# Out:
# 0.009291803013776108

# %%
nx.average_shortest_path_length(nx.Graph(sub_mat))
# Out:
# 6.714782046620612

# %% [markdown]
# 計算diameter

# %%
nx.diameter(nx.Graph(sub_mat))
# Out:
# 15

# %% [markdown]
# 計算clustering

# %%
nx.average_clustering(nx.Graph(sub_mat))
# Out:
# 0.007630112787063458
