# %% [markdown]
# # 第14週 社群網路分析

# %% [markdown]
# ### Author: 蔡少懷、游兆愷、秦苡軒、陳侑萱、呂育真、李圯(音同怡)瀞、洪唯瑄、陳志翔
# ### 資料來源: 文字平台收集PTT日本旅遊版版
# ### 資料集: japan.csv
# ### 關鍵字: "東京"
# ### 資料時間: 2023/05/01 ~ 2023/05/21
# ### 資料筆數: 共 38 篇文章、300 篇回文
#
# #### 因為疫情漸漸趨緩，許多國家開放旅遊，其中以日本為最多台灣人去的地方，因此本次讀書會藉由文字平台下載PTT日本旅遊版五月份到目前為止的文章，討論日旅版上關於東京的發文風向進行網路分析。

# %%
#大家好，我們是第一組，我們針對PTT日旅板五月份的發文做社群網路分析。
#因為疫情漸漸趨緩，許多國家開放旅遊，其中以日本為最多台灣人去的地方，因此本次讀書會藉由文字平台下載PTT日本旅遊版五月份到目前為止的文章，討論日旅版上關於東京的發文風向進行網路分析。

# %%
! pip install pyvis networkx pandas numpy #在colab下載用到的套件
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyvis in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from pyvis) (7.34.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.1.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9.6->pyvis) (2.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.6)

# %%
import pandas as pd
import numpy as np
import pyvis
import networkx as nx
from pyvis import network as net
import IPython
from IPython.display import display, HTML

# %%
raw_data = pd.read_csv('./japan.csv')
raw_data = raw_data[raw_data.artComment != '[]']
raw_data = raw_data.sample(round(raw_data.shape[0]/4))
print(raw_data.shape)
raw_data.head()
# Out:
# (38, 11)
#      system_id                                             artUrl  \
# 36          37  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...
# 49          50  https://www.ptt.cc/bbs/Japan_Travel/M.16835337...
# 160        161  https://www.ptt.cc/bbs/Japan_Travel/M.16845877...
# 81          82  https://www.ptt.cc/bbs/Japan_Travel/M.16838571...
# 93          94  https://www.ptt.cc/bbs/Japan_Travel/M.16840297...
#
#                      artTitle              artDate    artPoster   artCatagory  \
# 36   [資訊]20230506JX803懶人包(暫定)  2023-05-07 02:03:39     UncleRed  Japan_Travel
# 49           [問題]帶父母第一次東京自助八天  2023-05-08 16:14:57  adychen1982  Japan_Travel
# 160       [問題]迪士尼好夥伴飯店購買迪士尼門票  2023-05-20 21:02:41        skw15  Japan_Travel
# 81                    九州自駕11月  2023-05-12 10:05:39      zonapha  Japan_Travel
# 93          [問題]住宿選擇之深夜的東京藥妝店  2023-05-14 10:02:52   shin761124  Japan_Travel
#
#                                             artContent  \
# 36   遠因跟基礎知識部分\n\n1.5/6成田機場大風，許多班機重飛或是轉降其他機場\n  (另，...
# 49   大家好：\n\n  自己是有單獨自助關西的經驗，但東京是第一次。\n\n  而且第一次就帶了...
# 160  各位大大好\n\n我跟家人將在5/25~5/30去日本東京旅遊\n\n頭幾天會住在東京灣東方...
# 81   去日本多次都是電車但是東京大阪等大城市\n\n這次是去沒去過的九州\n\n請各位大大幫我看行...
# 93   以往去東京首選一定是新宿歌舞伎町，白天跑行程，深夜回新宿吃宵夜買藥妝都方便，但隨著時間增長有...
#
#                                             artComment            e_ip  \
# 36   [{"cmtStatus": "推", "cmtPoster": "chen210121",...            None
# 49   [{"cmtStatus": "→", "cmtPoster": "kuku321", "c...   115.165.214.2
# 160  [{"cmtStatus": "→", "cmtPoster": "leejones", "...   36.227.196.88
# 81   [{"cmtStatus": "→", "cmtPoster": "borriss", "c...    39.10.10.157
# 93   [{"cmtStatus": "推", "cmtPoster": "tsuneo", "cm...  223.138.11.203
#
#             insertedDate dataSource
# 36   2023-05-09 01:51:39        ptt
# 49   2023-05-09 01:51:45        ptt
# 160  2023-05-21 02:06:14        ptt
# 81   2023-05-13 02:01:31        ptt
# 93   2023-05-15 01:49:21        ptt

# %%
#parse comment
def getComtInfo(com):
  cmters,cmt_statuss = [],[]
  com = eval(com)
  for i in com:
    print(i)
    cmters.append(i['cmtPoster'])
    cmt_statuss.append(i['cmtStatus'])
  return pd.Series([cmters, cmt_statuss])

raw_data[['artComter','artStatus']] = raw_data['artComment'].apply(lambda r: getComtInfo(r))
# Out:
# {'cmtStatus': '推', 'cmtPoster': 'chen210121', 'cmtContent': ':高調', 'cmtDate': '2023-05-07 02:05:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kyonyuumania', 'cmtContent': ':感謝分享', 'cmtDate': '2023-05-07 02:06:00'}
# {'cmtStatus': '推', 'cmtPoster': 'debby1993', 'cmtContent': ':據傳803暫定8:00飛？目前乘客發睡袋睡機場地板', 'cmtDate': '2023-05-07 02:07:00'}
# {'cmtStatus': '→', 'cmtPoster': 'soulXdancer', 'cmtContent': ':機上罵罵而已沒暴動真是奇蹟', 'cmtDate': '2023-05-07 02:08:00'}
# {'cmtStatus': '→', 'cmtPoster': 'shlee', 'cmtContent': ':暴動也沒辦法飛啊也只能罵一罵發洩一下了', 'cmtDate': '2023-05-07 02:08:00'}
# {'cmtStatus': '推', 'cmtPoster': 'YYZZKK', 'cmtContent': ':補充極度精簡版懶人包', 'cmtDate': '2023-05-07 02:08:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mithralin', 'cmtContent': ':我香草航空那次也沒有人暴動，可能是LCC乘客比較能', 'cmtDate': '2023-05-07 02:10:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mithralin', 'cmtContent': ':體諒成本因素(?)，不過有人爭取下才有飲料和早餐', 'cmtDate': '2023-05-07 02:11:00'}
# {'cmtStatus': '推', 'cmtPoster': 'purevision', 'cmtContent': ':聽說來回機票全退（？', 'cmtDate': '2023-05-07 02:12:00'}
# {'cmtStatus': '→', 'cmtPoster': 'er5820', 'cmtContent': ':睡不到5小時隔天一定很精彩', 'cmtDate': '2023-05-07 02:14:00'}
# {'cmtStatus': '推', 'cmtPoster': 'spw050693', 'cmtContent': ':推懶人包解釋', 'cmtDate': '2023-05-07 02:14:00'}
# {'cmtStatus': '推', 'cmtPoster': 'encorea84459', 'cmtContent': ':803旅客推精闢懶人包', 'cmtDate': '2023-05-07 02:14:00'}
# {'cmtStatus': '推', 'cmtPoster': 'chinick1478', 'cmtContent': ':Push', 'cmtDate': '2023-05-07 02:16:00'}
# {'cmtStatus': '推', 'cmtPoster': 'debby1993', 'cmtContent': ':800/801應該是用同組組員來回？只是delay造成超時所', 'cmtDate': '2023-05-07 02:16:00'}
# {'cmtStatus': '→', 'cmtPoster': 'debby1993', 'cmtContent': ':以只能直接取消？（待專業人士補充', 'cmtDate': '2023-05-07 02:16:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Subscript9', 'cmtContent': ':直接被洞八…', 'cmtDate': '2023-05-07 02:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'shlee', 'cmtContent': ':800從名古屋回到成田的時候已經日本時間晚上7點多', 'cmtDate': '2023-05-07 02:18:00'}
# {'cmtStatus': '→', 'cmtPoster': 'shlee', 'cmtContent': ':了那時候801的旅客應該早就跑完轉簽跟併班的手續', 'cmtDate': '2023-05-07 02:18:00'}
# {'cmtStatus': '→', 'cmtPoster': 'shlee', 'cmtContent': ':在803上面', 'cmtDate': '2023-05-07 02:18:00'}
# {'cmtStatus': '推', 'cmtPoster': 'debby1993', 'cmtContent': ':801就是沒飛機來所以直接取消，那02也不早點取消讓', 'cmtDate': '2023-05-07 02:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'debby1993', 'cmtContent': ':其他人轉簽去另外兩家，那兩家都飛了才說要取消，真', 'cmtDate': '2023-05-07 02:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'debby1993', 'cmtContent': ':的是史詩級災難……', 'cmtDate': '2023-05-07 02:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'UncleRed', 'cmtContent': ':就算那兩家還沒飛也沒位置吧，等下轉不完被說大小眼', 'cmtDate': '2023-05-07 02:24:00'}
# {'cmtStatus': '推', 'cmtPoster': 'benson1613', 'cmtContent': ':這真的超級大出事,好久沒有這樣追航空八點檔了哈哈', 'cmtDate': '2023-05-07 02:24:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mithralin', 'cmtContent': ':801團客全轉簽其他航空公司，散客改搭803', 'cmtDate': '2023-05-07 02:26:00'}
# {'cmtStatus': '推', 'cmtPoster': 'pimachu', 'cmtContent': ':看其他公司要不要出手救援不然這粽子串不完', 'cmtDate': '2023-05-07 02:27:00'}
# {'cmtStatus': '推', 'cmtPoster': 'marunouchi', 'cmtContent': ':等著看TPE跟LAX', 'cmtDate': '2023-05-07 02:27:00'}
# {'cmtStatus': '推', 'cmtPoster': 'debby1993', 'cmtContent': ':不幫轉還是有少數人會直接當場買別家飛過去，都不給', 'cmtDate': '2023-05-07 02:28:00'}
# {'cmtStatus': '→', 'cmtPoster': 'debby1993', 'cmtContent': ':人應變時間的真的糟……', 'cmtDate': '2023-05-07 02:28:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mithralin', 'cmtContent': ':這次事件應該可以寫入教科書了，負面教材方面的', 'cmtDate': '2023-05-07 02:29:00'}
# {'cmtStatus': '推', 'cmtPoster': 'umyiwen', 'cmtContent': ':有夠大包', 'cmtDate': '2023-05-07 02:31:00'}
# {'cmtStatus': '推', 'cmtPoster': 'marunouchi', 'cmtContent': ':後面一串粽子', 'cmtDate': '2023-05-07 02:31:00'}
# {'cmtStatus': '推', 'cmtPoster': 'gtayu', 'cmtContent': ':辛苦了', 'cmtDate': '2023-05-07 02:33:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ORIENT0510', 'cmtContent': ':究竟是會變成公關的災難還是業界的笑話？', 'cmtDate': '2023-05-07 02:33:00'}
# {'cmtStatus': '推', 'cmtPoster': 'roger61212', 'cmtContent': ':如果當下聯絡其他航空業者支援疏散會不會比較好，雖', 'cmtDate': '2023-05-07 02:36:00'}
# {'cmtStatus': '→', 'cmtPoster': 'roger61212', 'cmtContent': ':然重拿行李跟登入也是需要不少時間', 'cmtDate': '2023-05-07 02:36:00'}
# {'cmtStatus': '→', 'cmtPoster': 'shlee', 'cmtContent': ':要看其他航空公司的航班時間跟有沒有位置', 'cmtDate': '2023-05-07 02:37:00'}
# {'cmtStatus': '→', 'cmtPoster': 'shlee', 'cmtContent': ':801是有轉簽團客跟少部分散客給華航也有飛回來然', 'cmtDate': '2023-05-07 02:38:00'}
# {'cmtStatus': '→', 'cmtPoster': 'shlee', 'cmtContent': ':後剩餘的散客被安排搭803', 'cmtDate': '2023-05-07 02:38:00'}
# {'cmtStatus': '推', 'cmtPoster': 'tookbon', 'cmtContent': ':老實說成田這個風寧可今天不飛命要緊但星宇處理', 'cmtDate': '2023-05-07 02:41:00'}
# {'cmtStatus': '→', 'cmtPoster': 'tookbon', 'cmtContent': ':要更完整', 'cmtDate': '2023-05-07 02:41:00'}
# {'cmtStatus': '→', 'cmtPoster': 'a27281591', 'cmtContent': ':也要別家有人有時間接', 'cmtDate': '2023-05-07 02:42:00'}
# {'cmtStatus': '→', 'cmtPoster': 'a27281591', 'cmtContent': ':還好這不是在超級旺季發生否則更可怕...', 'cmtDate': '2023-05-07 02:43:00'}
# {'cmtStatus': '推', 'cmtPoster': 'pimachu', 'cmtContent': ':問題就是你團客都能轉了啊不整機轉掉', 'cmtDate': '2023-05-07 02:44:00'}
# {'cmtStatus': '推', 'cmtPoster': 'jakert123', 'cmtContent': ':感覺就是散客改搭803造成的，當初全部轉簽就沒事了', 'cmtDate': '2023-05-07 02:45:00'}
# {'cmtStatus': '→', 'cmtPoster': 'jakert123', 'cmtContent': ':，併班導致後面全部gg', 'cmtDate': '2023-05-07 02:45:00'}
# {'cmtStatus': '→', 'cmtPoster': 'wisteriachi', 'cmtContent': ':只有800跟成田風有關係，後續一連串是星宇調度問題', 'cmtDate': '2023-05-07 02:46:00'}
# {'cmtStatus': '→', 'cmtPoster': 'wisteriachi', 'cmtContent': ':。', 'cmtDate': '2023-05-07 02:46:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mithralin', 'cmtContent': ':轉簽也要其他航班飛機有空位，現在還在黃金週加上', 'cmtDate': '2023-05-07 02:49:00'}
# {'cmtStatus': '→', 'cmtPoster': 'mithralin', 'cmtContent': ':假日位置本來就不多了', 'cmtDate': '2023-05-07 02:49:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':我樂桃被關四小時那次有人直接去敲機長室的門抗議', 'cmtDate': '2023-05-07 02:50:00'}
# {'cmtStatus': '推', 'cmtPoster': 'suba1121', 'cmtContent': ':推很精闢的懶人包連轉簽的801行李狀況都有', 'cmtDate': '2023-05-07 02:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'sinohara', 'cmtContent': ':以前的強側風重落地在NH還是767老飛機的時代也有過', 'cmtDate': '2023-05-07 02:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'huang19898', 'cmtContent': ':如果暴動有沒機會下飛機?認賠刷機場住宿+第二天他', 'cmtDate': '2023-05-07 02:54:00'}
# {'cmtStatus': '→', 'cmtPoster': 'huang19898', 'cmtContent': ':家廉航機票也遠比關飛機上8個小時好', 'cmtDate': '2023-05-07 02:55:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mithralin', 'cmtContent': ':沒有機會，因為過宵禁時間人家都下班了', 'cmtDate': '2023-05-07 02:55:00'}
# {'cmtStatus': '推', 'cmtPoster': 'MTBF', 'cmtContent': ':精簡客觀', 'cmtDate': '2023-05-07 02:55:00'}
# {'cmtStatus': '→', 'cmtPoster': 'huang19898', 'cmtContent': ':如果9點之類的時間以生病之名要求下機或報警不知可', 'cmtDate': '2023-05-07 02:58:00'}
# {'cmtStatus': '→', 'cmtPoster': 'huang19898', 'cmtContent': ':不可行', 'cmtDate': '2023-05-07 02:58:00'}
# {'cmtStatus': '推', 'cmtPoster': 'jasonchiu122', 'cmtContent': ':看FB旅客的最新回報，現在都獲得成田候機室地板體', 'cmtDate': '2023-05-07 02:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'jasonchiu122', 'cmtContent': ':驗券一張', 'cmtDate': '2023-05-07 02:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':如果是119或110的方式出艙門的話後果應該滿有趣的..', 'cmtDate': '2023-05-07 02:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':因為不是台灣，是日本。是成田機場不是成田車站。', 'cmtDate': '2023-05-07 03:00:00'}
# {'cmtStatus': '→', 'cmtPoster': 'er5820', 'cmtContent': ':社團桃園飛美國罵聲連連有給飯店4人一間只有30個房', 'cmtDate': '2023-05-07 03:02:00'}
# {'cmtStatus': '→', 'cmtPoster': 'er5820', 'cmtContent': ':間', 'cmtDate': '2023-05-07 03:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'phoebe147', 'cmtContent': ':臉書一堆看不懂新聞再罵乘客的，哭啊', 'cmtDate': '2023-05-07 03:06:00'}
# {'cmtStatus': '推', 'cmtPoster': 'huang19898', 'cmtContent': ':110或119的方式出艙門會違反飛安法嗎?', 'cmtDate': '2023-05-07 03:14:00'}
# {'cmtStatus': '推', 'cmtPoster': 'S890127', 'cmtContent': ':早上那個強風轉降還算是情有可原，安全要緊', 'cmtDate': '2023-05-07 03:14:00'}
# {'cmtStatus': '→', 'cmtPoster': 'S890127', 'cmtContent': ':那時候怪星宇沒道理但後面調度處理太糟糕了', 'cmtDate': '2023-05-07 03:15:00'}
# {'cmtStatus': '→', 'cmtPoster': 'TheoEpstein', 'cmtContent': ':推一個懶人包', 'cmtDate': '2023-05-07 03:16:00'}
# {'cmtStatus': '→', 'cmtPoster': 'S890127', 'cmtContent': ':這個只有賠機票錢根本不夠', 'cmtDate': '2023-05-07 03:16:00'}
# {'cmtStatus': '→', 'cmtPoster': 'S890127', 'cmtContent': ':行程延誤大亂還被關在飛機上最後睡機場地板', 'cmtDate': '2023-05-07 03:16:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':對阿，有保不便險的人虧大了....', 'cmtDate': '2023-05-07 03:18:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':有沒有違反飛安法不知道，但在機場謊報應該很刺激', 'cmtDate': '2023-05-07 03:19:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':我去年在沖繩看到有人倒路邊沒確認就打110，警察來', 'cmtDate': '2023-05-07 03:20:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':了之後看到是爛醉就唸了我一下要我先確認再打電話..', 'cmtDate': '2023-05-07 03:21:00'}
# {'cmtStatus': '推', 'cmtPoster': 'TheoEpstein', 'cmtContent': ':現在就退不了關了', 'cmtDate': '2023-05-07 03:23:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yanwu0105', 'cmtContent': ':18年也有遇到成田宵禁但捷星有讓我們退關補償全額', 'cmtDate': '2023-05-07 03:40:00'}
# {'cmtStatus': '→', 'cmtPoster': 'yanwu0105', 'cmtContent': ':食物計程車飯店費隔天原機飛回台灣', 'cmtDate': '2023-05-07 03:40:00'}
# {'cmtStatus': '推', 'cmtPoster': 'chewthelife8', 'cmtContent': ':真的是直接被洞八….當過兵的都知道洞八的痛苦', 'cmtDate': '2023-05-07 03:48:00'}
# {'cmtStatus': '→', 'cmtPoster': 'yaoilot', 'cmtContent': ':疫情前酷航高雄飛機壞了，過宵禁還是有退關送去旅館', 'cmtDate': '2023-05-07 03:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'yaoilot', 'cmtContent': ':，所以日本那邊移民署跟海關是時間到準時打卡下班', 'cmtDate': '2023-05-07 03:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'yaoilot', 'cmtContent': ':嗎？', 'cmtDate': '2023-05-07 03:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'lovejay52012', 'cmtContent': ':誰會幫他們家啊............', 'cmtDate': '2023-05-07 03:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'er5820', 'cmtContent': ':酷航是大阪機場是24小時影藝跟成田不一樣', 'cmtDate': '2023-05-07 03:53:00'}
# {'cmtStatus': '推', 'cmtPoster': 'MTBF', 'cmtContent': ':是成田宵禁關場移民官海關就下班', 'cmtDate': '2023-05-07 03:54:00'}
# {'cmtStatus': '→', 'cmtPoster': 'MTBF', 'cmtContent': ':捷星有辦法協調退關是他們有本事', 'cmtDate': '2023-05-07 03:54:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':記得捷星後台是JAL，可能是本國班機比較好處理？', 'cmtDate': '2023-05-07 03:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'carolyntsai', 'cmtContent': ':跟主不主場有關係嗎?', 'cmtDate': '2023-05-07 03:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'carolyntsai', 'cmtContent': ':我是想問,是不是跟主場也有關係?', 'cmtDate': '2023-05-07 04:01:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':我覺得有可能，我幾年前搭往高雄的樂桃因故降落桃園', 'cmtDate': '2023-05-07 04:01:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':出不去也是因為飛機國籍問題', 'cmtDate': '2023-05-07 04:01:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Misako', 'cmtContent': ':調度問題吧危機處理很差，講真的飛不了早點出來說明', 'cmtDate': '2023-05-07 04:11:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Misako', 'cmtContent': ':或安排乘客下機休息也好過現在這樣，根本是最爛的處', 'cmtDate': '2023-05-07 04:11:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Misako', 'cmtContent': ':理方式', 'cmtDate': '2023-05-07 04:11:00'}
# {'cmtStatus': '推', 'cmtPoster': 'cching1021', 'cmtContent': ':801轉簽轉不了的直接送旅館讓803自己正常起飛就', 'cmtDate': '2023-05-07 04:13:00'}
# {'cmtStatus': '→', 'cmtPoster': 'cching1021', 'cmtContent': ':什麼事都不會有', 'cmtDate': '2023-05-07 04:13:00'}
# {'cmtStatus': '推', 'cmtPoster': 'asdfgh369', 'cmtContent': ':801跟803的大大們都辛苦了...這處理真的太誇張', 'cmtDate': '2023-05-07 04:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'tprktpps', 'cmtContent': ':星宇調度真的爛不應該併班就算了機組人員超時時', 'cmtDate': '2023-05-07 04:48:00'}
# {'cmtStatus': '→', 'cmtPoster': 'tprktpps', 'cmtContent': ':也早該放人下機想也知道今天肯定無法起飛了高層', 'cmtDate': '2023-05-07 04:48:00'}
# {'cmtStatus': '→', 'cmtPoster': 'tprktpps', 'cmtContent': ':真的有病', 'cmtDate': '2023-05-07 04:48:00'}
# {'cmtStatus': '推', 'cmtPoster': 'gm3252', 'cmtContent': ':旅客這麼生氣還有一點是是被關在飛機上太久，早點', 'cmtDate': '2023-05-07 05:31:00'}
# {'cmtStatus': '→', 'cmtPoster': 'gm3252', 'cmtContent': ':放人到機場還不會這麼嚴重', 'cmtDate': '2023-05-07 05:31:00'}
# {'cmtStatus': '推', 'cmtPoster': 'encorea84459', 'cmtContent': ':而且8點那時說要延到11點就有乘客反應宵禁問題了', 'cmtDate': '2023-05-07 05:33:00'}
# {'cmtStatus': '→', 'cmtPoster': 'encorea84459', 'cmtContent': ':完全不管硬要賭真的是扯爛', 'cmtDate': '2023-05-07 05:33:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Taku1003', 'cmtContent': ':原801乘客淚推…為什麼不把我轉簽出去', 'cmtDate': '2023-05-07 05:48:00'}
# {'cmtStatus': '推', 'cmtPoster': 'darrenh', 'cmtContent': ':所以jx2有飛嗎？', 'cmtDate': '2023-05-07 05:48:00'}
# {'cmtStatus': '推', 'cmtPoster': 'naoko10078', 'cmtContent': ':搭今天800的瑟瑟發抖', 'cmtDate': '2023-05-07 05:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'darrenh', 'cmtContent': ':樓上應該已經在機場了吧？有飛？', 'cmtDate': '2023-05-07 05:58:00'}
# {'cmtStatus': '推', 'cmtPoster': 'naoko10078', 'cmtContent': ':前往機場路上', 'cmtDate': '2023-05-07 06:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'darrenh', 'cmtContent': ':今天到底有沒有飛機可以飛800，我看桃機寫正常', 'cmtDate': '2023-05-07 06:03:00'}
# {'cmtStatus': '推', 'cmtPoster': 'naoko10078', 'cmtContent': ':看星宇網站動態也都是正常', 'cmtDate': '2023-05-07 06:05:00'}
# {'cmtStatus': '推', 'cmtPoster': 'nolimits', 'cmtContent': ':虎航也有飛成田的吧怎麼就沒有問題？', 'cmtDate': '2023-05-07 06:18:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Vladivostok', 'cmtContent': ':要是其他兩家這樣應該幹譙到翻了吧', 'cmtDate': '2023-05-07 06:20:00'}
# {'cmtStatus': '推', 'cmtPoster': 'naoko10078', 'cmtContent': ':看起來今早800是正常', 'cmtDate': '2023-05-07 06:28:00'}
# {'cmtStatus': '推', 'cmtPoster': 'TT', 'cmtContent': ':昨天正好是延遲一下起飛的CI103，風超大超晃', 'cmtDate': '2023-05-07 06:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'TT', 'cmtContent': ':主要看起來是後續處理的太糟，好險都平安', 'cmtDate': '2023-05-07 06:30:00'}
# {'cmtStatus': '推', 'cmtPoster': 'zxc11234', 'cmtContent': ':天氣因素的話也沒什麼好說的，但很明顯就是星宇完', 'cmtDate': '2023-05-07 06:32:00'}
# {'cmtStatus': '→', 'cmtPoster': 'zxc11234', 'cmtContent': ':全沒有危機處理能力，一個大風就把問題吹出來，以', 'cmtDate': '2023-05-07 06:32:00'}
# {'cmtStatus': '→', 'cmtPoster': 'zxc11234', 'cmtContent': ':後直接列入黑名單了，我猜補償應該會很豐厚不然壓', 'cmtDate': '2023-05-07 06:32:00'}
# {'cmtStatus': '→', 'cmtPoster': 'zxc11234', 'cmtContent': ':不下來', 'cmtDate': '2023-05-07 06:32:00'}
# {'cmtStatus': '→', 'cmtPoster': 'lcchang', 'cmtContent': ':目前日本時間07:38，還在成田躺睡袋還沒有任何登機', 'cmtDate': '2023-05-07 06:39:00'}
# {'cmtStatus': '→', 'cmtPoster': 'lcchang', 'cmtContent': ':消息', 'cmtDate': '2023-05-07 06:39:00'}
# {'cmtStatus': '→', 'cmtPoster': 'encorea84459', 'cmtContent': ':是我沒睡醒還是怎樣剛說要拆三班？', 'cmtDate': '2023-05-07 06:43:00'}
# {'cmtStatus': '推', 'cmtPoster': 'S890127', 'cmtContent': ':話說如果有人買要冰的土產(Royce之類)不就報銷了', 'cmtDate': '2023-05-07 07:12:00'}
# {'cmtStatus': '→', 'cmtPoster': 'S890127', 'cmtContent': ':雖然這相較之下沒那麼重要了', 'cmtDate': '2023-05-07 07:12:00'}
# {'cmtStatus': '推', 'cmtPoster': 'jtsu5223', 'cmtContent': ':好慘', 'cmtDate': '2023-05-07 07:15:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Yumon', 'cmtContent': ':要冰的土產可能就打開吃了吧', 'cmtDate': '2023-05-07 07:16:00'}
# {'cmtStatus': '推', 'cmtPoster': 'TT', 'cmtContent': ':這有買旅平險應該能利用到，沒買就真的慘', 'cmtDate': '2023-05-07 07:20:00'}
# {'cmtStatus': '推', 'cmtPoster': 'nuc1earsub', 'cmtContent': ':董欸不是去現場了?', 'cmtDate': '2023-05-07 07:23:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':這次的狀況是不便險的賠償範圍吧？', 'cmtDate': '2023-05-07 07:25:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kenploin', 'cmtContent': ':這家這樣搞絕對不搭呀處理很糟糕', 'cmtDate': '2023-05-07 07:35:00'}
# {'cmtStatus': '推', 'cmtPoster': 'inewhand', 'cmtContent': ':兩班乘客跟機組都辛苦了，卡一個等後續', 'cmtDate': '2023-05-07 07:42:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':剛想到星宇這樣搞，不便險的理賠金額可能也不太樂觀', 'cmtDate': '2023-05-07 07:52:00'}
# {'cmtStatus': '推', 'cmtPoster': 'applebob', 'cmtContent': ':明天要飛怕...', 'cmtDate': '2023-05-07 07:56:00'}
# {'cmtStatus': '推', 'cmtPoster': 'TT', 'cmtContent': ':就超過四小時+行程延誤這兩款項能領吧', 'cmtDate': '2023-05-07 07:56:00'}
# {'cmtStatus': '→', 'cmtPoster': 'chie24', 'cmtContent': ':行李延誤要看有的回國段不賠……', 'cmtDate': '2023-05-07 08:01:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':我之前搭樂桃沖繩高雄沖繩的環線班機申請理賠時弄很', 'cmtDate': '2023-05-07 08:02:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':久，而且同班機專員的判斷居然不一樣害我少領一筆', 'cmtDate': '2023-05-07 08:03:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Bokaka', 'cmtContent': ':航空板說k董還得幫忙開飛機回來XD', 'cmtDate': '2023-05-07 08:03:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':星宇這趟最想哭的應該是沒有「過夜補助」', 'cmtDate': '2023-05-07 08:04:00'}
# {'cmtStatus': '→', 'cmtPoster': 'chie24', 'cmtContent': ':用睡袋換滯留旅客住宿費用賺爛，我說星宇賺爛', 'cmtDate': '2023-05-07 08:07:00'}
# {'cmtStatus': '推', 'cmtPoster': 'TT', 'cmtContent': ':新企畫夜宿成田機場(無料)', 'cmtDate': '2023-05-07 08:10:00'}
# {'cmtStatus': '推', 'cmtPoster': 'greenfetish', 'cmtContent': ':所以被關在機上多久啊？待候機室我能忍，被關機上', 'cmtDate': '2023-05-07 08:23:00'}
# {'cmtStatus': '→', 'cmtPoster': 'greenfetish', 'cmtContent': ':那小空間真心不能忍', 'cmtDate': '2023-05-07 08:23:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Serio', 'cmtContent': ':行李延誤要看保險怎寫之前我PEK-TPE行李沒上飛機', 'cmtDate': '2023-05-07 08:27:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Serio', 'cmtContent': ':最後也沒賠(因為已經回國沒有影響衣住等)', 'cmtDate': '2023-05-07 08:28:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Serio', 'cmtContent': ':行程延誤這應該算人為非天候(大雪)應該有辦法拿', 'cmtDate': '2023-05-07 08:29:00'}
# {'cmtStatus': '推', 'cmtPoster': 'IUOIUOIUO', 'cmtContent': ':開始需要看這次事件哪些保險有賠了感覺沒那麼簡單', 'cmtDate': '2023-05-07 08:30:00'}
# {'cmtStatus': '→', 'cmtPoster': 'w2776803', 'cmtContent': ':這個人為疏失居多吧換成自己被關在機上，機組員只會', 'cmtDate': '2023-05-07 08:33:00'}
# {'cmtStatus': '→', 'cmtPoster': 'w2776803', 'cmtContent': ':說等，雖然基層無辜，但旅客生氣也正常', 'cmtDate': '2023-05-07 08:33:00'}
# {'cmtStatus': '推', 'cmtPoster': 'BNT5566', 'cmtContent': ':關在機上7小時啦18-01', 'cmtDate': '2023-05-07 08:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'BNT5566', 'cmtContent': ':重點過程中沒持續更新消息，導致大家都不知在等啥', 'cmtDate': '2023-05-07 08:45:00'}
# {'cmtStatus': '→', 'cmtPoster': 'alwayspink', 'cmtContent': ':樓上那真的會很無力無助', 'cmtDate': '2023-05-07 08:47:00'}
# {'cmtStatus': '→', 'cmtPoster': 'IUOIUOIUO', 'cmtContent': ':機上關玩換關機場總共到底多久800跟803', 'cmtDate': '2023-05-07 08:48:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kwinner', 'cmtContent': ':長榮和華航會怎麼處理？', 'cmtDate': '2023-05-07 08:49:00'}
# {'cmtStatus': '→', 'cmtPoster': 'IUOIUOIUO', 'cmtContent': ':長榮一開始就會降落成功華航會一堆飛機載人回來', 'cmtDate': '2023-05-07 08:50:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kwinner', 'cmtContent': ':誰在乎飛機駕駛是誰？什麼飛才是重點行李、住宿、', 'cmtDate': '2023-05-07 08:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kwinner', 'cmtContent': ':餐點', 'cmtDate': '2023-05-07 08:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'foreverfree', 'cmtContent': ':調度真的雷，廉航都沒看過這麼大的包', 'cmtDate': '2023-05-07 08:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'autumoon', 'cmtContent': ':在這之前我以為我被樂桃關艙四小時重返原地已經夠慘', 'cmtDate': '2023-05-07 08:52:00'}
# {'cmtStatus': '→', 'cmtPoster': 'chinick1478', 'cmtContent': ':今天801也延誤囉～', 'cmtDate': '2023-05-07 08:53:00'}
# {'cmtStatus': '推', 'cmtPoster': 'cmelo1515', 'cmtContent': ':800的乘客張董會給壓驚補貼嗎', 'cmtDate': '2023-05-07 08:59:00'}
# {'cmtStatus': '推', 'cmtPoster': 'vashwu', 'cmtContent': ':沒事啦再找兩個網紅開箱經濟艙餐點就好', 'cmtDate': '2023-05-07 09:04:00'}
# {'cmtStatus': '推', 'cmtPoster': 'IUOIUOIUO', 'cmtContent': ':順便推出800特調803特調期間限定', 'cmtDate': '2023-05-07 09:05:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Jelen', 'cmtContent': ':辛苦旅客了', 'cmtDate': '2023-05-07 09:07:00'}
# {'cmtStatus': '推', 'cmtPoster': 's91ad017', 'cmtContent': ':申請理賠看起來可以選班機延誤，本來還可以選旅遊', 'cmtDate': '2023-05-07 09:11:00'}
# {'cmtStatus': '→', 'cmtPoster': 's91ad017', 'cmtContent': ':更改(但因為沒有住宿交通的費用，睡機場)', 'cmtDate': '2023-05-07 09:11:00'}
# {'cmtStatus': '推', 'cmtPoster': 'n196t', 'cmtContent': ':調度雷暴', 'cmtDate': '2023-05-07 09:13:00'}
# {'cmtStatus': '推', 'cmtPoster': 'willieliu', 'cmtContent': ':推精品廉航', 'cmtDate': '2023-05-07 09:13:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kiromomo168', 'cmtContent': ':退機票以外也要給補償金吧，人家都被困在飛機上好幾', 'cmtDate': '2023-05-07 09:14:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kiromomo168', 'cmtContent': ':個小時還被迫睡機場地板', 'cmtDate': '2023-05-07 09:14:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kadolong', 'cmtContent': ':張董親自道歉又有消息全退了好了啦', 'cmtDate': '2023-05-07 09:15:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kadolong', 'cmtContent': ':還要貪補償金咧這樣算時薪300好了', 'cmtDate': '2023-05-07 09:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'wlmily', 'cmtContent': ':全退是應該的好嗎？', 'cmtDate': '2023-05-07 09:17:00'}
# {'cmtStatus': '→', 'cmtPoster': 'adort', 'cmtContent': ':兩架在成田只有一班要載客回來嗎', 'cmtDate': '2023-05-07 09:18:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kadolong', 'cmtContent': ':精神賠償和住宿費也順便好了', 'cmtDate': '2023-05-07 09:18:00'}
# {'cmtStatus': '推', 'cmtPoster': 'sendtreepad', 'cmtContent': ':兩架359都在空中了，裡面都沒乘客', 'cmtDate': '2023-05-07 09:18:00'}
# {'cmtStatus': '→', 'cmtPoster': 'wlmily', 'cmtContent': ':張董道歉又怎樣==道歉是基本的吧....讓他自己被關', 'cmtDate': '2023-05-07 09:19:00'}
# {'cmtStatus': '→', 'cmtPoster': 'wlmily', 'cmtContent': ':在飛機上沒得吃沒得喝試看看啦', 'cmtDate': '2023-05-07 09:19:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ttnakafzcm', 'cmtContent': ':801D803D都是空的.....', 'cmtDate': '2023-05-07 09:19:00'}
# {'cmtStatus': '推', 'cmtPoster': 'playerst', 'cmtContent': ':這次神調度不管賠償是啥都會讓人以後對星宇航空', 'cmtDate': '2023-05-07 09:20:00'}
# {'cmtStatus': '→', 'cmtPoster': 'playerst', 'cmtContent': ':怯步太可怕', 'cmtDate': '2023-05-07 09:20:00'}
# {'cmtStatus': '推', 'cmtPoster': 's860382', 'cmtContent': ':關在機上好幾個小時真的會火爆', 'cmtDate': '2023-05-07 09:21:00'}
# {'cmtStatus': '→', 'cmtPoster': 's860382', 'cmtContent': ':而且也不是單純天候因素', 'cmtDate': '2023-05-07 09:21:00'}
# {'cmtStatus': '推', 'cmtPoster': 'vashwu', 'cmtContent': ':人家董ㄟ怎麼可能跟你睡地板包睡袋刁民', 'cmtDate': '2023-05-07 09:21:00'}
# {'cmtStatus': '推', 'cmtPoster': 'toole', 'cmtContent': ':兩班都空機回來？不太可能吧這什麼鬼決策', 'cmtDate': '2023-05-07 09:23:00'}
# {'cmtStatus': '推', 'cmtPoster': 'IUOIUOIUO', 'cmtContent': ':今天早上803到底有沒有載人原本803旅客呢', 'cmtDate': '2023-05-07 09:23:00'}
# {'cmtStatus': '推', 'cmtPoster': 'as981134', 'cmtContent': ':阿就機組員超時啊沒辦法載客', 'cmtDate': '2023-05-07 09:24:00'}
# {'cmtStatus': '→', 'cmtPoster': 'as981134', 'cmtContent': ':原本的803有另一台飛機去載了', 'cmtDate': '2023-05-07 09:24:00'}
# {'cmtStatus': '推', 'cmtPoster': 'chinick1478', 'cmtContent': ':聽說張國煒已經開空機回來旅客繼續等', 'cmtDate': '2023-05-07 09:24:00'}
# {'cmtStatus': '→', 'cmtPoster': 'IUOIUOIUO', 'cmtContent': ':803旅客早上沒有登機嗎', 'cmtDate': '2023-05-07 09:24:00'}
# {'cmtStatus': '推', 'cmtPoster': 'bigdodoro', 'cmtContent': ':原本803沒載人只載行李', 'cmtDate': '2023-05-07 09:24:00'}
# {'cmtStatus': '→', 'cmtPoster': 'volcom', 'cmtContent': ':算一算虧個上千萬應該有，不過企業名聲比較重要', 'cmtDate': '2023-05-07 09:25:00'}
# {'cmtStatus': '→', 'cmtPoster': 'bigdodoro', 'cmtContent': ':有派加班機但不夠全載803部份803要等801', 'cmtDate': '2023-05-07 09:25:00'}
# {'cmtStatus': '→', 'cmtPoster': 'bigdodoro', 'cmtContent': ':航空版有現場大大分享', 'cmtDate': '2023-05-07 09:25:00'}
# {'cmtStatus': '推', 'cmtPoster': 'bockychen727', 'cmtContent': ':不知退的是什麼？該不會是代金劵？', 'cmtDate': '2023-05-07 09:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'chinick1478', 'cmtContent': ':今天Jx800後推延誤一小時', 'cmtDate': '2023-05-07 09:31:00'}
# {'cmtStatus': '→', 'cmtPoster': 'eveningcloud', 'cmtContent': ':之前遇過其他航空公司因為鳥襲回降後沒班機，', 'cmtDate': '2023-05-07 09:31:00'}
# {'cmtStatus': '→', 'cmtPoster': 'eveningcloud', 'cmtContent': ':過夜就是送我們去旅館...隔天再搭', 'cmtDate': '2023-05-07 09:32:00'}
# {'cmtStatus': '推', 'cmtPoster': 'bigdodoro', 'cmtContent': ':801感覺也要delay了', 'cmtDate': '2023-05-07 09:32:00'}
# {'cmtStatus': '→', 'cmtPoster': 'eveningcloud', 'cmtContent': ':現在新聞稿就是想推給怪風你們睡機場都是怪風的錯~', 'cmtDate': '2023-05-07 09:33:00'}
# {'cmtStatus': '推', 'cmtPoster': 'windletterz', 'cmtContent': ':應該只有低能兒會認同星宇操作合理，搞成這樣都', 'cmtDate': '2023-05-07 09:34:00'}
# {'cmtStatus': '→', 'cmtPoster': 'windletterz', 'cmtContent': ':是天氣的問題', 'cmtDate': '2023-05-07 09:34:00'}
# {'cmtStatus': '→', 'cmtPoster': 'eveningcloud', 'cmtContent': ':那還好我那班美國航空沒有怪鳥叫我睡機場', 'cmtDate': '2023-05-07 09:34:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Lindbergh', 'cmtContent': ':800還是350去理論上可以接回所有的旅客現在返程', 'cmtDate': '2023-05-07 09:35:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Lindbergh', 'cmtContent': ':那兩架應該一架802一架002吧', 'cmtDate': '2023-05-07 09:35:00'}
# {'cmtStatus': '推', 'cmtPoster': 'vashwu', 'cmtContent': ':整個成田就你星宇會碰怪風其他航空都不會', 'cmtDate': '2023-05-07 09:35:00'}
# {'cmtStatus': '→', 'cmtPoster': 'windletterz', 'cmtContent': ':A350開過去只載行李，我他媽真的長知識了', 'cmtDate': '2023-05-07 09:36:00'}
# {'cmtStatus': '推', 'cmtPoster': 'venusmoon', 'cmtContent': ':這公司很糟明明是自己處理不好', 'cmtDate': '2023-05-07 09:36:00'}
# {'cmtStatus': '→', 'cmtPoster': 'venusmoon', 'cmtContent': ':現在想轉移開始怪東怪西', 'cmtDate': '2023-05-07 09:36:00'}
# {'cmtStatus': '推', 'cmtPoster': 'sendtreepad', 'cmtContent': ':沒有特地開359去載行李啦，現在兩架空的359是昨天', 'cmtDate': '2023-05-07 09:37:00'}
# {'cmtStatus': '→', 'cmtPoster': 'sendtreepad', 'cmtContent': ':就被關在成田的', 'cmtDate': '2023-05-07 09:37:00'}
# {'cmtStatus': '→', 'cmtPoster': 'sendtreepad', 'cmtContent': ':K是搭其他家去成田接其中一台359回來的', 'cmtDate': '2023-05-07 09:37:00'}
# {'cmtStatus': '→', 'cmtPoster': 'chinick1478', 'cmtContent': ':早上A32N載不回所有乘客現在還在喬吧', 'cmtDate': '2023-05-07 09:38:00'}
# {'cmtStatus': '→', 'cmtPoster': 'sendtreepad', 'cmtContent': ':今天800的359去到那邊也要接今天的801乘客，昨天的', 'cmtDate': '2023-05-07 09:39:00'}
# {'cmtStatus': '→', 'cmtPoster': 'sendtreepad', 'cmtContent': ':801、803乘客沒辦法都上今天的801', 'cmtDate': '2023-05-07 09:39:00'}
# {'cmtStatus': '推', 'cmtPoster': 'cherokee2006', 'cmtContent': ':不怕不怕，再找個網紅置入一下又可打著台式精緻服', 'cmtDate': '2023-05-07 09:39:00'}
# {'cmtStatus': '→', 'cmtPoster': 'cherokee2006', 'cmtContent': ':務的招牌攬客了。誒，我說了再嗎？', 'cmtDate': '2023-05-07 09:39:00'}
# {'cmtStatus': '推', 'cmtPoster': 'windletterz', 'cmtContent': ':抱歉，應該是開回來只載行李，s大說的對', 'cmtDate': '2023-05-07 09:41:00'}
# {'cmtStatus': '→', 'cmtPoster': 'windletterz', 'cmtContent': ':應該是為了洛杉磯的航線，不論怎樣都要把飛機拉', 'cmtDate': '2023-05-07 09:41:00'}
# {'cmtStatus': '→', 'cmtPoster': 'windletterz', 'cmtContent': ':回來', 'cmtDate': '2023-05-07 09:41:00'}
# {'cmtStatus': '推', 'cmtPoster': 'raymond501', 'cmtContent': ':星宇該降價了吧還沒認清自己定位是嗎', 'cmtDate': '2023-05-07 09:41:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kakashi71', 'cmtContent': ':乘客們辛苦了…還好今天還是星期日', 'cmtDate': '2023-05-07 09:42:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kakashi71', 'cmtContent': ':沒影響到上班日', 'cmtDate': '2023-05-07 09:42:00'}
# {'cmtStatus': '推', 'cmtPoster': 'quatre00', 'cmtContent': ':爛透了', 'cmtDate': '2023-05-07 09:43:00'}
# {'cmtStatus': '→', 'cmtPoster': 'nepson', 'cmtContent': ':801跟803到底能回家了沒好可憐', 'cmtDate': '2023-05-07 09:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'cherokee2006', 'cmtContent': ':還有人要降價？鄉民不懂什麽是台式精緻服務吧', 'cmtDate': '2023-05-07 09:48:00'}
# {'cmtStatus': '推', 'cmtPoster': 't21', 'cmtContent': ':機組搭華航ci222到羽田,再到成田機場，23:52申請起', 'cmtDate': '2023-05-07 09:48:00'}
# {'cmtStatus': '→', 'cmtPoster': 't21', 'cmtContent': ':飛，結果成田機場不准。', 'cmtDate': '2023-05-07 09:48:00'}
# {'cmtStatus': '→', 'cmtPoster': 't21', 'cmtContent': ':討論區有人說的', 'cmtDate': '2023-05-07 09:48:00'}
# {'cmtStatus': '推', 'cmtPoster': 'IUOIUOIUO', 'cmtContent': ':臉書k董出現很多人覺得帥氣感動真的嗎', 'cmtDate': '2023-05-07 09:49:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ntouma', 'cmtContent': ':目前有少部分人登機了（加班載不回全部）其他還在', 'cmtDate': '2023-05-07 09:49:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ntouma', 'cmtContent': ':等', 'cmtDate': '2023-05-07 09:49:00'}
# {'cmtStatus': '→', 'cmtPoster': 'IUOIUOIUO', 'cmtContent': ':難道只有我活在反指標世界', 'cmtDate': '2023-05-07 09:49:00'}
# {'cmtStatus': '推', 'cmtPoster': 'bala73', 'cmtContent': ':朝聖各種技術問題', 'cmtDate': '2023-05-07 09:50:00'}
# {'cmtStatus': '推', 'cmtPoster': 'windletterz', 'cmtContent': ':如果他說一個人補償十萬現金的話，我就信', 'cmtDate': '2023-05-07 09:50:00'}
# {'cmtStatus': '推', 'cmtPoster': 'asclepias', 'cmtContent': ':這樣調度危機對企業是個傷害', 'cmtDate': '2023-05-07 09:50:00'}
# {'cmtStatus': '→', 'cmtPoster': 't21', 'cmtContent': ':一部分人搭今天201,一部分人搭203.我剛看影片。k董', 'cmtDate': '2023-05-07 09:50:00'}
# {'cmtStatus': '→', 'cmtPoster': 't21', 'cmtContent': ':是這樣說的。無法全部一起載回來', 'cmtDate': '2023-05-07 09:50:00'}
# {'cmtStatus': '→', 'cmtPoster': 't21', 'cmtContent': ':所以影片才有K董是為昨天差幾十分就可以起飛', 'cmtDate': '2023-05-07 09:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'BigBird110', 'cmtContent': ':帥氣感動?甲賽啦能回家比較實在', 'cmtDate': '2023-05-07 09:54:00'}
# {'cmtStatus': '推', 'cmtPoster': 'vashwu', 'cmtContent': ':人家想來就來想走就走還不夠帥氣嗎?什麼沒飛機?', 'cmtDate': '2023-05-07 09:56:00'}
# {'cmtStatus': '推', 'cmtPoster': 'u1988926', 'cmtContent': ':臉書已經一片祥和各種董仔了不起負責', 'cmtDate': '2023-05-07 09:56:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ray0208', 'cmtContent': ':明明就是高層人為決策錯誤導致一連串災難，公關付', 'cmtDate': '2023-05-07 09:57:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ray0208', 'cmtContent': ':錢要開始帶風向帶成是天氣因素，K董大器負責了', 'cmtDate': '2023-05-07 09:57:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ttnakafzcm', 'cmtContent': ':因為組員不夠法規有規定有多少人就要多少組員', 'cmtDate': '2023-05-07 09:58:00'}
# {'cmtStatus': '推', 'cmtPoster': 'SteveVai', 'cmtContent': ':為啥兩台A359不載人要空的回來啊？趕時間嗎？', 'cmtDate': '2023-05-07 09:58:00'}
# {'cmtStatus': '推', 'cmtPoster': 'playerst', 'cmtContent': ':如果星宇是這樣的態度處理問題那我以後真的不敢搭', 'cmtDate': '2023-05-07 09:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'playerst', 'cmtContent': ':了XD', 'cmtDate': '2023-05-07 09:59:00'}
# {'cmtStatus': '推', 'cmtPoster': 'metallolly', 'cmtContent': ':誰敢搭啊我看來就是推給日本機場然後旅客得罪了也', 'cmtDate': '2023-05-07 10:00:00'}
# {'cmtStatus': '→', 'cmtPoster': 'metallolly', 'cmtContent': ':無所謂了', 'cmtDate': '2023-05-07 10:00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yjjs', 'cmtContent': ':就是賭日本會放殊不知人家就是照規矩來', 'cmtDate': '2023-05-07 10:00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'vashwu', 'cmtContent': ':本來就無所謂拿老爸的錢來揮霍而已王子復仇記懂?', 'cmtDate': '2023-05-07 10:01:00'}
# {'cmtStatus': '推', 'cmtPoster': 't21', 'cmtContent': ':因為空服員工不夠。所以才空機回來。聽說載行李', 'cmtDate': '2023-05-07 10:01:00'}
# {'cmtStatus': '→', 'cmtPoster': 'yjjs', 'cmtContent': ':直接退關801散客問題就小多了這這危機處理真嚇人', 'cmtDate': '2023-05-07 10:01:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yokomata', 'cmtContent': ':看到老闆來卻開著空機走，我要是旅客心都涼了', 'cmtDate': '2023-05-07 10:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'metallolly', 'cmtContent': ':還沒帶早餐..-.-', 'cmtDate': '2023-05-07 10:04:00'}
# {'cmtStatus': '推', 'cmtPoster': 'toole', 'cmtContent': ':去了也沒讓人發早餐券安撫一下有夠廢', 'cmtDate': '2023-05-07 10:04:00'}
# {'cmtStatus': '推', 'cmtPoster': 'SteveVai', 'cmtContent': ':看到了，航空版好像有說組員不夠不合法', 'cmtDate': '2023-05-07 10:05:00'}
# {'cmtStatus': '→', 'cmtPoster': 'A00610lol', 'cmtContent': ':哈哈星宇優越粉快出來吧', 'cmtDate': '2023-05-07 10:05:00'}
# {'cmtStatus': '推', 'cmtPoster': 'danielpupu20', 'cmtContent': ':老闆是搭最早捷星去的。', 'cmtDate': '2023-05-07 10:06:00'}
# {'cmtStatus': '推', 'cmtPoster': 'griffick', 'cmtContent': ':感覺是星宇調度問題比較大，自以為精品航空，但處', 'cmtDate': '2023-05-07 10:07:00'}
# {'cmtStatus': '→', 'cmtPoster': 'griffick', 'cmtContent': ':理問題的sop跟態度比較像贗品航空', 'cmtDate': '2023-05-07 10:07:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ichiro0805', 'cmtContent': ':精品航空也跟廉航一樣', 'cmtDate': '2023-05-07 10:07:00'}
# {'cmtStatus': '推', 'cmtPoster': 'raymond501', 'cmtContent': ':沒有後勤又不是廉航票價根本是來亂的吧', 'cmtDate': '2023-05-07 10:08:00'}
# {'cmtStatus': '→', 'cmtPoster': 'raymond501', 'cmtContent': ':要開業先準備好再來吧，疫情不是藉口', 'cmtDate': '2023-05-07 10:09:00'}
# {'cmtStatus': '推', 'cmtPoster': 'onepiecefan', 'cmtContent': ':803原本的旅客最衰呵', 'cmtDate': '2023-05-07 10:10:00'}
# {'cmtStatus': '推', 'cmtPoster': 'nae0916', 'cmtContent': ':看來K董慘了早知道就不要忤逆連媒體都不幫了', 'cmtDate': '2023-05-07 10:10:00'}
# {'cmtStatus': '推', 'cmtPoster': 'w6523520', 'cmtContent': ':803真的好慘。從昨天下午延誤到現在', 'cmtDate': '2023-05-07 10:11:00'}
# {'cmtStatus': '→', 'cmtPoster': 'as199629', 'cmtContent': ':本來對星宇就沒特別期望，沒想到處理方式比廉航還', 'cmtDate': '2023-05-07 10:15:00'}
# {'cmtStatus': '→', 'cmtPoster': 'as199629', 'cmtContent': ':不如…', 'cmtDate': '2023-05-07 10:15:00'}
# {'cmtStatus': '推', 'cmtPoster': 'marforme', 'cmtContent': ':餐點好吃根本不該是選擇航空公司重點，這次星宇危', 'cmtDate': '2023-05-07 10:16:00'}
# {'cmtStatus': '→', 'cmtPoster': 'marforme', 'cmtContent': ':機處理根本0分，併班根本是錯誤', 'cmtDate': '2023-05-07 10:16:00'}
# {'cmtStatus': '→', 'cmtPoster': 'A00610lol', 'cmtContent': ':哈哈樓上還有充電座跟機上娛樂XD', 'cmtDate': '2023-05-07 10:18:00'}
# {'cmtStatus': '推', 'cmtPoster': 'phoebe147', 'cmtContent': ':公關公司忙著在PTT以外的地方帶風向XD', 'cmtDate': '2023-05-07 10:18:00'}
# {'cmtStatus': '推', 'cmtPoster': 'virgo914', 'cmtContent': ':老闆大半夜搭他曾經痛批的廉航來救自己的愛機真是', 'cmtDate': '2023-05-07 10:20:00'}
# {'cmtStatus': '→', 'cmtPoster': 'virgo914', 'cmtContent': ':令人感動', 'cmtDate': '2023-05-07 10:20:00'}
# {'cmtStatus': '推', 'cmtPoster': 'phoebe147', 'cmtContent': ':LA的美國客人比較兇（O', 'cmtDate': '2023-05-07 10:21:00'}
# {'cmtStatus': '推', 'cmtPoster': 'IUOIUOIUO', 'cmtContent': ':臉書大家還是都給k董讚捏ptt反指標？', 'cmtDate': '2023-05-07 10:23:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mtcoat', 'cmtContent': ':新聞一出來臉書下面一堆吹捧留言什麼安全第一我', 'cmtDate': '2023-05-07 10:27:00'}
# {'cmtStatus': '→', 'cmtPoster': 'mtcoat', 'cmtContent': ':都快笑死', 'cmtDate': '2023-05-07 10:27:00'}
# {'cmtStatus': '→', 'cmtPoster': 'IUOIUOIUO', 'cmtContent': ':星迷還是一篇吹捧呀', 'cmtDate': '2023-05-07 10:28:00'}
# {'cmtStatus': '推', 'cmtPoster': 'playerst', 'cmtContent': ':臉書下面一堆說安全第一的大概也不是星宇客群是星', 'cmtDate': '2023-05-07 10:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'playerst', 'cmtContent': ':宇客群的大概也不會被公關牽著鼻子走反而會更怒吧X', 'cmtDate': '2023-05-07 10:29:00'}
# {'cmtStatus': '→', 'cmtPoster': 'playerst', 'cmtContent': ':D', 'cmtDate': '2023-05-07 10:29:00'}
# {'cmtStatus': '推', 'cmtPoster': 'AtDe', 'cmtContent': ':航空版刪文了耶~', 'cmtDate': '2023-05-07 10:32:00'}
# {'cmtStatus': '推', 'cmtPoster': 'u1988926', 'cmtContent': ':刪文真的很怪', 'cmtDate': '2023-05-07 10:33:00'}
# {'cmtStatus': '→', 'cmtPoster': 'aclahm', 'cmtContent': ':航空版那篇原po自刪了==', 'cmtDate': '2023-05-07 10:34:00'}
# {'cmtStatus': '推', 'cmtPoster': 'vashwu', 'cmtContent': ':公關第一阿不刪我就告死你', 'cmtDate': '2023-05-07 10:34:00'}
# {'cmtStatus': '推', 'cmtPoster': 'dbdudsorj', 'cmtContent': ':隔壁棚2000多樓的主文就這樣掰了“自刪”', 'cmtDate': '2023-05-07 10:35:00'}
# {'cmtStatus': '→', 'cmtPoster': 'A00610lol', 'cmtContent': ':樓樓上www', 'cmtDate': '2023-05-07 10:35:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ivan761016', 'cmtContent': ':所以是公關終於開始動作了嗎？', 'cmtDate': '2023-05-07 10:37:00'}
# {'cmtStatus': '→', 'cmtPoster': 'willieliu', 'cmtContent': ':$$$$$$$$$$^_^', 'cmtDate': '2023-05-07 10:37:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kim1998', 'cmtContent': ':慘', 'cmtDate': '2023-05-07 10:40:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Alano', 'cmtContent': ':看看航空版就知道，公關公司今天加班囉', 'cmtDate': '2023-05-07 10:40:00'}
# {'cmtStatus': '推', 'cmtPoster': 'iamthebest08', 'cmtContent': ':公關出動了', 'cmtDate': '2023-05-07 10:40:00'}
# {'cmtStatus': '推', 'cmtPoster': 'vashwu', 'cmtContent': ':公關早就出動了先派人鬼扯飛安再來霸氣董仔親自飛', 'cmtDate': '2023-05-07 10:41:00'}
# {'cmtStatus': '推', 'cmtPoster': 'GarnettKing', 'cmtContent': ':說到餐點虎航其實不錯欸', 'cmtDate': '2023-05-07 10:41:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ivan761016', 'cmtContent': ':講飛安理由真的會笑死，不過真的一堆星粉相信', 'cmtDate': '2023-05-07 10:42:00'}
# {'cmtStatus': '噓', 'cmtPoster': 'nekogogogo2', 'cmtContent': ':都玩完回家了，來回也免費了，台灣人民族性真的很優', 'cmtDate': '2023-05-07 10:42:00'}
# {'cmtStatus': '→', 'cmtPoster': 'nekogogogo2', 'cmtContent': ':！', 'cmtDate': '2023-05-07 10:42:00'}
# {'cmtStatus': '→', 'cmtPoster': 'A00610lol', 'cmtContent': ':沒差啦下次換優越仔睡地板嘻嘻', 'cmtDate': '2023-05-07 10:42:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ivan761016', 'cmtContent': ':有飛安問題還讓你上飛機關艙，邏輯死去', 'cmtDate': '2023-05-07 10:43:00'}
# {'cmtStatus': '→', 'cmtPoster': 'A00610lol', 'cmtContent': ':剛說完又一個死忠仔', 'cmtDate': '2023-05-07 10:43:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Alano', 'cmtContent': ':重點應該是簽轉跟後續安置旅客的處置', 'cmtDate': '2023-05-07 10:43:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Alano', 'cmtContent': ':糟糕到一個不行，想硬飛以為成田是你張家的ww', 'cmtDate': '2023-05-07 10:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'A00610lol', 'cmtContent': ':看了真可憐哈哈星粉都去睡地板嘍', 'cmtDate': '2023-05-07 10:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'insu36', 'cmtContent': ':我是801團客因為是下午1點多的飛機，', 'cmtDate': '2023-05-07 10:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'insu36', 'cmtContent': ':所以11點多就到機場掛行李了', 'cmtDate': '2023-05-07 10:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'insu36', 'cmtContent': ':結果就是遇到800怪風沒辦法降落', 'cmtDate': '2023-05-07 10:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'insu36', 'cmtContent': ':後來星宇是幫我們轉CI105華航，到台灣搞來稿去', 'cmtDate': '2023-05-07 10:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'insu36', 'cmtContent': ':結果發現行李根本沒到台灣已經快要晚上11點了', 'cmtDate': '2023-05-07 10:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'insu36', 'cmtContent': ':等於是超過12小時沒有進食，', 'cmtDate': '2023-05-07 10:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'insu36', 'cmtContent': ':飛機上根本沒有所謂的三明治只有給你餅乾跟飲料', 'cmtDate': '2023-05-07 10:44:00'}
# {'cmtStatus': '推', 'cmtPoster': 'vashwu', 'cmtContent': ":希望這篇還能撐住不要也突然來個'自刪'", 'cmtDate': '2023-05-07 10:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'redtears', 'cmtContent': ':某N吃不吃免費的營養大便呀？', 'cmtDate': '2023-05-07 10:44:00'}
# {'cmtStatus': '推', 'cmtPoster': 'A00610lol', 'cmtContent': ':叫版主m起來阿', 'cmtDate': '2023-05-07 10:46:00'}
# {'cmtStatus': '→', 'cmtPoster': 'A00610lol', 'cmtContent': ':*把這篇m起來', 'cmtDate': '2023-05-07 10:46:00'}
# {'cmtStatus': '→', 'cmtPoster': 'eric33456', 'cmtContent': ':張董早上說803延誤是因為機身檢查才導致組員超時', 'cmtDate': '2023-05-07 10:46:00'}
# {'cmtStatus': '推', 'cmtPoster': 'chinick1478', 'cmtContent': ':結果乘客還沒回來...', 'cmtDate': '2023-05-07 10:47:00'}
# {'cmtStatus': '→', 'cmtPoster': 'YuriLowell', 'cmtContent': ':三明治應該是指給昨天803上801的散客的？', 'cmtDate': '2023-05-07 10:47:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mtcoat', 'cmtContent': ':那就保守一點提早把人送旅館隔天再飛呀硬要賭…', 'cmtDate': '2023-05-07 10:48:00'}
# {'cmtStatus': '→', 'cmtPoster': 'mtcoat', 'cmtContent': ':因小失大', 'cmtDate': '2023-05-07 10:48:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mithralin', 'cmtContent': ':請各位推文討論時注意用詞謝謝', 'cmtDate': '2023-05-07 10:50:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ilove1530', 'cmtContent': ':不愧是驚品航空', 'cmtDate': '2023-05-07 10:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'tetsulove', 'cmtContent': ':轉給華航的機上沒餐只有小零食應該是太突然了轉太多', 'cmtDate': '2023-05-07 10:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'chinick1478', 'cmtContent': ':隔壁版的已經坐上飛機了恭喜', 'cmtDate': '2023-05-07 10:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'tetsulove', 'cmtContent': ':人華航來不及備餐只能先準備現成的小零食給旅客墊', 'cmtDate': '2023-05-07 10:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'tetsulove', 'cmtContent': ':墊肚子真的是辛苦各位苦主了', 'cmtDate': '2023-05-07 10:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'terrymoon', 'cmtContent': ':星粉跟館粉是不是都一樣以為商品最頂結果跟別牌差', 'cmtDate': '2023-05-07 10:52:00'}
# {'cmtStatus': '→', 'cmtPoster': 'terrymoon', 'cmtContent': ':不多', 'cmtDate': '2023-05-07 10:52:00'}
# {'cmtStatus': '推', 'cmtPoster': 'xSAUCEx', 'cmtContent': ':錢都在做行銷了', 'cmtDate': '2023-05-07 10:52:00'}
# {'cmtStatus': '推', 'cmtPoster': 'toole', 'cmtContent': ':803檢查18:13就結束了沒併801散客可以飛的機率頗', 'cmtDate': '2023-05-07 10:52:00'}
# {'cmtStatus': '→', 'cmtPoster': 'toole', 'cmtContent': ':大說檢查才超時沒道理', 'cmtDate': '2023-05-07 10:52:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kr119396', 'cmtContent': ':睡機場是處理方式，精品航空就這？', 'cmtDate': '2023-05-07 10:53:00'}
# {'cmtStatus': '推', 'cmtPoster': 'terrymoon', 'cmtContent': ':精品廉航啦', 'cmtDate': '2023-05-07 10:54:00'}
# {'cmtStatus': '推', 'cmtPoster': 'jason5678tw', 'cmtContent': ':小宇把我們最頂的飛機牽出來！', 'cmtDate': '2023-05-07 10:54:00'}
# {'cmtStatus': '→', 'cmtPoster': 'chinick1478', 'cmtContent': ':A32n在不飛出去又要超時了', 'cmtDate': '2023-05-07 10:55:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ks2384im', 'cmtContent': ':睡機場人生成就達成該分享親友說嘴了', 'cmtDate': '2023-05-07 10:55:00'}
# {'cmtStatus': '→', 'cmtPoster': 'YuriLowell', 'cmtContent': ':是說老闆都特地飛過去了那先掏個腰包請乘客一頓早', 'cmtDate': '2023-05-07 10:55:00'}
# {'cmtStatus': '→', 'cmtPoster': 'YuriLowell', 'cmtContent': ':餐安撫一下沒那麼難吧', 'cmtDate': '2023-05-07 10:55:00'}
# {'cmtStatus': '推', 'cmtPoster': 'vashwu', 'cmtContent': ':人家是來作秀的不是來花錢的公關要求懂?', 'cmtDate': '2023-05-07 10:57:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ups', 'cmtContent': ':好慘', 'cmtDate': '2023-05-07 10:58:00'}
# {'cmtStatus': '推', 'cmtPoster': 'cink8', 'cmtContent': ':好險我堅持選長榮，一堆人神話老K神過頭', 'cmtDate': '2023-05-07 10:58:00'}
# {'cmtStatus': '推', 'cmtPoster': 'terrymoon', 'cmtContent': ':這件事的啟示就是星宇危機處理沒有其他國航來得好', 'cmtDate': '2023-05-07 10:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'terrymoon', 'cmtContent': ':票價也沒有特別便宜但公關撒錢撒很兇', 'cmtDate': '2023-05-07 10:59:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kilu', 'cmtContent': ':短期內不會考慮搭乘這家航空了', 'cmtDate': '2023-05-07 11:00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'as981134', 'cmtContent': ':所以這年頭玩行銷也不要玩太大吹過頭爆炸很可怕的', 'cmtDate': '2023-05-07 11:00:00'}
# {'cmtStatus': '→', 'cmtPoster': 'as981134', 'cmtContent': ':一樣的事情發生在其他家搞不好還沒這麼多人氣', 'cmtDate': '2023-05-07 11:00:00'}
# {'cmtStatus': '推', 'cmtPoster': 'vashwu', 'cmtContent': ':吹整天的妖風長榮跟華航都沒事就你網紅航空有事', 'cmtDate': '2023-05-07 11:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'playerst', 'cmtContent': ':其他家應該不會發生一樣的事這次有點誇張', 'cmtDate': '2023-05-07 11:02:00'}
# {'cmtStatus': '→', 'cmtPoster': 'vashwu', 'cmtContent': ':更別提霸氣董仔還是坐廉航去日本真是夠糗', 'cmtDate': '2023-05-07 11:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'debby1993', 'cmtContent': ':華航可能是帶來回餐，突然塞進來的人太多餐根本不', 'cmtDate': '2023-05-07 11:03:00'}
# {'cmtStatus': '→', 'cmtPoster': 'debby1993', 'cmtContent': ':夠發吧？辛苦了', 'cmtDate': '2023-05-07 11:03:00'}
# {'cmtStatus': '推', 'cmtPoster': 'terrymoon', 'cmtContent': ':其他家頂多就道歉退費星宇就真的自己吹很兇這次', 'cmtDate': '2023-05-07 11:04:00'}
# {'cmtStatus': '→', 'cmtPoster': 'terrymoon', 'cmtContent': ':事件反彈太大', 'cmtDate': '2023-05-07 11:04:00'}
# {'cmtStatus': '推', 'cmtPoster': 'ju06080719', 'cmtContent': ':反觀其他家最多推總經理出來道歉', 'cmtDate': '2023-05-07 11:05:00'}
# {'cmtStatus': '推', 'cmtPoster': 'BornFish', 'cmtContent': ':臉書上相關新聞下的回覆都在稱讚張國煒欸...好扯。', 'cmtDate': '2023-05-07 11:05:00'}
# {'cmtStatus': '→', 'cmtPoster': 'charogne', 'cmtContent': ':星宇沒有增加組員與飛機，在旺季真的要小心', 'cmtDate': '2023-05-07 11:06:00'}
# {'cmtStatus': '→', 'cmtPoster': 'charogne', 'cmtContent': ':只會再發生，不會只有日本黃金週這發', 'cmtDate': '2023-05-07 11:06:00'}
# {'cmtStatus': '推', 'cmtPoster': 'u1988926', 'cmtContent': ':其他家可能推總經理道歉但該做的都會做好吧（反觀', 'cmtDate': '2023-05-07 11:06:00'}
# {'cmtStatus': '→', 'cmtPoster': 'charogne', 'cmtContent': ':目前看起來只有公關力封頂，星宇要作為頂級航空', 'cmtDate': '2023-05-07 11:07:00'}
# {'cmtStatus': '→', 'cmtPoster': 'charogne', 'cmtContent': ':真的要努力很多', 'cmtDate': '2023-05-07 11:07:00'}
# {'cmtStatus': '推', 'cmtPoster': 'playerst', 'cmtContent': ':因為其他家還沒出國這種大包啊', 'cmtDate': '2023-05-07 11:07:00'}
# {'cmtStatus': '推', 'cmtPoster': 's1d87', 'cmtContent': ':睡醒了，所以旅客還沒回來喔？', 'cmtDate': '2023-05-07 11:08:00'}
# {'cmtStatus': '推', 'cmtPoster': 'metallolly', 'cmtContent': ':其他家有出過這種包嗎', 'cmtDate': '2023-05-07 11:08:00'}
# {'cmtStatus': '噓', 'cmtPoster': 'mtcoat', 'cmtContent': ':沒飛機沒組員還想玩長程航線', 'cmtDate': '2023-05-07 11:08:00'}
# {'cmtStatus': '推', 'cmtPoster': 's860382', 'cmtContent': ':臉書清一色讚揚董事長完全不誇張', 'cmtDate': '2023-05-07 11:09:00'}
# {'cmtStatus': '推', 'cmtPoster': 'hmt17', 'cmtContent': ':新聞底下質疑的留言還會被嗆不然你想怎樣呵呵', 'cmtDate': '2023-05-07 11:10:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Serio', 'cmtContent': ':BR,CI是NRT還有班好調度,JX這個綁死應變能力負分', 'cmtDate': '2023-05-07 11:11:00'}
# {'cmtStatus': '推', 'cmtPoster': 'willieliu', 'cmtContent': ':還好版主先M了反觀航空版被自刪', 'cmtDate': '2023-05-07 11:11:00'}
# {'cmtStatus': '推', 'cmtPoster': 'devilkool', 'cmtContent': ':希望板主與這篇原po不要輸給邪惡力量', 'cmtDate': '2023-05-07 11:11:00'}
# {'cmtStatus': '→', 'cmtPoster': 'charogne', 'cmtContent': ':給餐卷＋住宿就解決一半了，轉簽+調自家飛機就解決', 'cmtDate': '2023-05-07 11:11:00'}
# {'cmtStatus': '→', 'cmtPoster': 'charogne', 'cmtContent': ':很少爆這麼慘的', 'cmtDate': '2023-05-07 11:12:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Ryder', 'cmtContent': ':版主真的英明先m讚讚讚', 'cmtDate': '2023-05-07 11:12:00'}
# {'cmtStatus': '→', 'cmtPoster': 'charogne', 'cmtContent': ':我搭卡達delay過幾小時，直接領餐卷在機場打發時間.', 'cmtDate': '2023-05-07 11:12:00'}
# {'cmtStatus': '推', 'cmtPoster': 'silveriodide', 'cmtContent': ':真的好慘', 'cmtDate': '2023-05-07 11:12:00'}
# {'cmtStatus': '→', 'cmtPoster': 'charogne', 'cmtContent': ':餐卷＋住宿、轉簽+調自家，星宇這次完成度0%', 'cmtDate': '2023-05-07 11:13:00'}
# {'cmtStatus': '→', 'cmtPoster': 'charogne', 'cmtContent': ':只有董事長親自搭廉航安撫乘客...', 'cmtDate': '2023-05-07 11:13:00'}
# {'cmtStatus': '→', 'cmtPoster': 'charogne', 'cmtContent': ':總之要加油，大家都對星宇有厚望，但機＆員真的太少', 'cmtDate': '2023-05-07 11:14:00'}
# {'cmtStatus': '推', 'cmtPoster': 'mtcoat', 'cmtContent': ':星宇沒飛機沒組員調度難，沒加入任何聯盟想轉簽也', 'cmtDate': '2023-05-07 11:15:00'}
# {'cmtStatus': '→', 'cmtPoster': 'mtcoat', 'cmtContent': ':麻煩選其他家比較好吧', 'cmtDate': '2023-05-07 11:15:00'}
# {'cmtStatus': '→', 'cmtPoster': 'pigofwind', 'cmtContent': ':這個真的是後面的處理太糟了', 'cmtDate': '2023-05-07 11:15:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Alano', 'cmtContent': ':說厚望其實也只有粉絲跟網美吧', 'cmtDate': '2023-05-07 11:18:00'}
# {'cmtStatus': '推', 'cmtPoster': 'nanase123', 'cmtContent': ':話說有沒有已經買好這家未來要去日本的版友啊', 'cmtDate': '2023-05-07 11:18:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Alano', 'cmtContent': ':行銷變成才是這家航空公司的重點', 'cmtDate': '2023-05-07 11:19:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Alano', 'cmtContent': ':各種噱頭，超商聯名，網路上各種業配等等', 'cmtDate': '2023-05-07 11:20:00'}
# {'cmtStatus': '推', 'cmtPoster': 'requan', 'cmtContent': ':昨天唯一做對的就是轉簽團客！不然惹到團客第一個一', 'cmtDate': '2023-05-07 11:20:00'}
# {'cmtStatus': '→', 'cmtPoster': 'requan', 'cmtContent': ':定是團客跟旅行社求償，沒有安置旅客吃喝，然後團', 'cmtDate': '2023-05-07 11:20:00'}
# {'cmtStatus': '→', 'cmtPoster': 'requan', 'cmtContent': ':客也不能賭不退關睡候機室，一定要安排飯店的，不然', 'cmtDate': '2023-05-07 11:20:00'}
# {'cmtStatus': '→', 'cmtPoster': 'requan', 'cmtContent': ':旅行社以後也不敢用星宇了', 'cmtDate': '2023-05-07 11:20:00'}
# {'cmtStatus': '推', 'cmtPoster': 'bubucargo', 'cmtContent': ':這個處理方式真的不行欸！', 'cmtDate': '2023-05-07 11:20:00'}
# {'cmtStatus': '→', 'cmtPoster': 'pigofwind', 'cmtContent': ':目前只有看到公關力點滿，重點是你要安撫好那群旅客', 'cmtDate': '2023-05-07 11:21:00'}
# {'cmtStatus': '→', 'cmtPoster': 'pigofwind', 'cmtContent': ':而不是忙著洗輿論阿', 'cmtDate': '2023-05-07 11:21:00'}
# {'cmtStatus': '推', 'cmtPoster': 'sss60308', 'cmtContent': ':搭過聯合的災難延誤感覺星宇其實還好', 'cmtDate': '2023-05-07 11:21:00'}
# {'cmtStatus': '→', 'cmtPoster': 'mooto', 'cmtContent': ':這個會造成信心危機以前ダメエア碰過一次就不搭了', 'cmtDate': '2023-05-07 11:21:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kiddcat', 'cmtContent': ':這處理實在太爛，機場沒整天關場，結果是航空公司', 'cmtDate': '2023-05-07 11:21:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kiddcat', 'cmtContent': ':自己關客戶', 'cmtDate': '2023-05-07 11:21:00'}
# {'cmtStatus': '推', 'cmtPoster': 'toole', 'cmtContent': ':803的團客也是炸了啊哪有比較好', 'cmtDate': '2023-05-07 11:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'pigofwind', 'cmtContent': ':會買你家機票的客群，看到這種處理方式早就嚇跑了，', 'cmtDate': '2023-05-07 11:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'pigofwind', 'cmtContent': ':一堆人在臉書讚你道歉有什麼用？', 'cmtDate': '2023-05-07 11:22:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Misako', 'cmtContent': ':道歉不是應該的嗎？全退不是應該的嗎？', 'cmtDate': '2023-05-07 11:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Alano', 'cmtContent': ':如果要看完整討論還是去航空版吧', 'cmtDate': '2023-05-07 11:22:00'}
# {'cmtStatus': '→', 'cmtPoster': 'mooto', 'cmtContent': ':沒想到團客這麼有保障是因為旅行社比較難處理嗎', 'cmtDate': '2023-05-07 11:23:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Alano', 'cmtContent': ':日旅版對星宇還是偏愛居多', 'cmtDate': '2023-05-07 11:23:00'}
# {'cmtStatus': '推', 'cmtPoster': 'as981134', 'cmtContent': ':人健忘啊過一陣子特價還是賣光', 'cmtDate': '2023-05-07 11:23:00'}
# {'cmtStatus': '推', 'cmtPoster': 'applemonster', 'cmtContent': ':看起來危機處理差，票價沒便宜，以後會避開這家航空', 'cmtDate': '2023-05-07 11:23:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Godofthebutt', 'cmtContent': ':這家是廉航嗎？', 'cmtDate': '2023-05-07 11:24:00'}
# {'cmtStatus': '→', 'cmtPoster': 'mooto', 'cmtContent': ':那就拿出誠意特價阿(笑)我這人很簡單', 'cmtDate': '2023-05-07 11:24:00'}
# {'cmtStatus': '→', 'cmtPoster': 'as981134', 'cmtContent': ':團客收益大要先顧啊這個每家都差不多', 'cmtDate': '2023-05-07 11:24:00'}
# {'cmtStatus': '→', 'cmtPoster': 'as981134', 'cmtContent': ':出問題就先安撫高階卡然後團客最後才散客', 'cmtDate': '2023-05-07 11:24:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kiddcat', 'cmtContent': ':昨天廉航也沒怎樣，就你星宇問題最多', 'cmtDate': '2023-05-07 11:24:00'}
# {'cmtStatus': '→', 'cmtPoster': 'as981134', 'cmtContent': ':反正散客一年搭沒幾次跑了就跑了', 'cmtDate': '2023-05-07 11:24:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yjjs', 'cmtContent': ':FB口碑洗到不行好可怕', 'cmtDate': '2023-05-07 11:24:00'}
# {'cmtStatus': '推', 'cmtPoster': 'marforme', 'cmtContent': ':本來有在考慮星宇經過此事危機處理0分後不在考慮', 'cmtDate': '2023-05-07 11:25:00'}
# {'cmtStatus': '→', 'cmtPoster': 'marforme', 'cmtContent': ':，餐點好吃娛樂設備充電等根本不該是選擇航空公司', 'cmtDate': '2023-05-07 11:25:00'}
# {'cmtStatus': '→', 'cmtPoster': 'marforme', 'cmtContent': ':應考慮重點', 'cmtDate': '2023-05-07 11:25:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Serio', 'cmtContent': ':旅行社不是難處理不處理想自砍固定收入啊', 'cmtDate': '2023-05-07 11:25:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Alano', 'cmtContent': ':而且星宇也沒有比較便宜啊，不像是以前復興', 'cmtDate': '2023-05-07 11:25:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Alano', 'cmtContent': ':票價跟兩大比起來真的有便宜', 'cmtDate': '2023-05-07 11:26:00'}
# {'cmtStatus': '→', 'cmtPoster': 'mooto', 'cmtContent': ':那你就得罪44看散客用來塞載客率還是有貢獻的', 'cmtDate': '2023-05-07 11:26:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Alano', 'cmtContent': ':連後面取消的JX2也可以出包wwww', 'cmtDate': '2023-05-07 11:26:00'}
# ...
# {'cmtStatus': '→', 'cmtPoster': 'ybite', 'cmtContent': ':名古屋說實話真的很普通大阪進出我一定選大阪', 'cmtDate': '2023-05-14 13:52:00'}
# {'cmtStatus': '推', 'cmtPoster': 'annle1217', 'cmtContent': ':實在抱歉，我有認識的的確是因為行程太累直接在日本', 'cmtDate': '2023-05-14 14:19:00'}
# {'cmtStatus': '→', 'cmtPoster': 'annle1217', 'cmtContent': ':吵架談離婚，用詞引起不快在此致歉', 'cmtDate': '2023-05-14 14:19:00'}
# {'cmtStatus': '→', 'cmtPoster': 'blueperi', 'cmtContent': ':名古屋可以刪掉，第一天直接衝到富山，第二天黑部', 'cmtDate': '2023-05-14 14:43:00'}
# {'cmtStatus': '→', 'cmtPoster': 'blueperi', 'cmtContent': ':第三天玩高山接合掌村，或是高山結束回富山移動至金', 'cmtDate': '2023-05-14 14:43:00'}
# {'cmtStatus': '→', 'cmtPoster': 'blueperi', 'cmtContent': ':澤，第四天從金澤搭巴士去合掌村再回金澤，這樣飯店', 'cmtDate': '2023-05-14 14:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'blueperi', 'cmtContent': ':可以少換2次，會輕鬆一點', 'cmtDate': '2023-05-14 14:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'blueperi', 'cmtContent': ':第五天在金澤玩，晚上移動到大阪，第六天就在大阪', 'cmtDate': '2023-05-14 14:45:00'}
# {'cmtStatus': '→', 'cmtPoster': 'blueperi', 'cmtContent': ':如果奈良無法刪，就第四天晚上搭車到大阪，第五天玩', 'cmtDate': '2023-05-14 14:46:00'}
# {'cmtStatus': '→', 'cmtPoster': 'blueperi', 'cmtContent': ':奈良，不要最後一天才去奈良比較保險', 'cmtDate': '2023-05-14 14:47:00'}
# {'cmtStatus': '推', 'cmtPoster': 'appear25', 'cmtContent': ':沒有雪的合掌村，只能說沒有特色', 'cmtDate': '2023-05-14 15:54:00'}
# {'cmtStatus': '→', 'cmtPoster': 'appear25', 'cmtContent': ':另外我是名古屋派，真心認為比大阪東京有更多好玩', 'cmtDate': '2023-05-14 15:55:00'}
# {'cmtStatus': '→', 'cmtPoster': 'appear25', 'cmtContent': ':的景點(非逛街)', 'cmtDate': '2023-05-14 15:55:00'}
# {'cmtStatus': '→', 'cmtPoster': 'zzyyxx77', 'cmtContent': ':只有無聊的旅人', 'cmtDate': '2023-05-14 16:08:00'}
# {'cmtStatus': '推', 'cmtPoster': 'wanryung', 'cmtContent': ':富山的雪牆4-6月左右，11月沒有', 'cmtDate': '2023-05-15 22:01:00'}
# {'cmtStatus': '推', 'cmtPoster': 'lucifero', 'cmtContent': ':黑部立山的楓葉很漂亮只是11月可能有點晚了', 'cmtDate': '2023-05-15 22:17:00'}
# {'cmtStatus': '→', 'cmtPoster': 'lucifero', 'cmtContent': ':去合掌村那天晚上去金澤沒行程的話不如直接住富山', 'cmtDate': '2023-05-15 22:18:00'}
# {'cmtStatus': '推', 'cmtPoster': 'BigBird110', 'cmtContent': ':藤蔓橋很短但有點恐怖', 'cmtDate': '2023-05-19 12:52:00'}
# {'cmtStatus': '推', 'cmtPoster': 'whotoceem', 'cmtContent': ':感謝分享', 'cmtDate': '2023-05-19 13:42:00'}
# {'cmtStatus': '推', 'cmtPoster': 'huang19898', 'cmtContent': ':藤蔓橋我曾經一隻腳踏空卡到間隙裡，超可怕', 'cmtDate': '2023-05-19 17:27:00'}
# {'cmtStatus': '推', 'cmtPoster': 'BigBird110', 'cmtContent': ':對那個間隙超大每個人都緊抓左右的扶手', 'cmtDate': '2023-05-19 20:13:00'}
# {'cmtStatus': '推', 'cmtPoster': 'yebot', 'cmtContent': ':推分享', 'cmtDate': '2023-05-20 08:53:00'}
# {'cmtStatus': '→', 'cmtPoster': 'billiechick', 'cmtContent': ':感謝分享！！！！', 'cmtDate': '2023-05-21 00:15:00'}
# {'cmtStatus': '→', 'cmtPoster': 'MoonCatQQ', 'cmtContent': ':感謝建議！', 'cmtDate': '2023-05-03 11:39:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ecknair', 'cmtContent': ':距離關櫃只剩20分鐘順利的話趕得上但一點都不早吧', 'cmtDate': '2023-05-03 18:18:00'}
# {'cmtStatus': '→', 'cmtPoster': 'MoonCatQQ', 'cmtContent': ':離關櫃只剩20分鐘好像真的太緊迫了！參考各位的建', 'cmtDate': '2023-05-03 21:45:00'}
# {'cmtStatus': '→', 'cmtPoster': 'MoonCatQQ', 'cmtContent': ':議後我會早點到機場的', 'cmtDate': '2023-05-03 21:45:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kenploin', 'cmtContent': ':我第一點看錯時間了真的太趕修改一下內文最好至', 'cmtDate': '2023-05-04 10:50:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kenploin', 'cmtContent': ':少在提早半小時', 'cmtDate': '2023-05-04 10:50:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Kamelie', 'cmtContent': ':推', 'cmtDate': '2023-05-01 17:47:00'}
# {'cmtStatus': '推', 'cmtPoster': 'richer23', 'cmtContent': ':札幌好像差不多', 'cmtDate': '2023-05-12 11:07:00'}
# {'cmtStatus': '→', 'cmtPoster': 'iwinlottery', 'cmtContent': ':虎航不要還比老母貴耶', 'cmtDate': '2023-05-12 11:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Aaron22', 'cmtContent': ':昨天剛開釜山機票，剛看到心揪了一下。但是查詢後', 'cmtDate': '2023-05-12 11:19:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Aaron22', 'cmtContent': ':卻比我昨天開的機票還貴', 'cmtDate': '2023-05-12 11:19:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kashima228', 'cmtContent': ':札幌暑假就兩萬三了', 'cmtDate': '2023-05-12 11:33:00'}
# {'cmtStatus': '推', 'cmtPoster': 'zirong', 'cmtContent': ':南部要再加上高鐵票，北高差不多啦！', 'cmtDate': '2023-05-12 11:43:00'}
# {'cmtStatus': '→', 'cmtPoster': 'OhmoriHarumi', 'cmtContent': ':台北有晚去早回班次，比較便宜不意外。', 'cmtDate': '2023-05-12 11:53:00'}
# {'cmtStatus': '→', 'cmtPoster': 'hans7192', 'cmtContent': ':商務艙賣得那麼好?', 'cmtDate': '2023-05-12 13:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'WRD', 'cmtContent': ':改321之後小港商務艙就很值得買', 'cmtDate': '2023-05-12 13:14:00'}
# {'cmtStatus': '推', 'cmtPoster': 'smileyeah', 'cmtContent': ':不知為何有符合上述條件但票價跟昨晚看到一樣', 'cmtDate': '2023-05-12 13:44:00'}
# {'cmtStatus': '推', 'cmtPoster': 'asdf0923', 'cmtContent': ':這次要的日期是旺日，天價打折以後還是天價（笑', 'cmtDate': '2023-05-12 14:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'weicang', 'cmtContent': ':暑假跟10月連假好像沒變XD', 'cmtDate': '2023-05-12 14:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'nolimits', 'cmtContent': ':名古屋時間好爛', 'cmtDate': '2023-05-12 16:11:00'}
# {'cmtStatus': '→', 'cmtPoster': 'imlavender', 'cmtContent': ':真的有降價嗎?我看競爭很激烈的泰國也沒太大降幅', 'cmtDate': '2023-05-12 16:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'whalelover', 'cmtContent': ':記得華航的名古屋跟廣島時間都滿鳥的XDD', 'cmtDate': '2023-05-12 17:35:00'}
# {'cmtStatus': '推', 'cmtPoster': 'andykao082', 'cmtContent': ':比虎航貴了一點而已，在降一點吧', 'cmtDate': '2023-05-12 18:07:00'}
# {'cmtStatus': '推', 'cmtPoster': 'condition0', 'cmtContent': ':上週星宇出事之後華航有小漲現在9折就變回漲價前', 'cmtDate': '2023-05-12 18:21:00'}
# {'cmtStatus': '→', 'cmtPoster': 'condition0', 'cmtContent': ':而已', 'cmtDate': '2023-05-12 18:21:00'}
# {'cmtStatus': '→', 'cmtPoster': 'condition0', 'cmtContent': ':不過今天還是決定開票了不想再等了XD', 'cmtDate': '2023-05-12 18:23:00'}
# {'cmtStatus': '推', 'cmtPoster': 'TS28', 'cmtContent': ':華航這價格應該沒人會買星宇了吧', 'cmtDate': '2023-05-12 18:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'altcd', 'cmtContent': ':華航名古屋時間真的超爛....', 'cmtDate': '2023-05-12 19:03:00'}
# {'cmtStatus': '推', 'cmtPoster': 'asdsasd', 'cmtContent': ':樓樓上，可是華航特價票很多時間都很爛XD', 'cmtDate': '2023-05-12 19:08:00'}
# {'cmtStatus': '推', 'cmtPoster': 'cheeshan', 'cmtContent': ':我的日期機票變便宜了好不爽', 'cmtDate': '2023-05-12 19:49:00'}
# {'cmtStatus': '→', 'cmtPoster': 'imlavender', 'cmtContent': ':看到我的日期機票只剩商務艙,華航會超賣嗎', 'cmtDate': '2023-05-12 22:08:00'}
# {'cmtStatus': '推', 'cmtPoster': 'el500', 'cmtContent': ':看到比原本買的大概降個桃園機場稅左右', 'cmtDate': '2023-05-13 11:33:00'}
# {'cmtStatus': '推', 'cmtPoster': 'travelman', 'cmtContent': ':推廣島六去日回，雖是晚去早回，但價格頗甜', 'cmtDate': '2023-05-13 12:22:00'}
# {'cmtStatus': '推', 'cmtPoster': 'griffick', 'cmtContent': ':星宇除非比華航便宜個兩三千，不然不會買', 'cmtDate': '2023-05-14 11:36:00'}
# {'cmtStatus': '推', 'cmtPoster': 'condition0', 'cmtContent': ':主要還是看時間啦像KIX星宇回來是下午', 'cmtDate': '2023-05-15 10:42:00'}
# {'cmtStatus': '→', 'cmtPoster': 'condition0', 'cmtContent': ':除非超便宜不然根本不會選', 'cmtDate': '2023-05-15 10:42:00'}
# {'cmtStatus': '推', 'cmtPoster': 'cocoel34', 'cmtContent': ':聖誕節期間松山羽田早去午回不到1.6萬，還可以接受', 'cmtDate': '2023-05-15 15:57:00'}
# {'cmtStatus': '→', 'cmtPoster': 'cocoel34', 'cmtContent': ':就買了', 'cmtDate': '2023-05-15 15:57:00'}
# {'cmtStatus': '推', 'cmtPoster': 'f1986715', 'cmtContent': ':名古屋應該是適合商務客，晚去早回', 'cmtDate': '2023-05-15 19:10:00'}
# {'cmtStatus': '→', 'cmtPoster': 'lucifero', 'cmtContent': ':\u3000\u3000\u3000\u3000\u3000機票開了就不要再去看票價了XD', 'cmtDate': '2023-05-15 21:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'silentgirl', 'cmtContent': ':竟然比我原先買的貴？', 'cmtDate': '2023-05-16 21:46:00'}
# {'cmtStatus': '→', 'cmtPoster': 'bemily32', 'cmtContent': ':沖繩這價格比疫情前還是貴了50%確定已經是特價？', 'cmtDate': '2023-05-17 14:26:00'}
# {'cmtStatus': '推', 'cmtPoster': 'AisinGioro', 'cmtContent': ':閱讀障礙你應該用JPG才對', 'cmtDate': '2023-05-06 23:33:00'}
# {'cmtStatus': '→', 'cmtPoster': 'AisinGioro', 'cmtContent': ':點開網頁版也看不到圖我不想一個個連結慢慢點', 'cmtDate': '2023-05-06 23:33:00'}
# {'cmtStatus': '→', 'cmtPoster': 'AisinGioro', 'cmtContent': ':退回重發', 'cmtDate': '2023-05-06 23:33:00'}
# {'cmtStatus': '→', 'cmtPoster': 'AisinGioro', 'cmtContent': ':照片耀光也太嚴重....', 'cmtDate': '2023-05-06 23:34:00'}
# {'cmtStatus': '推', 'cmtPoster': 'uio3344', 'cmtContent': ':推！', 'cmtDate': '2023-05-07 00:37:00'}
# {'cmtStatus': '推', 'cmtPoster': 'aalps', 'cmtContent': ':比ANAbug票文實用', 'cmtDate': '2023-05-07 01:02:00'}
# {'cmtStatus': '推', 'cmtPoster': 'stacy623', 'cmtContent': ':上上禮拜才在這看backnumber演唱會回來，看到你的', 'cmtDate': '2023-05-07 07:54:00'}
# {'cmtStatus': '→', 'cmtPoster': 'newsbow', 'cmtContent': ':柳皇的球衣就走了', 'cmtDate': '2023-05-07 08:54:00'}
# {'cmtStatus': '推', 'cmtPoster': 'newsbow', 'cmtContent': ':我穿短袖一整天不覺得冷，paypay巨蛋海風一直吹也', 'cmtDate': '2023-05-08 16:55:00'}
# {'cmtStatus': '→', 'cmtPoster': 'newsbow', 'cmtContent': ':一樣', 'cmtDate': '2023-05-08 16:55:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ybite', 'cmtContent': ':跟家人我認為不要一直換宿加上行李超麻煩', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'ybite', 'cmtContent': ':然後我覺得仙台機場返程拉去東京沒意義太遠了', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'ybite', 'cmtContent': ':就算搭直達車也幾乎是台北左營的時間了', 'cmtDate': '2023-05-12 02:36:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ybite', 'cmtContent': ':想看自然景觀就專心排東北我認為會比較盡興', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'ybite', 'cmtContent': ':北海道那張官網說是要連續四天', 'cmtDate': '2023-05-12 02:38:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ybite', 'cmtContent': ':仙台附近就狐狸村跟松島淨土之濱之類就車程很長', 'cmtDate': '2023-05-12 02:42:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ybite', 'cmtContent': ':真的要去東京第一次排個淺草晴空塔澀谷都是安全', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'ybite', 'cmtContent': ':牌', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'ybite', 'cmtContent': ':最後非都市區域不會日文有點麻煩要多點耐心QQ', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'ybite', 'cmtContent': ':剛看過夏天狐狸村確實不好毛量問題QQ', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '推', 'cmtPoster': 'tekamolo', 'cmtContent': ':日光、五色沼、藏王、海嘯遺址', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '推', 'cmtPoster': 'ijkppy', 'cmtContent': ':函館朝市只開到下午兩點多，改第六天早一點去即可', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'ijkppy', 'cmtContent': ':。', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'spencers', 'cmtContent': ':tabelog', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '推', 'cmtPoster': 'rose21777', 'cmtContent': ':函館朝市沒記錯的話只開到下午2點，你不如排到隔天', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'rose21777', 'cmtContent': ':早上；金森倉庫轉個彎就到八幡板了，目前的路線很', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'rose21777', 'cmtContent': ':不順', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '推', 'cmtPoster': 'rose21777', 'cmtContent': ':建議路線應該是：函館車站>金森倉庫>八幡板>函館夜', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'rose21777', 'cmtContent': ':景', 'cmtDate': '2023-05-12 07:56:00'}
# {'cmtStatus': '→', 'cmtPoster': 'rose21777', 'cmtContent': ':隔天：函館朝市>五稜郭', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'strayfrog', 'cmtContent': ':D1有沒有考慮住札幌，隔天再去小樽', 'cmtDate': '2023-05-12 09:27:00'}
# {'cmtStatus': '→', 'cmtPoster': 'strayfrog', 'cmtContent': ':小樽晚上6點應該也沒什麼能逛了', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':因為考慮之後再札幌都不換飯店了', 'cmtDate': '2023-05-12 09:46:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':過去應該就是看看夜景跟三角市場吃飯這樣', 'cmtDate': '2023-05-12 02:26:06'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':因為第一天飯店剛好就在運河旁邊', 'cmtDate': '2023-05-12 09:50:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Gwendolynn', 'cmtContent': ':只為夜景有必要第一天拉到小樽嗎', 'cmtDate': '2023-05-12 14:15:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Gwendolynn', 'cmtContent': ':DAY6帶著行李從北海道移動到新青森後，繼續帶著行', 'cmtDate': '2023-05-12 14:19:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Gwendolynn', 'cmtContent': ':李去弘前再去青森這樣不累嗎？', 'cmtDate': '2023-05-12 14:19:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':抱歉行李的部分像是第五天跟第六天', 'cmtDate': '2023-05-12 15:10:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':都會先把行李放飯店再出去逛', 'cmtDate': '2023-05-12 15:10:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':第一天的部分會在討論看看謝謝你', 'cmtDate': '2023-05-12 15:10:00'}
# {'cmtStatus': '→', 'cmtPoster': 'ivymorita', 'cmtContent': ':不用住到小樽都住札幌就行了吧', 'cmtDate': '2023-05-12 16:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'kimic', 'cmtContent': ':三角市場晚餐時間很多店都關了吧', 'cmtDate': '2023-05-12 17:28:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Gwendolynn', 'cmtContent': ':住青森早餐可以去古川市場，跟函館朝市又有點不一樣', 'cmtDate': '2023-05-12 18:53:00'}
# {'cmtStatus': '推', 'cmtPoster': 'apple110122', 'cmtContent': ':Day5可去倉庫跟八幡板函館夜景ㄧ起玩因爲都在', 'cmtDate': '2023-05-12 19:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'apple110122', 'cmtContent': ':附近，隔天去青森也不會這麽趕。另外在仙台不要在', 'cmtDate': '2023-05-12 19:51:00'}
# {'cmtStatus': '→', 'cmtPoster': 'apple110122', 'cmtContent': ':拉車去東京了，太浪費時間，建議可增加東北的行程。', 'cmtDate': '2023-05-12 19:51:00'}
# {'cmtStatus': '推', 'cmtPoster': 'apple110122', 'cmtContent': ':還有朝市的話Day6ㄧ早再去吧。', 'cmtDate': '2023-05-12 19:53:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':了解另外想問一下有關星野的奧入瀨溪流飯店因為', 'cmtDate': '2023-05-12 20:56:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':房價蠻貴一個人換算差不多快六千元但看起來很不錯', 'cmtDate': '2023-05-12 20:56:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':而且又有接駁車', 'cmtDate': '2023-05-12 20:56:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':但關於接駁車他官網的說明看起來就是一班車而已….', 'cmtDate': '2023-05-12 20:56:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':所以也不能選時間對嗎？', 'cmtDate': '2023-05-12 20:56:00'}
# {'cmtStatus': '推', 'cmtPoster': 'CiaoTwo', 'cmtContent': ':不能選時間,訂完飯店就可以去預定接駁車', 'cmtDate': '2023-05-12 21:31:00'}
# {'cmtStatus': '→', 'cmtPoster': 'CiaoTwo', 'cmtContent': ':在奧入瀨十和田地區遊玩的時間可以拉長一些', 'cmtDate': '2023-05-12 21:37:00'}
# {'cmtStatus': '推', 'cmtPoster': 'CiaoTwo', 'cmtContent': ':從青森會合的家人如果是買東日本PASS可以免費乘車', 'cmtDate': '2023-05-12 21:44:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':那如果不要住星野附近還有其他方便搭車的好選擇嗎', 'cmtDate': '2023-05-12 21:55:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':？', 'cmtDate': '2023-05-12 21:55:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':飯店的部分', 'cmtDate': '2023-05-12 21:58:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':目前分兩個因為還在猶豫奧入瀨溪要怎麼走', 'cmtDate': '2023-05-13 14:17:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':一日來回（行李放飯店）', 'cmtDate': '2023-05-13 14:17:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':住星野一晚但需考慮行李要怎麼帶', 'cmtDate': '2023-05-13 14:17:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':仙台的行程變成要先看在青森怎麼走了', 'cmtDate': '2023-05-13 14:17:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':又或者不住青森改青森一日遊晚上直接拉去八戶住', 'cmtDate': '2023-05-13 14:17:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Midiya', 'cmtContent': ':不太建議青森殺到東京再回仙台耶太花時間了', 'cmtDate': '2023-05-13 20:54:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Midiya', 'cmtContent': ':把原本要去東京的時間改去山形可以去藏王御釜', 'cmtDate': '2023-05-13 20:54:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Midiya', 'cmtContent': ':六月底七月初的山形還有機會去摘櫻桃(佐藤錦)', 'cmtDate': '2023-05-13 20:55:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Midiya', 'cmtContent': ':山形是日本數一數二的水果產地櫻桃和鴨梨都很棒', 'cmtDate': '2023-05-13 20:56:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Midiya', 'cmtContent': ':不去東京的話pass改買另一張東北+南北海道的就好', 'cmtDate': '2023-05-13 20:56:00'}
# {'cmtStatus': '推', 'cmtPoster': 'Midiya', 'cmtContent': ':BTW藏王御釜可以只搭巴士上去看景色或者健行都可', 'cmtDate': '2023-05-13 20:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Midiya', 'cmtContent': ':看你的時間安排我是覺得藏王御釜真的很美!', 'cmtDate': '2023-05-13 20:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Midiya', 'cmtContent': ':不過這個點比較吃天氣需要一點運氣才能看到', 'cmtDate': '2023-05-13 20:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Midiya', 'cmtContent': ':另外仙台市區觀光你就搭他們的觀光巡迴巴士就好', 'cmtDate': '2023-05-13 20:59:00'}
# {'cmtStatus': '→', 'cmtPoster': 'Midiya', 'cmtContent': ':去瑞鳳殿、仙台城跡、大崎八幡宮等等', 'cmtDate': '2023-05-13 21:01:00'}
# {'cmtStatus': '→', 'cmtPoster': 'kashima228', 'cmtContent': ':山形嗎我來研究看看謝謝你', 'cmtDate': '2023-05-13 22:49:00'}

# %%
#首先我們在經過資料前處理後，將資料整理成方便分析的格式

# %%
raw_data = raw_data.explode(['artComter','artStatus'])
social_data = raw_data[['artUrl','artPoster','artComter','artStatus']]
social_data.head(10)
# Out:
#                                                artUrl artPoster     artComter  \
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed    chen210121
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed  kyonyuumania
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed     debby1993
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed   soulXdancer
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed         shlee
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed        YYZZKK
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed     mithralin
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed     mithralin
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed    purevision
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed        er5820
#
#    artStatus
# 36         推
# 36         推
# 36         推
# 36         →
# 36         →
# 36         推
# 36         推
# 36         推
# 36         推
# 36         →

# %%
#查看資料集的推文狀況，可以看到有推有噓也有箭頭
social_data.artStatus.unique()
# Out:
# array(['推', '→', '噓'], dtype=object)

# %% [markdown]
# 接著劃分發文、跟回覆，建立網路圖

# %%
# 建立邊的資料
import random


po_df = social_data[['artPoster','artUrl']].drop_duplicates().rename(columns = {'artPoster':'src','artUrl':'dis'})
sample_url = random.choices(po_df.dis.unique().tolist(),k=300)
po_df = po_df[po_df.dis.isin(sample_url)]
re_df = social_data[['artComter','artUrl','artStatus']].rename(columns = {'artComter':'src','artUrl':'dis','artStatus':'weight'})
re_df = re_df[re_df.dis.isin(sample_url)]
re_df = re_df[~re_df['src'].isna()]



def convertStatus(s):
  if s == '推':
    return 2
  elif s == '→':
    return 1
  else :
    return -1
re_df['weight'] = re_df['weight'].map(convertStatus)
re_df = re_df.groupby(['src','dis']).sum().reset_index()

# 設定分數低的為紅色
def getColor(w):
  if w>0:
    return 'green'
  else:
    return 'red'
re_df['color'] = re_df.weight.map(getColor)

# %%
# 人為綠色節點
# po文為橘色節點

netWork = pyvis.network.Network(notebook=True, cdn_resources='in_line',directed=True)
person = list(set(po_df.src.unique().tolist()+re_df.src.unique().tolist()))
url = po_df.dis.unique().tolist()
netWork.add_nodes(
    nodes = person,
    value = [1 for i in range(len(person))],
    color = ['#66CDAA' for i in range(len(person))],
    title = person
)
netWork.add_nodes(
    nodes = url,
    value = [2 for i in range(len(url))],
    color = ['#FFB366' for i in range(len(url))],
    title = url
)
for i in po_df.to_numpy():
  netWork.add_edge(i[0],i[1],width = 2,color='grey')
for i in re_df.to_numpy():
  netWork.add_edge(i[0],i[1],width = 2,color=i[3])

# 設定layout
netWork.repulsion()

netWork.toggle_physics(False)
netWork.set_options("""
const options = {
  "physics": {
    "forceAtlas2Based": {
      "springLength": 100
    },
    "minVelocity": 0.75,
    "solver": "forceAtlas2Based",
    "timestep": 0.48
  }
}
""")

netWork.show("./basic_netWork.html")
IPython.display.HTML('basic_netWork.html')
# Out:
# ./basic_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# 可以看到圖中，將有較多回覆的文拉出來看一下大概是哪類型的文，可以有較多的回覆。
# 另一方面可以看到在圖上有少數的發文是有紅線的，也將該文拿出來看看是哪種文。

# %% [markdown]
# 接著簡單看一下哪篇文跟作者的回覆最多

# %%
social_data['artUrl'].value_counts()
# Out:
# https://www.ptt.cc/bbs/Japan_Travel/M.1683396221.A.169.html    960
# https://www.ptt.cc/bbs/Japan_Travel/M.1683829568.A.6FF.html     65
# https://www.ptt.cc/bbs/Japan_Travel/M.1683533701.A.374.html     64
# https://www.ptt.cc/bbs/Japan_Travel/M.1684289901.A.336.html     60
# https://www.ptt.cc/bbs/Japan_Travel/M.1683457949.A.2D3.html     60
# https://www.ptt.cc/bbs/Japan_Travel/M.1684032796.A.1B9.html     48
# https://www.ptt.cc/bbs/Japan_Travel/M.1683836664.A.4BC.html     41
# https://www.ptt.cc/bbs/Japan_Travel/M.1683526229.A.A21.html     40
# https://www.ptt.cc/bbs/Japan_Travel/M.1684215601.A.7E2.html     36
# https://www.ptt.cc/bbs/Japan_Travel/M.1683859440.A.3CF.html     35
# https://www.ptt.cc/bbs/Japan_Travel/M.1684029778.A.8EC.html     34
# https://www.ptt.cc/bbs/Japan_Travel/M.1684254309.A.519.html     27
# https://www.ptt.cc/bbs/Japan_Travel/M.1683805781.A.426.html     25
# https://www.ptt.cc/bbs/Japan_Travel/M.1684046197.A.496.html     22
# https://www.ptt.cc/bbs/Japan_Travel/M.1683557672.A.20C.html     19
# https://www.ptt.cc/bbs/Japan_Travel/M.1683210008.A.6AD.html     18
# https://www.ptt.cc/bbs/Japan_Travel/M.1683823202.A.296.html     11
# https://www.ptt.cc/bbs/Japan_Travel/M.1683386395.A.A11.html     10
# https://www.ptt.cc/bbs/Japan_Travel/M.1684587763.A.BE8.html      8
# https://www.ptt.cc/bbs/Japan_Travel/M.1684499712.A.4E7.html      8
# https://www.ptt.cc/bbs/Japan_Travel/M.1684162487.A.2BE.html      8
# https://www.ptt.cc/bbs/Japan_Travel/M.1684535449.A.6B6.html      7
# https://www.ptt.cc/bbs/Japan_Travel/M.1684319286.A.A0B.html      7
# https://www.ptt.cc/bbs/Japan_Travel/M.1684468573.A.9CC.html      6
# https://www.ptt.cc/bbs/Japan_Travel/M.1684300498.A.D56.html      6
# https://www.ptt.cc/bbs/Japan_Travel/M.1683045443.A.A37.html      6
# https://www.ptt.cc/bbs/Japan_Travel/M.1683277152.A.386.html      4
# https://www.ptt.cc/bbs/Japan_Travel/M.1684198206.A.65A.html      4
# https://www.ptt.cc/bbs/Japan_Travel/M.1683217157.A.F78.html      4
# https://www.ptt.cc/bbs/Japan_Travel/M.1682951703.A.1FC.html      3
# https://www.ptt.cc/bbs/Japan_Travel/M.1684512030.A.A9C.html      3
# https://www.ptt.cc/bbs/Japan_Travel/M.1684508435.A.D56.html      2
# https://www.ptt.cc/bbs/Japan_Travel/M.1683785580.A.7EA.html      2
# https://www.ptt.cc/bbs/Japan_Travel/M.1683457974.A.2D4.html      2
# https://www.ptt.cc/bbs/Japan_Travel/M.1683564640.A.C62.html      1
# https://www.ptt.cc/bbs/Japan_Travel/M.1682933943.A.126.html      1
# https://www.ptt.cc/bbs/Japan_Travel/M.1683857141.A.41D.html      1
# https://www.ptt.cc/bbs/Japan_Travel/M.1683476665.A.0BE.html      1
# Name: artUrl, dtype: int64

# %%
social_data['artPoster'].value_counts()
# Out:
# UncleRed        960
# OhmoriHarumi    100
# kashima228       65
# adychen1982      64
# xxYAYAxx         60
# shinchenboy      48
# bababana         41
# bluewith         36
# yhls             35
# shin761124       34
# Jamez            27
# talon0222        25
# bravewarrior     22
# legool           19
# abnerli          18
# JimXpp           12
# buaa2211         11
# mvpdirk712       10
# Aurora5566        8
# skw15             8
# ihatebbo          8
# allen101pq        7
# kenploin          6
# hesitates         6
# rainwing          6
# k272821           4
# HeSit             4
# lsylin            3
# jardin123         3
# tedandjolin       2
# emu200            2
# matmoki           2
# sleetyarn         1
# airpigeon         1
# zonapha           1
# Name: artPoster, dtype: int64

# %% [markdown]
# 可以發現，比較多人回覆的貼文大都是日本旅遊板的鄉民幫忙旅遊行程健檢或推薦，以及遊記的分享，會有較多的回覆，且都是箭頭或是推。
# 最特別的是最多人回覆的那篇，是關於星宇航空最近的新聞的懶人包，該機上乘客對於整起事件的整理，因此關注度最高
# 而出現噓文的幾篇貼文中，較多回覆的那篇(https://www.ptt.cc/bbs/Japan_Travel/M.1683526229.A.A21.html)
# 內容則是分享國泰航空的優惠，但是由於國泰航空是香港的航空公司，有一些鄉民會因為意識型態不同而有不同立場的推文，因此出現了噓文。
#
# 而第二篇有噓文的(https://www.ptt.cc/bbs/Japan_Travel/M.1684568147.A.946.html) 文章主要是在問歷年來九月東京的人潮，藉此有個預期心理，但噓文的人認為今年九月還沒到怎麼知道人潮如何而做出噓文，整體來說這篇文是正常的提問，只出現一個噓，可以當作特例。

# %% [markdown]
# 計算網友之間的關係

# %%
pos_cmt = social_data.copy()
pos_cmt = pos_cmt[~pos_cmt.artComter.isna()]
pos_cmt.head(10)
# Out:
#                                                artUrl artPoster     artComter  \
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed    chen210121
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed  kyonyuumania
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed     debby1993
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed   soulXdancer
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed         shlee
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed        YYZZKK
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed     mithralin
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed     mithralin
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed    purevision
# 36  https://www.ptt.cc/bbs/Japan_Travel/M.16833962...  UncleRed        er5820
#
#    artStatus
# 36         推
# 36         推
# 36         推
# 36         →
# 36         →
# 36         推
# 36         推
# 36         推
# 36         推
# 36         →

# %%
pos_cmt['score'] = pos_cmt['artStatus'].apply(lambda r: convertStatus(r))
pos_cmt = pos_cmt.groupby(['artComter','artPoster']).sum('score').reset_index()
pos_cmt = pos_cmt[pos_cmt.score>=0]
pos_cmt = pos_cmt[pos_cmt.artComter != pos_cmt.artPoster]
# pos_cmt.score = 1
pos_cmt
# Out:
#       artComter     artPoster  score
# 0     A00610lol      UncleRed      9
# 1           APC      UncleRed      2
# 2       Aaron22          yhls      3
# 3    Abbaschian      xxYAYAxx      2
# 4    AisinGioro    mvpdirk712      5
# ..          ...           ...    ...
# 596    zxc70227        JimXpp      2
# 597       zzlzz      UncleRed      2
# 598        zzro  OhmoriHarumi      3
# 599    zzyyxx77   shinchenboy      1
# 600    zzzz8931      UncleRed      2
#
# [582 rows x 3 columns]

# %%
pers = np.unique(pos_cmt[['artComter', 'artPoster']])
mat = pd.pivot_table(pos_cmt,index = 'artComter', columns = 'artPoster' ,values='score' ).fillna(0)\
  .reindex(columns=pers, index=pers, fill_value=0).to_numpy() #有向
print(mat.shape)
tri = (np.tril(mat,-1).T + np.triu(mat,1))
mat_s = tri+tri.T #無向
# Out:
# (523, 523)

# %%
def random_color():
  r = lambda: random.randint(0,255)
  return '#%02X%02X%02X' % (r(),r(),r())

def matPresentGraph(mat:np.array,node_id:list,node_type:list=None,node_value:list = None,directed = True,edge_color=None) -> pyvis.network.Network:

  if directed != True:
    if (mat == mat.transpose()).all():
      print('matrix is Symmetric')
    else:
      print('matrix is not Symmetric')
  if node_type == None:
    c = random_color()
    node_colors = [c for i in range(len(node_id))]
    node_type = [" " for i in range(len(node_id))]
  else:
    node_color_map = {}
    for i in set(node_type):
      while True:
        c = random_color()
        if c not in node_color_map.values():
          break
      node_color_map[i] = c
    node_colors = [node_color_map[i] for i in node_type]
  # print(node_colors)
  if edge_color == None:
    edge_color = random_color()
  edge_color = random_color()
  if node_value == None:
    node_value = [1 for i in range(len(node_id))]

  net = pyvis.network.Network(notebook=True, directed = directed, cdn_resources='in_line')
  
  titles_list = []
  for i ,j in zip(node_id,node_type):
    titles_list.append(str(i)+":"+str(j))

  net.add_nodes(
      nodes = node_id,
      value = node_value,
      label = node_id,
      title = titles_list,
      color = node_colors
  )

  for row in range(len(node_id)):
    for col in range(len(node_id)):
      if mat[row][col]>0.:
        net.add_edge(
            node_id[row],node_id[col],width = mat[row][col],color = edge_color,title = mat[row][col]
        )
  net.repulsion()
  return net

# %%
# 定義發文者（po）、評論者(cmt)、兩者兼具(both)
node_type = []

cmt_list = pos_cmt['artComter'].unique().tolist()
po_list = pos_cmt['artPoster'].unique().tolist()
both_list = list(set(cmt_list) & set(po_list))
for p in pers:
  if p in both_list:
    node_type.append('both')

  elif p in cmt_list:
    node_type.append('cmt')

  elif p in po_list:
    node_type.append('po')

# %%
net = matPresentGraph(mat = mat,node_id = pers,node_type = node_type)
net.show("./pers_netWork.html")
IPython.display.HTML('pers_netWork.html')
# Out:
# ./pers_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# 可以發現回覆的網友最多，其次是發文的，both的網友最少

# %% [markdown]
# 計算eigenvector centrality （無向圖）

# %%
eigenvec = np.array(list(nx.eigenvector_centrality(nx.Graph(mat_s),max_iter = 10000).values()))
eigenvec = (eigenvec-np.min(eigenvec))/(np.max(eigenvec)-np.min(eigenvec))

# %%
q = np.quantile(eigenvec,[.2,.4,.6,.8])
q
# Out:
# array([0.000717  , 0.00480973, 0.05876176, 0.05876176])

# %%
node_value = []


for i in eigenvec:

  if i > q[3]:
    node_value.append(25)
  elif i >q[2]:
    node_value.append(20)
  elif i>q[1]:
    node_value.append(15)
  elif i>q[0]:
    node_value.append(10)
  else:
    node_value.append(5)
net = matPresentGraph(mat = mat,node_id = pers,node_type = node_type,node_value = node_value,directed=False)
net.show("./pers_eig_netWork.html")
IPython.display.HTML('pers_eig_netWork.html')
# Out:
# matrix is not Symmetric
# ./pers_eig_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# 可以看到回覆的人數越多，該文的原PO的重要程度越高，而同時有發文也是評論者的人的重要程度也比只有發文或只有回的網友高

# %% [markdown]
# PageRank (有向圖)

# %%
# Digraph 設定有向圖
pagerank = np.array(list(nx.pagerank(nx.DiGraph(mat)).values()))
# pagerank = (pagerank-np.min(pagerank))/(np.max(pagerank)-np.min(pagerank))
pagerank
# Out:
# array([0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.0018825 , 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00112335, 0.00090733,
#        0.01081804, 0.00090733, 0.00810798, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.06987818,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.2485662 , 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.01079968, 0.00090733, 0.00090733,
#        0.01476346, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00167882, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00222238, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00299743, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00397354,
#        0.00090733, 0.00090733, 0.00090733, 0.00980798, 0.00090733,
#        0.00090733, 0.00360367, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00245032, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00418619, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00425967, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00245032, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00245032,
#        0.00090733, 0.00090733, 0.00090733, 0.00773294, 0.00090733,
#        0.00090733, 0.00245032, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00295007, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00176455, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00245032, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00476482, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00377902, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00710638, 0.00552292, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00158086, 0.00090733, 0.00167882,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.0087362 , 0.00090733, 0.00090733, 0.00167882, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.01545005, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.08226547, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00129308, 0.00090733, 0.00090733, 0.00090733, 0.00090733,
#        0.00090733, 0.00090733, 0.00090733])

# %%
net = matPresentGraph(mat = mat,node_id = pers,node_type = node_type,node_value=(pagerank*1000).tolist())
net.show("./pers_page_netWork.html")
IPython.display.HTML('pers_page_netWork.html')
# Out:
# ./pers_page_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# 可以看出indegree 較多，重要程度愈高，很明顯星宇航空那篇文的作者的分數是最高的

# %% [markdown]
# Hits score （有向圖）

# %%
out_,in_ = nx.hits(nx.DiGraph(mat),max_iter=100)
out_,in_ = np.array(list(out_.values())),np.array(list(in_.values()))
out_ = (out_-np.min(out_))/(np.max(out_)-np.min(out_))
in_ = (in_-np.min(in_))/(np.max(in_)-np.min(in_))

# %%
in_q = np.quantile(in_,[.2,.4,.6,.8])
out_q = np.quantile(out_,[.2,.4,.6,.8])

# %%
in_q
# Out:
# array([2.69670641e-17, 2.90774611e-17, 2.99045276e-17, 3.30653254e-17])

# %%
node_value = []


for i in out_:
  if i > out_q[3]:
    node_value.append(25)
  elif i >out_q[2]:
    node_value.append(20)
  elif i>out_q[1]:
    node_value.append(15)
  elif i>out_q[0]:
    node_value.append(10)
  else:
    node_value.append(5)

net = matPresentGraph(mat = mat,node_id = pers,node_type = node_type,node_value=node_value)
net.show("./pers_out_netWork.html")
IPython.display.HTML('pers_out_netWork.html')
# Out:
# ./pers_out_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %%
node_value = []
for i in in_:
  if i > in_q[3]:
    node_value.append(25)
  elif i >in_q[2]:
    node_value.append(20)
  elif i>in_q[1]:
    node_value.append(15)
  elif i>in_q[0]:
    node_value.append(10)
  else:
    node_value.append(5)

net = matPresentGraph(mat = mat,node_id = pers,node_type = node_type,node_value=node_value)
net.show("./pers_in_netWork.html")
IPython.display.HTML('pers_in_netWork.html')
# Out:
# ./pers_in_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# 可以發現indegree/outdegree的多寡會決定其重要程度，星宇航空那篇文的作者(UncleRed)的indegree多outdegreeg少，他在關於東京的相關文中，最近只有發這篇文，而且並沒有去回覆他人。

# %% [markdown]
# betweenness centrality

# %%
bet = np.array(list(nx.betweenness_centrality(nx.Graph(mat_s)).values()))
bet = (bet-np.min(bet))/(np.max(bet)-np.min(bet))
bet_q = np.quantile(bet,[.2,.4,.6,.8])

# %%
node_value = []
for i in bet:
  if i > bet_q[3]:
    node_value.append(25)
  elif i > bet_q[2]:
    node_value.append(20)
  elif i>bet_q[1]:
    node_value.append(15)
  elif i>bet_q[0]:
    node_value.append(10)
  else:
    node_value.append(5)

net = matPresentGraph(mat = mat,node_id = pers,node_type = node_type,node_value=node_value)
net.show("./pers_bet_netWork.html")
IPython.display.HTML('pers_bet_netWork.html')
# Out:
# ./pers_bet_netWork.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# 計算最大的子圖的指標

# %%
# 計算max subgraph
G = nx.Graph(mat_s)
G_sub = sorted(nx.connected_components(G), key=len, reverse=True)
G_max_sub = G.subgraph(G_sub[0])
# # 重新定義 mat
sub_mat = nx.adjacency_matrix(G_max_sub).todense()
node_idx = list(G_max_sub.nodes)
sub_pers = pers[node_idx]

# %% [markdown]
# 畫出最大subgraph

# %%
net = matPresentGraph(mat=sub_mat,node_id=sub_pers,directed=False)
net.show("./max_sub.html")
IPython.display.HTML('max_sub.html')
# Out:
# matrix is Symmetric
# ./max_sub.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <style>.vis-overlay{bottom:0;left:0;position:absolute;right:0;top:0;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-color-picker{background-color:#fff;border-radius:15px;box-shadow:0 0 10px 0 rgba(0,0,0,.5);display:none;height:444px;left:30px;margin-left:30px;margin-top:-140px;padding:10px;position:absolute;top:0;width:310px;z-index:1}div.vis-color-picker div.vis-arrow{left:5px;position:absolute;top:147px}div.vis-color-picker div.vis-arrow:after,div.vis-color-picker div.vis-arrow:before{border:solid transparent;content:" ";height:0;pointer-events:none;position:absolute;right:100%;top:50%;width:0}div.vis-color-picker div.vis-arrow:after{border-color:hsla(0,0%,100%,0) #fff hsla(0,0%,100%,0) hsla(0,0%,100%,0);border-width:30px;margin-top:-30px}div.vis-color-picker div.vis-color{cursor:pointer;height:289px;position:absolute;width:289px}div.vis-color-picker div.vis-brightness{position:absolute;top:313px}div.vis-color-picker div.vis-opacity{position:absolute;top:350px}div.vis-color-picker div.vis-selector{background:#4c4c4c;background:-moz-linear-gradient(top,#4c4c4c 0,#595959 12%,#666 25%,#474747 39%,#2c2c2c 50%,#000 51%,#111 60%,#2b2b2b 76%,#1c1c1c 91%,#131313 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#4c4c4c),color-stop(12%,#595959),color-stop(25%,#666),color-stop(39%,#474747),color-stop(50%,#2c2c2c),color-stop(51%,#000),color-stop(60%,#111),color-stop(76%,#2b2b2b),color-stop(91%,#1c1c1c),color-stop(100%,#131313));background:-webkit-linear-gradient(top,#4c4c4c,#595959 12%,#666 25%

# %% [markdown]
# 計算transitivity

# %%
nx.transitivity(nx.Graph(sub_mat))
# Out:
# 0.0006702712364270075

# %% [markdown]
# 計算density 及 distance

# %%
nx.density(nx.Graph(sub_mat))
# Out:
# 0.004567728954371389

# %%
nx.average_shortest_path_length(nx.Graph(sub_mat))
# Out:
# 3.326831959498929

# %% [markdown]
# 計算diameter

# %%
nx.diameter(nx.Graph(sub_mat))
# Out:
# 8

# %% [markdown]
# 計算clustering

# %%
nx.average_clustering(nx.Graph(sub_mat))
# Out:
# 0.011418563898804333
